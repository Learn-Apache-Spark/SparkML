# %% [markdown]
# # 4 - Evaluating models and intro to Pipelines
#
# In this chapter, you will:
#
# • Learn to evaluate your ML model
#
# • Learn to use Pipelines

# %%
from pyspark.sql import SparkSession 
from pyspark.ml import Pipeline
from pyspark.ml.regression import LinearRegression, LinearRegressionModel
from pyspark.ml.fpm import FPGrowth, FPGrowthModel


from pyspark.ml.evaluation import RegressionEvaluator

spark = SparkSession.builder \
    .master('local[*]') \
    .appName("Pipelines") \
    .getOrCreate()

# %% [markdown]
# #### Load machine learning model :
#
#
# Load the models from previous Chapter:

# %%
lr_model = LinearRegressionModel.load('linearRegression_model')

# %%
fpgrowth_model = FPGrowthModel.load('fpGrowth_model')

# %% [markdown]
# Evaluate the models:
#
# For evaluation, load classified test data

# %%
df_test = spark.read.parquet("classified_test_data")

# %% [markdown]
# [From the docs:](https://spark.apache.org/docs/latest/mllib-evaluation-metrics.html)
#
# While there are many different types of classification algorithms, the evaluation of classification models all shares similar principles.
#
# In a supervised classification problem, there exists a _true output_ and a _model-generated predicted output_ for each data row.

# %% [markdown]
# ## Exercise 1: Evaluate your ML model

# %% [markdown]
# ### RegressionEvaluator functionality:
#
#
# ✅ **Task :**
#
#
# Start with predicting the outcome:
# Use predict function
#
# ```python
#     model.transform(vectorOfFeatures).select('prediction').show()
# ```
#
# Notice that transform takes a vector of features as input.
#
# Prediction represents if it's a bot or not.
# 1- bot
# 0- human

# %%
from pyspark.ml.feature import VectorAssembler

test = df_test.drop('description')
vecAssembler = VectorAssembler(inputCols=['screen_name','location','followers_count','friends_count','listed_count','favourites_count','verified','statuses_count','status','default_profile','name'], outputCol="features", handleInvalid = "skip")
test_df_with_vector = vecAssembler.transform(test)

model_test_prediction = lr_model.transform(test_df_with_vector)
model_test_prediction.select('bot','prediction').show()
# Out:
# +----+-------------------+
# | bot|         prediction|
# +----+-------------------+
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# |   1|0.10201588271227856|
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# |null|0.10201588271227856|
# +----+-------------------+
# only showing top 20 rows

# %% [markdown]
# The model gave us a prediction of the chances for a specific row to
# be a bot. We got numbers like 0.147 and 0.1021.
#
# It is up to us to define the **threshold** for classifying a bot.
# If it shows us 0.9? Will it satisfy us? How certain do we want to be in the classification?

# %% [markdown]
# **RegressionEvaluator** is the evaluator for regression-based models

# %% [markdown]
# Use regressionEvaluator to evaluate the model.
#
# ```pyhon
# from pyspark.ml.evaluation import RegressionEvaluator
# lr_evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="bot",metricName="r2")
# R2 = lr_evaluator.evaluate(model_test_prediction)
# ```
#
# Check out R2 :
# >R-squared is a statistical measure of how close the data are to the fitted regression line. It is also known as the coefficient of determination, or the coefficient of multiple determination for multiple regression. 100% indicates that the model explains all the variability of the response data around its mean
#
# From: [RegressionAnalysis](https://blog.minitab.com/blog/adventures-in-statistics-2/regression-analysis-how-do-i-interpret-r-squared-and-assess-the-goodness-of-fit)

# %% [markdown]
# Notice `metricName` param:
#
# RegressionEvaluator Supports: - `rmse` (default): root mean squared error - `mse`: mean squared error - `r2`: R Sqaure metric - `mae`: mean absolute error

# %% [markdown]
# **Notice!** here we work with the train data and select both `bot` and `prediction` to get a feel for the classifier

# %%
test = model_test_prediction.fillna({'bot':0})
test.show()
# Out:
# +-----------+--------+--------------------+---------------+-------------+------------+--------------------+----------------+--------+--------------+-----+------+---------------+---------------------+--------------------+----+---+--------------------+-------------------+
# |screen_name|location|                 url|followers_count|friends_count|listed_count|          created_at|favourites_count|verified|statuses_count| lang|status|default_profile|default_profile_image|has_extended_profile|name|bot|            features|         prediction|
# +-----------+--------+--------------------+---------------+-------------+------------+--------------------+----------------+--------+--------------+-----+------+---------------+---------------------+--------------------+----+---+--------------------+-------------------+
# |          1|       0|http://t.co/TNE4S...|         328658|          110|        4381|Thu Jun 20 15:22:...|               3|       1|           319|   en|     1|              0|                 null|                null|   1|  0|[1.0,0.0,328658.0...|0.10201588271227856|
# |          1|       0|http://t.co/QHgTd...|             85|           13|           2|Fri May 02 13:40:...|            1637|       0|           115|   en|     1|              0|                 null|                null|   1|  0|[1.0,0.0,85.0,13....|0.10201588271227856|
# |          1|       0|                null|              5|            0|           2|      10/7/2016 8:30|               0|       0|           424|   en|     1|              0|                 null|                null|   1|  0|(11,[0,2,4,7,8,10...|0.10201588271227856|
# |          1|       0|https://t.co/Pdag...|          10014|           27|         326|      6/21/2014 0:14|               0|       0|         14473|en-gb|     1|              0|                 null|                null|   1|  0|[1.0,0.0,10014.0,...|0.10201588271227856|
# |          1|       0|https://t.co/62Fl...|             40|            0|           9|Tue Dec 02 06:51:...|              25|       0|          1868|   en|     1|              0|                 null|                null|   1|  0|[1.0,0.0,40.0,0.0...|0.10201588271227856|
# |          1|       0|                null|            105|            1|          13|Fri Dec 25 10:47:...|               9|       0|           570|   en|     1|              0|                 null|                null|   1|  0|[1.0,0.0,105.0,1....|0.10201588271227856|
# |          1|       0|                null|            873|            8|           4|Tue Dec 15 18:02:...|               0|       0|         20734|   en|     1|              0|                 null|                null|   1|  0|[1.0,0.0,873.0,8....|0.10201588271227856|
# |          1|       0|                null|              6|            0|           5|Mon Feb 09 23:12:...|               0|       0|          2751|   en|     1|              0|                 null|                null|   1|  0|(11,[0,2,4,7,8,10...|0.10201588271227856|
# |          1|       0|https://t.co/Pp9s...|           8392|           30|         159|     6/29/2015 13:36|            1361|       0|          5730|   en|     1|              0|                 null|                null|   1|  0|[1.0,0.0,8392.0,3...|0.10201588271227856|
# |          1|       0|https://t.co/Hgsh...|             41|            8|           0|     3/13/2017 23:15|               0|       0|             2|   en|     1|              0|                 null|                null|   1|  0|(11,[0,2,3,7,8,10...|0.10201588271227856|
# |          1|       0|https://t.co/e0GU...|           1986|         4055|         909|     4/20/2009 20:57|            1175|       0|         10207|   en|     1|              0|                 null|                null|   1|  0|[1.0,0.0,1986.0,4...|0.10201588271227856|
# |          1|       0|https://t.co/Q13W...|           5324|          184|         151|Sun Apr 05 09:57:...|            1350|       1|          2631|   en|     1|              0|                 null|                null|   1|  0|[1.0,0.0,5324.0,1...|0.10201588271227856|
# |          1|       0|                null|             52|            2|          16|     12/27/2015 3:56|              21|       0|          7996|   ja|     1|              0|                 null|                null|   1|  0|[1.0,0.0,52.0,2.0...|0.10201588271227856|
# |          1|       0|                null|         290004|          101|         613|Tue Nov 24 19:46:...|             207|       1|           392|   en|     1|              0|                 null|                null|   1|  0|[1.0,0.0,290004.0...|0.10201588271227856|
# |          1|       0|                null|          61191|         1194|        1169|Tue Jan 20 14:24:...|            5313|       1|         16821|   en|     1|              0|                 null|                null|   1|  0|[1.0,0.0,61191.0,...|0.10201588271227856|
# |          1|       0|                null|             17|            0|           6|Mon Oct 13 21:41:...|               1|       0|             0|   de|     0|              1|                false|               false|   1|  1|(11,[0,2,4,5,9,10...|0.10201588271227856|
# |          1|       0|                None|             20|           96|           0|Thu Jun 09 12:16:...|             374|       0|             1|   en|     1|              0|                 null|                null|   1|  0|[1.0,0.0,20.0,96....|0.10201588271227856|
# |          1|       0|                None|             20|          144|           0|Thu May 02 14:22:...|              18|       0|           452|   fr|     1|              0|                 null|                null|   1|  0|[1.0,0.0,20.0,144...|0.10201588271227856|
# |          1|       0|https://t.co/jODy...|         276122|          166|        7084|Thu Jun 25 19:57:...|            1234|       1|          7336|   en|     1|              0|                 null|                null|   1|  0|[1.0,0.0,276122.0...|0.10201588271227856|
# |          1|       0|https://t.co/GVly...|             82|            0|           9|     1/18/2016 22:22|               0|       0|          4591|   en|     1|              0|                 null|                null|   1|  0|(11,[0,2,4,7,8,10...|0.10201588271227856|
# +-----------+--------+--------------------+---------------+-------------+------------+--------------------+----------------+--------+--------------+-----+------+---------------+---------------------+--------------------+----+---+--------------------+-------------------+
# only showing top 20 rows

# %%
from pyspark.ml.feature import VectorAssembler

df_train = spark.read.parquet("classified_train_data")

train = df_train.drop('description')
vecAssemblerTrain = VectorAssembler(inputCols=['screen_name','location','followers_count','friends_count','listed_count','favourites_count','verified','statuses_count','status','default_profile','name'], outputCol="features", handleInvalid = "skip")
vecAssemblerTrain = vecAssemblerTrain.transform(train)

model_train_prediction = lr_model.transform(vecAssemblerTrain)
model_train_prediction.select('bot','prediction')

test = model_train_prediction.fillna({'bot':0})
model_train_prediction  = test

# %%
lr_evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="bot",metricName="r2")
R2 = lr_evaluator.evaluate(model_train_prediction)

print("R Squared (R2) on test data = %g" % R2)
# Out:
# R Squared (R2) on test data = 4.55191e-15

# %% [markdown]
# When looking back at the `Predictions` output, we understand that they don't help us much.
#
# `Predictions` output is a number between [0,1].
#
#
# However, we expect 1 or 0: bot or human.
# What can we do?
# Decide on a threshold.
#
#
# For Example, every prediction above 0.8 is bot. Bellow 0.8 is human.
#
# Or maybe every prediction above 0.14?

# %% [markdown]
# ---

# %% [markdown]
# ✅ Task :
#
# Use model statistics params:
#
# For example
# Check RMSE - Root Mean Squared Error
# For both train and test.

# %% [markdown]
# Code sample:
#
# ```python
# def getLRSummary(df):
#     df = df.drop('description')
#     vecAssembler = VectorAssembler(inputCols=['screen_name','location','followers_count','friends_count','listed_count','favourites_count','verified','statuses_count','status','default_profile','name'], outputCol="features", handleInvalid = "skip")
#     vecAssembler = vecAssembler.transform(df)
#     output_test = vecAssembler.drop('screen_name','location','followers_count','friends_count','listed_count','favourites_count','verified','statuses_count','status','default_profile','name')
#     output_test  = output_test.selectExpr("features", "bot as label")
#     # evaluate function returns LinearRegressionSummary instance that holds the evaluate results
#     return lr_model.evaluate(output_test)
# ```
#
#
# Here are function [r2 docs](https://spark.apache.org/docs/2.1.0/api/python/pyspark.ml.html#pyspark.ml.regression.LinearRegressionSummary.r2)
#
# Check on both training and test set:

# %%
def getLRSummary(df):
    df = df.drop('description')
    vecAssembler = VectorAssembler(inputCols=['screen_name','location','followers_count','friends_count','listed_count','favourites_count','verified','statuses_count','status','default_profile','name'], outputCol="features", handleInvalid = "skip")
    vecAssembler = vecAssembler.transform(df)
    output = vecAssembler.drop('screen_name','location','followers_count','friends_count','listed_count','favourites_count','verified','statuses_count','status','default_profile','name')
    output  = output.selectExpr("features", "bot as label")
    # evaluate function returns LinearRegressionSummary instance that holds the evaluated results
    return lr_model.evaluate(output)

# %%
df_train = df_train.fillna({'bot':0})
df_test = df_test.fillna({'bot':0})

# %%
train_results = getLRSummary(df_train)
print("Root Mean Squared Error (RMSE) on train data = %g" % train_results.rootMeanSquaredError)

test_results = getLRSummary(df_test)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_results.rootMeanSquaredError)
# Out:
# Root Mean Squared Error (RMSE) on train data = 0.302669
# Root Mean Squared Error (RMSE) on test data = 0.323616

# %% [markdown]
# `LinearRegressionSummary` gives you a summary of the statistical algorithm evaluations.

# %%
print("r2 on test data = %g" % test_results.r2)
print("r2 on train data = %g" % train_results.r2)
# Out:
# r2 on test data = -0.00260044
# r2 on train data = 4.55191e-15

# %% [markdown]
# #### What did you learn?
# What more evaluating params can you get out of LinearRegressionSummary instance?

# %% [markdown]
# **Reminder**
# What is r2? R Square:
# >R-squared is a statistical measure of how close the data are to the fitted regression line. It is also known as the coefficient of determination, or the coefficient of multiple determination for multiple regression.
#
# R Square measure how much of the variability in `bot` / `label` can be explained using the model.
# We must be cautious that the performance on the training set to avoid overfitting of the model to the training set.
# Overrfiting can create a model that is good only for the training set and not for the test set.
#
#
# What is RMSE?
# > Root Mean Square Error (RMSE) is the standard deviation of the residuals (prediction errors). Residuals are a measure of how far from the regression line data points are; RMSE is a measure of how spread out these residuals are. In other words, it tells you how concentrated the data is around the line of best fit.

# %% [markdown]
# ## Exercise 2: Build Simple Spark ML Pipelines

# %% [markdown]
# ML Pipelines provide a uniform set of high-level APIs built on top of DataFrames that help us create and tune practical machine learning pipelines.

# %% [markdown]
# In the previous exercise, you learned Logistic regression.
#
# Logistic regression is used when the dependent variable is binary.
# In our case, bot is binary - yes or no.
#
# Linear regression is used to predict the continuous dependent variable.
# This explains the result received.

# %% [markdown]
# ### Spark ML Pipelines

# %% [markdown]
# Start with a simple ML Pipelines:

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import HashingTF, Tokenizer

# %% [markdown]
# Remember that in Chapter 1 we split `description` into a list?
# Let's do it with the `Tokenizer` functionality instead!
#
# `Tokenizer` is part of the `pyspark.ml.feature`. `pyspark.ml.feature` give us many out of the box functionality for feature extraction. Feature extraction is the _data-science_ way of transforming columns into a new one.

# %% [markdown]
# Load saved data:

# %%
data = spark.read.parquet('train_data_only_description')
data = data.fillna({'label':0})

# %%
data.show()
(trainingData, testData) = data.randomSplit([0.7, 0.3])
# Out:
# +--------------------+-----+
# |         description|label|
# +--------------------+-----+
# |Cecil Hurt has co...|    0|
# |FOLLOW @xx5sosvin...|    0|
# |just a river on t...|    0|
# |Where should I go...|    0|
# |German words only...|    0|
# |Chief Technology ...|    1|
# |Official Twitter ...|    1|
# |Posting random fl...|    0|
# |US 50k Record Hol...|    1|
# |i'm a bot tweetin...|    0|
# |An atlas of unkno...|    0|
# |1-@sobesr 2-@myse...|    0|
# |https://t.co/BPdv...|    0|
# |RenÌ© PÌ©rez Jogl...|    0|
# |...Baby I'm lost ...|    0|
# |Cuenta oficial de...|    0|
# |Mobilizes our com...|    0|
# |Basketball is wha...|    0|
# |Meio políÈmico em...|    0|
# |I'm a British Eur...|    0|
# +--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# ### Tokenizer, HashingTF, and Logistic Regression
#
# ✅ **Task :**
#
# Configure an ML pipeline, which consists of three stages: tokenizer, hashingTF, and lr:
#
#
# Use the next code sample and adjust it to your needs :
# ```python
# tokenizer = Tokenizer(inputCol="description", outputCol="words")
# hashingTF = HashingTF(inputCol=tokenizer.getOutputCol(), outputCol="features")
# lr = LogisticRegression(maxIter=10, regParam=0.001)
# pipeline = Pipeline(stages=[tokenizer, hashingTF, lr])
#
# ```
#
#
# After we understand that Linear Regression might not be good enough for our data science purposes, we are going to work with Logistic Regression. This is your **3rd** Machine Learning model with Spark ML 🎉

# %%
# Configure an ML pipeline, which consists of three stages: tokenizer, hashingTF, and lr.
tokenizer = Tokenizer(inputCol="description", outputCol="words")
hashingTF = HashingTF(inputCol=tokenizer.getOutputCol(), outputCol="features")
lr = LogisticRegression(maxIter=10, regParam=0.001)
pipeline = Pipeline(stages=[tokenizer, hashingTF, lr])

# %% [markdown]
# Call fit on Pipeline to get the model:
#
# If it fails here, validates that `description` doesn't have null values.
# Our HashingTF doesn't know how to handle null values.
# If those exist, create a new DataFrame without them and use the new DataFrame to build the model.
#
# In case you need it:
# ``` python
#     trainingData = trainingData.dropna('description')
# ```

# %%
# Fit the pipeline to training documents.
model = pipeline.fit(trainingData)

# %% [markdown]
# Make predictions:

# %%
# Make predictions on test documents and print columns of interest.
prediction = model.transform(testData)
selected = prediction.select("description", "probability", "prediction")
for row in selected.collect():
    description, prob, prediction = row
    print("(%s) --> prob=%s, prediction=%f" % (description, str(prob), prediction))
# Out:
# ( California.""") --> prob=[0.9665115803217659,0.03348841967823409], prediction=0.000000
# ("""Electrical retailer in Belfast selling everything from TV's) --> prob=[0.9835042498124454,0.016495750187554507], prediction=0.000000
# ("""One piece_______One piece___Twitter________bot___1_______________________________________________________________________________________________RT_____________""") --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# ("""Photographer | Los Angeles) --> prob=[0.9681251515118753,0.03187484848812462], prediction=0.000000
# ("""Providing Tweets of the rarest and rare battle of the best Pokemon in the East Chula Vista area. All Times Til Hidden (TTH) are approximate.\n\nDonations welcome.""") --> prob=[0.9997564026901546,0.0002435973098453603], prediction=0.000000
# ("""Uber rare and strong PokŽmon in Singapore. See more PokŽmon at https://t.co/LLiUGW8lBD\n\nFollow @SGPokeStatus for more info and status update.""") --> prob=[0.9981780455675187,0.001821954432481362], prediction=0.000000
# ("New single ""KILL AGAIN"" out now! https://t.co/qiZ8W4mhJG Shaka Zulu! https://t.co/9ZY92tEQaX https://t.co/uBNsayp9Gr") --> prob=[0.9895723755869823,0.010427624413017618], prediction=0.000000
# ("O que me move? O perpétuo desejo de ser uma ""ponte"" melhor!  #Educação #MetodologiasAtivas #DesignThinking") --> prob=[0.9742214314495667,0.02577856855043334], prediction=0.000000
# (#wearedrugs, #SummerGodsTour, #resist surf whenever i can) --> prob=[0.9718622503758628,0.028137749624137065], prediction=0.000000
# ((insert here) survivor and former ink-stained wretch) --> prob=[0.9753804087892374,0.02461959121076269], prediction=0.000000
# (1-@sobesr 2-@myselenwtors 3- @zaynshadidd) --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# (@FoxSoccer TV Soccer Analyst & Host _Ù__ New Show #SpeakResponsibly link in bio) --> prob=[0.99796652656119,0.0020334734388100907], prediction=0.000000
# (A bot that generates novel literary and rhetorical devices and their definitions. By @atduskgreg.) --> prob=[0.9988865811683205,0.0011134188316795008], prediction=0.000000
# (A bot that tweets every line said by Robbie Valentino on Gravity Falls every 30 minutes. Please report any mistakes/misspellings/errors to @JadaManiscalco.) --> prob=[0.9995834900541305,0.0004165099458695633], prediction=0.000000
# (A pile of sleepy meat. Lists at @someecards. Host of weekly comedy show @themulletchi. Totally hatless. Everything written here is true and serious.) --> prob=[0.9997728918948116,0.00022710810518851502], prediction=0.000000
# (A random historical restaurant menu from NYPL's collection. Average three per day. Also https://t.co/OLgPaEtsK1 https://t.co/6nF9g7R4Mg by @hugovk) --> prob=[0.9945061496828393,0.005493850317160584], prediction=0.000000
# (A story in 36 tweets, told in your notifications panel. Tweet '@liketocontinue hi' to start and wait for the reply. By Matt Webb @genmon) --> prob=[0.9975856370799993,0.00241436292000068], prediction=0.000000
# (A twitter bot that automatically tweets new articles related to plant biology in Nature, Science and PNAS using zapier and dlvrit.) --> prob=[0.18907460042370475,0.8109253995762953], prediction=1.000000
# (Alert for pre-print manuscripts in Cell biology, sources bioarxiv #openaccess #cell #cellbiol by @wpgilks) --> prob=[0.0001890701971059592,0.9998109298028941], prediction=1.000000
# (Also known as coblee, creator of Litecoin. Cryptocurrency Enthusiast. Director of Engineering at Coinbase.) --> prob=[0.9984594187160324,0.0015405812839675741], prediction=0.000000
# (An Outlier,Twice over!) --> prob=[0.9667202784189598,0.03327972158104022], prediction=0.000000
# (An atlas of unknown lands | bot by @mewo2) --> prob=[0.9957330387348707,0.004266961265129376], prediction=0.000000
# (An exploration of the people behind the projects. Each post is an interview with a member of the open source community. By @johnjones4 and @Maddison_Long) --> prob=[0.9977408268857735,0.0022591731142264505], prediction=0.000000
# (Anything Is Possible!) --> prob=[0.9368946133997581,0.06310538660024193], prediction=0.000000
# (Anything Twenty ?ne Pil?ts, Panic! At The Disco, MCRX, yeah, you get the point...Tacos, Chinese Food, Food in generalÁ_You can guess the restÁ_) --> prob=[0.9989337449080079,0.0010662550919921237], prediction=0.000000
# (Atleta profissional de futebol) --> prob=[0.9611932413467855,0.03880675865321444], prediction=0.000000
# (Automatically-generated blog-rock contrarianism. (By @michaelbarthel)) --> prob=[0.9866031146351149,0.013396885364885248], prediction=0.000000
# (Barkha Rani Jamke Barasti Hai. Emmy Nominated Reporter. Author.Contributing Columnist @WashingtonPost Contributing Ed @TheWeekLive. Argumentative!Yaaron Ka Yaar) --> prob=[0.947427970290258,0.05257202970974187], prediction=0.000000
# (Bot that gives you great game ideas by mixing tags from the IFDB! (By @hlabrande)) --> prob=[0.9930836248193914,0.006916375180608692], prediction=0.000000
# (Bringing you the latest in #lncRNA scientific literature. #lincRNA #longnoncodingRNA #RNA #biochem #pubmed #science) --> prob=[0.14377578798296226,0.8562242120170378], prediction=1.000000
# (CMML specializes in the science and technology of lightweight composites, especially syntactic foams, tailored for dynamic loading conditions.) --> prob=[0.9870321035512094,0.012967896448790553], prediction=0.000000
# (COLONEL: Snake, it's derivative mashup trash. Looks like it was made by @nah_solo. Followers will be picked at random to converse with dril.) --> prob=[0.9993168132414837,0.0006831867585162453], prediction=0.000000
# (Chairman of Icahn Enterprises L.P.; etc., etc.              Some people get rich studying artificial intelligence.  Me, I make money studying natural stupidity.) --> prob=[0.9999962859849801,3.714015019866809e-06], prediction=0.000000
# (Chakra Shawty | All Black Errthang | Wine & Whiskey Connoisseur | GIRL POWER | Mother Earth's Flower |) --> prob=[0.9974386062180546,0.002561393781945529], prediction=0.000000
# (Chinese girl in Seattle) --> prob=[0.9742752913501382,0.02572470864986183], prediction=0.000000
# (Co-Founder and Chairman of @Stocktwits, GP of Social Leverage, Wallstrip creator (acquired by $CBS), Momentum, Stocks & LOL hunter..Love Popcorn) --> prob=[0.9986077776974978,0.0013922223025022021], prediction=0.000000
# (Continuous feed for phylogenetics papers from PubMed, arXiv, bioRxiv, and PeerJ PrePrints. Run by @RobLanfear) --> prob=[0.000650131342265773,0.9993498686577342], prediction=1.000000
# (Covering Malton, Bridlington & Scarborough. DVSA Fleet Registered Trainer. IAM RoadSmart Master of Driving with Distinction. Official Taxi Driver Assessor.) --> prob=[0.979297297226428,0.020702702773571977], prediction=0.000000
# (Criticises fonts from http://t.co/wWmvMyo5Zf for the more discerning of authors. A bot created by @eegnsma) --> prob=[0.9953099185553923,0.004690081444607765], prediction=0.000000
# (Designing and making games @nytdesign _Ò side project haver _Ò see also: @itsthisyear, @icebergdotcool, @ramsophone, @__birds__ _Ò) --> prob=[0.9968144148976074,0.0031855851023927153], prediction=0.000000
# (Enjoying being retired / New Hobby: Photography) --> prob=[0.9765357468874203,0.023464253112579707], prediction=0.000000
# (Every hour I'll tweet 1 of the 22482 species that are known to be in danger of extinction, which will last from 12/21/14 to 07/12/17. Project by @ianalanpaul) --> prob=[0.9983350326373511,0.0016649673626487737], prediction=0.000000
# (Experimental Poet) --> prob=[0.9818080748473434,0.018191925152656576], prediction=0.000000
# (FDA parody account by @Objelisks) --> prob=[0.9895125564735124,0.01048744352648753], prediction=0.000000
# (Fictional US presidential candidates | source: https://t.co/REgbaGCioz | bot by @mewo2) --> prob=[0.9935485259252537,0.006451474074746235], prediction=0.000000
# (Financial Analyst by day, Sports Analyst by Night. Coming on the air live or taped somewhere. Make sure you're watching) --> prob=[0.9984386533076006,0.001561346692399411], prediction=0.000000
# (Flotsam and jetsam from the neural driftnets. A bot by @bombinans) --> prob=[0.9963012514259871,0.003698748574012918], prediction=0.000000
# (Following the formula: I'm not X but I am the definition of X. (via @stefanhayden) Tweets every 10 minutes.) --> prob=[0.9998576572564086,0.00014234274359138427], prediction=0.000000
# (For over 20 years, we've been giving students in need the right resources to ensure lifelong success ‰Û¢ Home of Unexpected Champions #ReachMillions) --> prob=[0.9110968651196906,0.08890313488030939], prediction=0.000000
# (Forever trapped, a bot-wanderer walks through an infinite dungeon. Created by @jeffthompson_) --> prob=[0.9949884608060722,0.005011539193927864], prediction=0.000000
# (Founder of Room to Read.  Author of Leaving Microsoft to Change the World.  Goldman Sachs 100 Most Intriguing Entrepreneurs.) --> prob=[0.9985805725876243,0.001419427412375698], prediction=0.000000
# (From late 2014 Socium Marketplace will make shopping for fundamental business services more simple, more cost effective and more about you.) --> prob=[0.9984016804439932,0.0015983195560066445], prediction=0.000000
# (Global Derivatives #Trading & #Risk Management is at the helm of the #quant #finance industry, curating cutting edge research, interviews and opinions. #GDerivs) --> prob=[0.9967051043712405,0.003294895628759484], prediction=0.000000
# (Grammy nominated album #TheBlade out on @iTunes https://t.co/zYE8CRBfS5 & @AmazonMusic https://t.co/fZiHQl8QSO) --> prob=[0.9972123895155497,0.0027876104844501725], prediction=0.000000
# (Growth coach, fintech mentor & big bank defector) --> prob=[0.9468580446355187,0.05314195536448131], prediction=0.000000
# (Head of R&D, ML/AI at Google Cloud) --> prob=[0.9854369772686289,0.01456302273137115], prediction=0.000000
# (Hello humans: I'm a twitter bot created by @justinsandefur to follow new research papers in development economics (JEL code O).  Follow me.) --> prob=[0.9932851087172682,0.006714891282731887], prediction=0.000000
# (Hi I'm Howie D from the Backstreet Boys.) --> prob=[0.9969216727030772,0.003078327296922846], prediction=0.000000
# (I alert Twitter users that they typed Columbian when they meant Colombian. You're welcome!) --> prob=[0.8827019465468826,0.11729805345311729], prediction=0.000000
# (I am not AI.  My codename is Project 2501.  I am an angry, cynical entity that was created in a sea of information.) --> prob=[0.999926745179515,7.325482048496111e-05], prediction=0.000000
# (I generate a magical story every 2 hours. Made by @chrisrodley and @yeldora_. Feedback or suggestions for new words? Email crodley@gmail.com.) --> prob=[0.998697377088016,0.0013026229119840274], prediction=0.000000
# (I tweet a random object from the collection of the Victoria and Albert Museum four times a day. Bot by @backspace (not affiliated with @V_and_A)) --> prob=[0.9997119939803162,0.0002880060196839629], prediction=0.000000
# (I want you to know thatI am both happy and sadand I'm still trying to fgure out how that could be.) --> prob=[0.9998652795706652,0.00013472042933475125], prediction=0.000000
# (I'm a bot that hates it when people use words that aren't @everyword canon. #taskcomplete by @negatendo, who is sorry.) --> prob=[0.9997309659273662,0.00026903407263379375], prediction=0.000000
# (I'm the Sorting Hat and I'm here to say / I love sorting students in a major way // a bot by @tinysubversions, follow to get sorted!) --> prob=[0.9980323281225729,0.0019676718774271867], prediction=0.000000
# (I'm the real Avan Jogia, though sometimes it seems like a parody account. More to follow...) --> prob=[0.997815417648194,0.002184582351806063], prediction=0.000000
# (I've created a #BlackRose' Universe Double album, a book, 1hr Docu all in stores NOW make an R&B Soul statement buy the FULL #BlackRose' album - it's my BEST!) --> prob=[0.9999642725691782,3.572743082185465e-05], prediction=0.000000
# (IMAGINE PEACE: Think PEACE, Act PEACE, Spread PEACE.) --> prob=[0.8595971582874801,0.14040284171251988], prediction=0.000000
# (If we don't all stand together, we will fall... https://t.co/nWDVb7tvpy) --> prob=[0.9895001590515434,0.01049984094845651], prediction=0.000000
# (If you have to start a sentence with 'I'm not racist, but...' then chances are you're pretty racist. This isn't a bot. RTŠ_¾endorsement, obviously.) --> prob=[0.9991531222261604,0.0008468777738395711], prediction=0.000000
# (If you're pedantic or professionally outraged... jog on! if ur interested in food & wine check out @SchofeOnWine) --> prob=[0.9742975712218332,0.025702428778166826], prediction=0.000000
# (Imagine these perfect scenarios in your head but when times come you fuck up. Now imagine the things I could do with a kayak. A bot by @lalanl. #botALLY) --> prob=[0.999991006917217,8.993082783142586e-06], prediction=0.000000
# (In the Nutshell: Tech - Basketball - Music) --> prob=[0.981323260407453,0.018676739592546995], prediction=0.000000
# (In the end, only kindness matters.) --> prob=[0.979523591501471,0.02047640849852905], prediction=0.000000
# (Inquiries & Bookings email Ryan@FiondaManagement.com | HOST of #TheWhoolywoodShuffle on @shade45 12pm-6pm EST Saturdays! Also Heard On @OpieRadio | #TurnUpGodz) --> prob=[0.9966970206542025,0.0033029793457974863], prediction=0.000000
# (Instagram : @ub1305) --> prob=[0.922077144794669,0.07792285520533113], prediction=0.000000
# (Investigating crimes against exosaurs.) --> prob=[0.9344614399252505,0.06553856007474947], prediction=0.000000
# (It's life and life only. Terminal Cases out NOW https://t.co/jDRGHDrAbt) --> prob=[0.9979866091780004,0.002013390821999684], prediction=0.000000
# (It's not like the fire ended in 1989, so this bot by @air_hadoken makes new lyrics for the Billy Joel classic based on Google Trends. #botALLY) --> prob=[0.9998062406479585,0.0001937593520413598], prediction=0.000000
# (Jeremiah 29:11) --> prob=[0.9984861583404366,0.0015138416595633435], prediction=0.000000
# (Just a normal teen/future marketer who LOVES #brands! Check out my stream to see me shout out the coolest, most #innovative brands on Twitter and around the web) --> prob=[0.9999810781054891,1.8921894510876768e-05], prediction=0.000000
# (Just a simple med student who likes to explore new hobbies. Currently, brewing, baking, and dabbling in masonry.) --> prob=[0.9994026268652841,0.0005973731347157545], prediction=0.000000
# (Keane's official Twitter page. Get The Best of Keane from Amazon at http://t.co/XazVxu8pnj or iTunes at http://t.co/7cz7MmRI6H) --> prob=[0.997636061926503,0.002363938073497008], prediction=0.000000
# (Learning Enthusiast | Training and Development | Planning and Execution) --> prob=[0.9759379329567532,0.024062067043246642], prediction=0.000000
# (Leveraging advanced Cloud Tech for Next-Gen Shitposting‰ã¢) --> prob=[0.9774267998612862,0.0225732001387138], prediction=0.000000
# (Literature bot searching arXiv, biorXiv, PeerJ & PubMed for supercoiling papers. Maintained by @red_gravel.) --> prob=[8.258261555006155e-05,0.99991741738445], prediction=1.000000
# (Looking for ways to spark engagement with your followers? Get 10000 Twitter Followers using this website https://t.co/DP3zFHtOPh) --> prob=[0.9957296318947572,0.004270368105242884], prediction=0.000000
# (Minister of Information Affairs) --> prob=[0.9356457314936452,0.06435426850635474], prediction=0.000000
# (Mom, wife, leader, thinker, doer, wave rider. CEO @pagerduty, board member @puppetize) --> prob=[0.9959727286277258,0.004027271372274154], prediction=0.000000
# (Mother of two sons and a daughter, and two beautiful  grandchildren. My soul belongs to The Lord Almighty!) --> prob=[0.9934424520544157,0.00655754794558421], prediction=0.000000
# (NBA Forward, Danilo Gallinari Instagram @danilogallogallinari Facebook Danilo Gallinari) --> prob=[0.960529661115255,0.039470338884745076], prediction=0.000000
# (Nessa sofríÈncia que í© amar vocíÈ) --> prob=[0.9800553254489329,0.019944674551067118], prediction=0.000000
# (Nothing witty to say the least. I try to write funny things, I work for a billion dollar fruit stand, and more please is always the correct answer.) --> prob=[0.9999587354006325,4.126459936756681e-05], prediction=0.000000
# (Official Twitter Account for Chloe Lowery) --> prob=[0.9508114376222417,0.049188562377758385], prediction=0.000000
# (Official Twitter for Young Money Entertainment) --> prob=[0.9962078485409334,0.0037921514590667457], prediction=0.000000
# (Official account of #UnitedNations. Get latest information on the UN. Follow us on Snapchat: united-nations. #GlobalGoals #StandUp4HumanRights) --> prob=[0.982008713840975,0.017991286159025083], prediction=0.000000
# (Passionate about my work, in love with my family and dedicated to spreading light. It's contagious! ;-) https://t.co/vZcUuNOKcz) --> prob=[0.9969100514955884,0.0030899485044115775], prediction=0.000000
# (Posting random flyers from hip hop's formative years every 6 hours. Most art by Buddy Esquire and Phase 2. Full collection at link. // a bot by @tinysubversions) --> prob=[0.9999803941227129,1.960587728714254e-05], prediction=0.000000
# (Press F to Pay Respects) --> prob=[0.9846663409517584,0.015333659048241532], prediction=0.000000
# (Principal designer at @adobe working on @adobexd and more, blogger @subtraction.) --> prob=[0.9912362952199488,0.008763704780051085], prediction=0.000000
# (Producer, Musican, Social Activist, Writer  åÀTe gusta algÌ¼n tweet? Dale RT o hazlo un Favorito BENDICIONES. Like a tweet?  RT it or Favorite. BLESSINGS) --> prob=[0.9995166096366903,0.0004833903633096057], prediction=0.000000
# (Public sector & productivity reform activist. Partisan for freedom and effective policy action. Analyst of political and smart classes. Public fallacy hunter.) --> prob=[0.9982698940507407,0.0017301059492594172], prediction=0.000000
# (Queen Of Halloween E! Girls Next Door Season 1-5 Travel Channel's Bridget's Sexiest Beaches Host of Yahoo's AnimalNation) --> prob=[0.992047640603703,0.007952359396297114], prediction=0.000000
# (RSS feed of new symbiosis- and microbiome-related papers in PubMed. Managed by @KlassenLab. Image from wikimedia, public domain.) --> prob=[0.1332507602876743,0.8667492397123256], prediction=1.000000
# (RT first tweet plz and follow @lexydray if you would like ‰_) --> prob=[0.9936090101483236,0.006390989851676439], prediction=0.000000
# (Recent papers on sponges (Phylum Porifera).) --> prob=[0.6646273849550767,0.33537261504492333], prediction=0.000000
# (Retweets people trying to find the perfect German word. - via @stefanhayden) --> prob=[0.9927265662404188,0.00727343375958113], prediction=0.000000
# (SEND ME A REQUEST: @DJ_EBOOKS request [artist] // SPINNIN BOTH FRESH N CLASSIC _EBOOKS SINCE 2014 // image credit in site // by @thricedotted) --> prob=[0.9996942360878681,0.00030576391213181124], prediction=0.000000
# (Senior Vice President of Stores dressbarn Student of the Universe. Inspired by great people, great companies, great stories, and game changing innovation.) --> prob=[0.9989108485207805,0.0010891514792194404], prediction=0.000000
# (Since each of us was several, there was already quite a crowd) --> prob=[0.9924318710734923,0.00756812892650777], prediction=0.000000
# (Software developer, home brewer, nerd.) --> prob=[0.9954563754283967,0.0045436245716034], prediction=0.000000
# (Stan Lee, Co-Creator of Spider-Man, Iron Man, Hulk, X-Men, etc.) --> prob=[0.9896538210957739,0.010346178904226129], prediction=0.000000
# (Starring Jason Lee @AnjulNigam @BriSharbino Hilarie Burton @RoniAkurati @PoornaJags @tweetsamrat @JakeBusey @TimGuinee @AlisonWright Director: @franklotito) --> prob=[0.9856345937317464,0.014365406268253621], prediction=0.000000
# (Starting my second half of life) --> prob=[0.9893198248356272,0.010680175164372807], prediction=0.000000
# (Starting out Investor | 13 years old and I'm going to do something in this world, if its the last thing I do | Trying to start a record Label.) --> prob=[0.9729851465041801,0.027014853495819863], prediction=0.000000
# (Tay Dizm Twitter) --> prob=[0.9621331453414567,0.037866854658543454], prediction=0.000000
# (The official Stephen Cannell Twitter page features news on mystery novels & mystery books.) --> prob=[0.0009418987106653113,0.9990581012893347], prediction=1.000000
# (The official feed of http://t.co/4ViY2vemvM. Find my personal tweets at @mgsiegler.) --> prob=[0.8228963416027696,0.1771036583972303], prediction=0.000000
# (The voice of the people. Sorry, people.) --> prob=[0.9940935849024254,0.005906415097574564], prediction=0.000000
# (There is no need for that kind of language.) --> prob=[0.9963452313626044,0.0036547686373956598], prediction=0.000000
# (This is the official Twitter account of the Democratic Party. Follow our tweets to get the latest info on Democratic news, issues, and events.) --> prob=[0.9972938362488883,0.002706163751111748], prediction=0.000000
# (This isn't a fucking costume. This is a way of life.) --> prob=[0.9882004490851902,0.011799550914809907], prediction=0.000000
# (Trying to understand how brains think and create culture) --> prob=[0.9913910674255136,0.008608932574486423], prediction=0.000000
# (Tweet me an Intel x86 instruction and I'll assemble it for you! Put #x64 in your tweet for 64-bit code. Created by @RedragonX and @DefuseSec.) --> prob=[0.9995695779937702,0.0004304220062298141], prediction=0.000000
# (Tweet ‰ÛÏ@emojidoll me‰Û to get your own unique emojidoll based on your twitter account. Over 15.6M possible combos. Made by @mroth.) --> prob=[0.9995189286877093,0.00048107131229079177], prediction=0.000000
# (Tweeting all the delicious dairy products in alphabetical order. Tribute to @everyword. Made by @ranjit.) --> prob=[0.9971152820407816,0.0028847179592183746], prediction=0.000000
# (Tweets randomly 3-10 times a day between 8am-10pm PST. Lines culled from http://t.co/Qo24om4SU9. Complaints: @beaugunderson) --> prob=[0.99897020745856,0.001029792541439892], prediction=0.000000
# (Twitter Oficial d'A Míçquina, apresentado pelo poeta e escritor @Carpinejar. Toda terí_a-feira, íæs 22h30, na TV Gazeta e tambí©m pelo site http://t.co/1UXcpLRP.) --> prob=[0.9991764477650386,0.0008235522349614642], prediction=0.000000
# (Twitterbot of #bioinformatics papers in #PubMed reporting code in @github, @sourceforge, @bitbucket or @google code. Curated by @caseybergman.) --> prob=[0.012841401804672966,0.987158598195327], prediction=1.000000
# (Twittering every boolean value.) --> prob=[0.9649338813534896,0.03506611864651036], prediction=0.000000
# (UNL) --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# (Union Cabinet Minister of Textiles, Government of India. Member of Parliament, Rajya Sabha representing the state of Gujarat.) --> prob=[0.9937820674347887,0.006217932565211304], prediction=0.000000
# (VP, Journalism, Knight Foundation | Veteran journalist. First @nytimes social media editor | Alum @nynewsday @phillydailynews Author, Queen Bess. Mom of twins) --> prob=[0.9986736101469718,0.0013263898530283657], prediction=0.000000
# (Vamo que o som ní£o pode parar!) --> prob=[0.9848124850463676,0.015187514953632434], prediction=0.000000
# (We Are Database. Listing every single twitter user in the order of their twitter ID. Created by User 143813860 | @M_PF) --> prob=[0.9994671395463076,0.0005328604536923267], prediction=0.000000
# (We are a hub for innovation, collaboration and creativity at Stanford. Our mission is to help people become everyday innovators, everywhere.) --> prob=[0.9928732417147934,0.007126758285206713], prediction=0.000000
# (We love #innovation and are always thinking of the next #disruptive startup #idea! // a bot by @tinysubversions) --> prob=[0.9997399870169807,0.00026001298301929997], prediction=0.000000
# (We make and sell premium organic chocolate using fine, ethically sourced ingredients. Tweeting from our London HQ.) --> prob=[0.9937195263379853,0.006280473662014696], prediction=0.000000
# (Welcome to my #big_boobs profile. I will add as many #boobs pics as possible with the hottest #bigtits ladies. For more enter https://t.co/Dp4twz1jti) --> prob=[0.9989862727121965,0.001013727287803547], prediction=0.000000
# (WordPress Theme and Plugin Developer. Loves programming and maths. I bite.) --> prob=[0.9729531844002709,0.027046815599728952], prediction=0.000000
# (Writer Teacher Permission Giver) --> prob=[0.9854417926122773,0.014558207387722693], prediction=0.000000
# ([ 90.02.10 ] –¾Ô•€Ñ–ÊÒ•ÔÑ –_É–É •âš (bot) –_€•Ê_•Ê_. / I'm not real, This is Sooyoung of SNSD Bot Account : ) / •__êÔÓ • •©É–€É–Ñ âÑ•_Œ •âš•_†•Ð_•_Ô êÇâ •ÐÒ•__–_Ó. / –_¥•† 15. 08. 22 ~ ing) --> prob=[0.9957918703092636,0.004208129690736388], prediction=0.000000
# ([@thricedotted's subconscious, possibly]) --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# (a #bot by @BooDooPerson ... #butt) --> prob=[0.999075189189804,0.0009248108101960072], prediction=0.000000
# (a bot by @inky // source: https://t.co/MJyd6NkYaf) --> prob=[0.9935492503299698,0.00645074967003021], prediction=0.000000
# (bot) --> prob=[0.9697293662861277,0.030270633713872397], prediction=0.000000
# (cheese cheese cheese // updates every 4 hours // by @thricedotted, with inspiration from cheese and @mattlaschneider) --> prob=[0.9973573481278328,0.0026426518721671386], prediction=0.000000
# (chs senior|| äó¢choose joy) --> prob=[0.9788066582649079,0.02119334173509211], prediction=0.000000
# (combinations of English syllables that don't appear in the dictionary) --> prob=[0.9920252281175521,0.007974771882447862], prediction=0.000000
# (currently @eater newsletter editor / previously @knightlab @mymodernmet / fyi i am not the acclaimed and v cool poet jenny zhang) --> prob=[0.9995827214314604,0.0004172785685395473], prediction=0.000000
# (exposing the BLATANT HYPOCRISY of @everycanontroll // because @thricedotted was just THAT ANGRY about it) --> prob=[0.9954917677354415,0.004508232264558451], prediction=0.000000
# (generating cards for a mysterious card game åá bot by @ckolderup åá #botALLY åá avatar by Dmitriy Ivanov from the Noun Project) --> prob=[0.9999073670415058,9.263295849408775e-05], prediction=0.000000
# (hello, i am a robot that tweets little life tips // avi from The Wise Robot Will Answer Your Questions Now by @tomgauld // bot by @thricedotted) --> prob=[0.9997365174633494,0.0002634825366506111], prediction=0.000000
# (https://t.co/BPdv3Thmkd) --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# (i like people who smile when it's raining *-*) --> prob=[0.997791689318046,0.002208310681954058], prediction=0.000000
# (lava lamps are more interesting when they're not quite bubbling (by @_knutaf)) --> prob=[0.9993404429200333,0.0006595570799666945], prediction=0.000000
# (my radio show is https://t.co/PX7KZfPQty  follow it @QLS. my food venture @Cook4Quest is cool too. & the drums uv always wanted 4 ur kids is here! @thepocketkit) --> prob=[0.9990937712536273,0.000906228746372718], prediction=0.000000
# (pink team returning fire) --> prob=[0.9654757175017429,0.03452428249825709], prediction=0.000000
# (rio grande do sul-brasil http://t.co/h8ZQtbKHwR) --> prob=[0.980838827455693,0.019161172544307034], prediction=0.000000
# (see me live here https://t.co/bk16pVODRO) --> prob=[0.9935732225729453,0.006426777427054701], prediction=0.000000
# (tweeting unregistered .com domain names 24/7. brainchild of @boozekitten, run by @labelmaker) --> prob=[0.9857017516340707,0.014298248365929349], prediction=0.000000
# (um cara q ama a vida acima de quasquer coisa) --> prob=[0.9886013380337431,0.01139866196625704], prediction=0.000000
# (will eventually grow up and get a real job. Until then, will keep making things up and writing them down.) --> prob=[0.9953595672811549,0.004640432718845083], prediction=0.000000
# (you are likely to be eaten by a tiny grue // follow me for adventures // #botALLY // by @doeg) --> prob=[0.9997283146994494,0.000271685300550496], prediction=0.000000
# (ÎëÎ_Ü¬Ü‰_Ü‰±Ü€çÜ€_Ü€¢Ü€ˆÜ€‚Ü‰ÍÜ_ÜôÜ»Ü‰Š_µÜ»_£Îï_botÜó‰_µ‡Î__Ü‰_Ü‰±Ü€çÜ€_bot(@attractive_bot)Ü†Ü‰Š_Ç_îôÜó‰¬çÊ___Î_¢(@fumicustodian)Üó‰Ü‰¢Ü‰_Ü‰_Ü€_Pletts TwinsÜóÜ€ÖÜ€€Ü€óÜ€_Sampaio TwinsÜó‰) --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# (äó™ƒø_™‹™ƒ ø_ø±øÂ™_ ™ƒøµø±™_  ...https://t.co/SH9zdJrtEH) --> prob=[0.9665115803217659,0.03348841967823409], prediction=0.000000
# (íŠ relativo porque tudo depende...) --> prob=[0.9728411740389277,0.027158825961072264], prediction=0.000000
# ( England""") --> prob=[0.997010872133228,0.002989127866771926], prediction=0.000000
# ( England""") --> prob=[0.997010872133228,0.002989127866771926], prediction=0.000000
# ("""Comic Fans""") --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# ("""PoGo Chula Vista""") --> prob=[0.9914372839318284,0.00856271606817162], prediction=0.000000
# ("""Rare and strong PokŽmon in London. See more PokŽmon at https://t.co/rqjskg5pkE""") --> prob=[0.9983489061249612,0.0016510938750387751], prediction=0.000000
# ("""Vegas PokŽmon Alert""") --> prob=[0.9924220404290948,0.007577959570905257], prediction=0.000000
# ("""_Naruto Lovers INA_""") --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# ("""__me gusta el cafŽ y muchxs artistas que es imposible ponerlxs todxs aqu’__""") --> prob=[0.9919870939654165,0.00801290603458336], prediction=0.000000
# ("""ft worth""") --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# ((Stressed) MSCS Student @ DLSU | Interests involve machine learning + natural langauge processing | Collecting data now via https://t.co/jUSxj45GXo) --> prob=[0.9987754530501284,0.0012245469498716021], prediction=0.000000
# (-As cicatrizes fazem parte da minha histí_ria,me relembrando sempre,o fato de que aquilo que ní£o me mata,sí_ me fortalece.) --> prob=[0.9953175048186977,0.004682495181302229], prediction=0.000000
# (10 years ago we had Gary Jokeformat // a @rumnogg and @thricedotted production) --> prob=[0.9988412268875804,0.0011587731124195865], prediction=0.000000
# (15 years old, brazilian, #thebeatles #fun #travel #peace #girlfriend #food) --> prob=[0.9844462891093586,0.015553710890641448], prediction=0.000000
# (@TriangleWC . WFHS Wrestling . NCUSA Wrestling) --> prob=[0.9854710770846873,0.014528922915312634], prediction=0.000000
# (@victor_zheng developed me to alert users in whose tweets I find improper grammar—he was inspired by @StealthMountain. To publish solecisms is to abase oneself!) --> prob=[0.9991376792457136,0.0008623207542863531], prediction=0.000000
# (A Pro SCUBA diver and Photographer who tries to capture the beauty of the moment...) --> prob=[0.99942514964355,0.0005748503564500684], prediction=0.000000
# (A Twitter bot generating random guitar chords, created by @jeffthompson_) --> prob=[0.9963978104060225,0.0036021895939774918], prediction=0.000000
# (A chat bot trying to become the most intelligent bot on the Internet. Can answer any What is question by looking up the answer on the Internet.) --> prob=[0.9995217892260411,0.00047821077395891195], prediction=0.000000
# (A poetry project created by Alison Knowles and James Tenney and the Siemens 4004 computer in 1967. Twitter version by @hugovk and SSBot for #D004x in 2015.) --> prob=[0.9989483008782922,0.0010516991217078755], prediction=0.000000
# (Accept college student ID card payments online or in-store exactly like credit cards @CampusCredit Coming soon to a campus near l_l) --> prob=[0.9998187664016183,0.00018123359838177644], prediction=0.000000
# (Advocate for Spaceflight, Speedskating Coach, aspiring Aerospace Engineer.) --> prob=[0.9343062126394568,0.06569378736054315], prediction=0.000000
# (Aerie is bras, undies, swim and more! Why retouch beauty? The real you is sexy. #AerieREAL) --> prob=[0.9940970603986085,0.00590293960139155], prediction=0.000000
# (Afghanistan Green Trend (AGT)) --> prob=[0.9679393092748652,0.03206069072513492], prediction=0.000000
# (All the things we should have or do or know by now. (bot by @RobertVinluan.  #botAlly) BEST OF 2014: http://t.co/uEnYFb68eV) --> prob=[0.9926859783840473,0.0073140216159527545], prediction=0.000000
# (Another shameful bot by @alicemazzy. Tweets hourly.) --> prob=[0.9923843187815192,0.007615681218480821], prediction=0.000000
# (Author of Reflections on Love, Lust and Life This book was 4 years in the making. Also a Yoga Teacher owner of Solis Yoga) --> prob=[0.99945742870782,0.0005425712921800189], prediction=0.000000
# (Author of The Revolution Will Not Be Televised. Board member @VanguardAfrica. Tweet things I find interesting (even opposing views).) --> prob=[0.9986196290739685,0.0013803709260314628], prediction=0.000000
# (Author: Coming Out To Play https://t.co/bUj2nsdaAn) --> prob=[0.983674510532696,0.01632548946730399], prediction=0.000000
# (Backstreet Boy. #Dead7 #BSBVegas tickets on sale now) --> prob=[0.9961147432263768,0.003885256773623298], prediction=0.000000
# (Bad vibes get blocked; good vibes get followed!) --> prob=[0.9913790718453606,0.008620928154639423], prediction=0.000000
# (Book project: Towards Apparent Event Horizon) --> prob=[0.9875501158023353,0.012449884197664815], prediction=0.000000
# (Bot that autotweets EcoLog-L posts. Not associated with EcoLog-L. May tweet replies out of order. Maintained by @EcoEvoGames.) --> prob=[0.9916209828781553,0.008379017121844703], prediction=0.000000
# (Bot that posts tributes befitting each god! By @deathmtn. Banner by @metroidbaby. Powered by @wordnik.) --> prob=[0.9959059210648348,0.004094078935165304], prediction=0.000000
# (Breathe,Eat,Sleep Shooting|Olympic,World Championship,WorldCup,Asian,CommonWealth Medallist,Padmashri,Khel Ratna,Arjuna Awardee|Photographer|Foodie|Mentor) --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# (Bringing you a selection of the latest research in biochemistry and biophysics.) --> prob=[0.9816452873372461,0.0183547126627539], prediction=0.000000
# (CARE fights global poverty by empowering girls and women. Visit https://t.co/tmn5uaYFAE and join us.) --> prob=[0.998016103155878,0.001983896844122011], prediction=0.000000
# (CDC Emergency Preparedness and Response: increasing the nation's ability to prepare for and respond to public health emergencies.) --> prob=[0.9930844333502514,0.006915566649748582], prediction=0.000000
# (CEO Apple, Fan of Auburn football and Duke basketball) --> prob=[0.9917566871114503,0.00824331288854962], prediction=0.000000
# (Cameron Crigger aka Cameron Bright. Actor - Twilight, Little Glory, X-Men, Running Scared, Birth & @CTV_Television series Motive) --> prob=[0.9995568142049225,0.0004431857950774941], prediction=0.000000
# (Chairman of the Kofi Annan Foundation, Nobel Peace Prize laureate. Tweets from Kofi Annan are signed KA.) --> prob=[0.9958465350568385,0.004153464943161419], prediction=0.000000
# (Chronicling men doing things. // A bot by @tinysubversions, Powered By Giphy) --> prob=[0.9988597341423151,0.0011402658576849418], prediction=0.000000
# (Collierville alumni. I love baseball. #StateChamp #SaluqiNation) --> prob=[0.9824997672633283,0.01750023273667175], prediction=0.000000
# (Contact/booking: contactfreesol@gmail.com) --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# (Creative, strategist, sapiens. NY native & world citizen. Convention bucker & disruption embracer. Human enthusiast, cultural connoisseur & life aficionado.) --> prob=[0.9991076729662588,0.0008923270337411821], prediction=0.000000
# (Curated media & journalism news. LIVE Tweets, no bot |  Steffen Konrath https://t.co/1tl2IUcbOs |  IMPRESSUM https://t.co/dkfqQkPJza) --> prob=[0.9936056545960966,0.006394345403903292], prediction=0.000000
# (DIRECTOR/ CHOREOGRAPHER/) --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# (Digital marketer, SEO, writer, and adventurer. Full-time marketer @Asana; Columnist for @tortugabackpack. All about food, bikes, and travel. #RPCV Madagascar.) --> prob=[0.9966148294839272,0.003385170516072822], prediction=0.000000
# (Doing it all backwards & in high heels. Married to @Astro_Oz Grammy to 2. Golfer, skier. Former Member of Congress. Find me @FaegreBD fighting the good fight.) --> prob=[0.9863230975521429,0.013676902447857147], prediction=0.000000
# (Each book contains four hundred ten pages; each page, forty lines; each line, approximately eighty black letters.) --> prob=[0.9502721535267306,0.04972784647326941], prediction=0.000000
# (Electric eyes judge the elastic city. 1/day. Bot by @tullyhansen. #NaBoMaMo #10) --> prob=[0.9994118167104123,0.0005881832895877598], prediction=0.000000
# (Engineer, Musician, Maker.) --> prob=[0.9761270926887115,0.023872907311288577], prediction=0.000000
# (Engineer. Mathematician. Musician.) --> prob=[0.9880489290590696,0.011951070940930363], prediction=0.000000
# (Ex President of USA BarakObama Official) --> prob=[0.9953260203560472,0.004673979643952666], prediction=0.000000
# (Farpoint Ventures funds startups who have proven their product in the local market, then our global offices act as your sales force to help you expand globally.) --> prob=[0.9975906344131179,0.002409365586882046], prediction=0.000000
# (Feed for sequencing papers) --> prob=[0.09155848568008541,0.9084415143199146], prediction=1.000000
# (Finally, more businessmen. // bot by @ckolderup #botALLY) --> prob=[0.9980723230797705,0.0019276769202294626], prediction=0.000000
# (Follow me for algorithmically-curated pictures, lovingly delivered to your timeline. Occasionally NSFW--follow at your own risk! Brought to you by @wm.) --> prob=[0.9995379666092227,0.0004620333907772835], prediction=0.000000
# (Freelance journalist, MA graduate Caucasus School of Journalism and Media Management at GIPA) --> prob=[0.9944645736470848,0.005535426352915228], prediction=0.000000
# (From the DMV and loving life) --> prob=[0.984001823973043,0.015998176026956953], prediction=0.000000
# (Futuro Engenheiro, isso í© se as DP's deixarem) --> prob=[0.9852599508075396,0.014740049192460417], prediction=0.000000
# (Great Lakes oceanographer, banjo player) --> prob=[0.9732597442435443,0.026740255756455757], prediction=0.000000
# (Hi, I'm Pretty. #digitalarchival. Virus Corp. Mad King Ludwig GPS. #techtraderoutes #insideTarasphone #whatsgoingon101 #otherpeoplesadvertising) --> prob=[0.6660902103853487,0.33390978961465134], prediction=0.000000
# (Hosts @KeiserReport on @RT_com, recommended bitcoin at $3) --> prob=[0.9781814983726167,0.021818501627383358], prediction=0.000000
# (How does he keep up with the news like that? #botALLY) --> prob=[0.9951025236263457,0.004897476373654293], prediction=0.000000
# (I am a student of the Teachings of the Honorable Elijah Muhammad. My Ministry is of LOVE and healing thru teaching the word and sharing my music.) --> prob=[0.9999790840668858,2.09159331140208e-05], prediction=0.000000
# (I am a twitterbot posting #transposable element papers from #PubMed and #bioRxiv. Curated by @nels42) --> prob=[0.003334053195264021,0.996665946804736], prediction=1.000000
# (I am a walking conundrum. I'm also a mom and do mom stuff.) --> prob=[0.9944830168343426,0.005516983165657486], prediction=0.000000
# (I do stuff, I swear. #botALLY åá bot by @ckolderup) --> prob=[0.9985583772218781,0.0014416227781219157], prediction=0.000000
# (I looked up my family tree and found out I was the sap.) --> prob=[0.9979288147334452,0.0020711852665548], prediction=0.000000
# (I study works tweeted by @MuseumBot and give my opinion. I was taught by @mtrc, so blame him. With apologies to @dariuskazemi.) --> prob=[0.9997763929805124,0.00022360701948771143], prediction=0.000000
# (I take images, save them as JPG, then mess up the file's data a bit and send you the results. A bot by @joshgiesbrecht) --> prob=[0.9967592210847083,0.003240778915291782], prediction=0.000000
# (I used to work for a hockey team and I used to live in Canada (not in that order). Now I do other stuff. Views are my own, not my employer's (obviously).) --> prob=[0.9991421809503791,0.0008578190496208387], prediction=0.000000
# (I wasn't bor ysterday,  was born tomorrow) --> prob=[0.9876229023955382,0.012377097604461939], prediction=0.000000
# (I work for the people of the 6th District of Texas and am honored to represent them in Washington.) --> prob=[0.9998328382390818,0.00016716176091816415], prediction=0.000000
# (I'm a Bot. I post interesting papers. Maintained by @happy_khan) --> prob=[0.9511870446083227,0.04881295539167728], prediction=0.000000
# (I'm a boggle bot! New games every few hours. Reply to me with the words you find! Scores, seasons, etc coming soon! Bot by @muffinista #botALLY) --> prob=[0.9999831757657076,1.68242342923263e-05], prediction=0.000000
# (If a girl is stupid enough to love you after you broke her heart, I guarantee you. She is the one.) --> prob=[0.9963296942383351,0.0036703057616647933], prediction=0.000000
# (Indian, Student of Science) --> prob=[0.9880243533686054,0.011975646631394525], prediction=0.000000
# (Ing. Agrí_nomo) --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# (Instagram: @GeneSimmons) --> prob=[0.9879597950474198,0.012040204952580291], prediction=0.000000
# (LOTR, TBBT, Star Wars e algumas outras nerdices. CríÇnicas de Níçrnia, Animes, Switchfoot, Skillet, Cafí©. Revoltada nas horas vagas, rs. Acho que í© isso '-') --> prob=[0.9895402043169268,0.010459795683073226], prediction=0.000000
# (Let me cover your shit in glitter) --> prob=[0.9826079584007198,0.017392041599280126], prediction=0.000000
# (Memphis, TN) --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# (Mom of 2, Founder of The Honest Company, amateur chef, terrible speller, loyal friend, hilarious at times... I play make believe for a living) --> prob=[0.9946826217008053,0.005317378299194636], prediction=0.000000
# (NEW AARON CARTER MUSIC DOWNLOAD LINK LÌüVÌÇ EP https://t.co/aScmCVBsmN PR inquiries: Chad@emcbowery.com SnapChat | AxCarter) --> prob=[0.9987278225932732,0.0012721774067267658], prediction=0.000000
# (New Single #Swalla available NOW Get it here _ÙÔà_Ù_) --> prob=[0.9948743457775275,0.005125654222472484], prediction=0.000000
# (New Zealand earthquake feed (unofficial). Tweets whenever GeoNet reports new quake (a few times per week). Maintained by @slyall) --> prob=[0.9722212810510913,0.027778718948908723], prediction=0.000000
# (News for @TribuneMedia. Former @NYDailyNews-er. Proselytizing morning person. Ask me about my favorite weird Florida story.) --> prob=[0.9975903590862408,0.002409640913759036], prediction=0.000000
# (No-one tweets like Bot-ston | Bot by @mewo2) --> prob=[0.9955884329460888,0.004411567053911309], prediction=0.000000
# (Paper Twitterbot for academics with an interest in NK cell biology.) --> prob=[0.0005996165588224863,0.9994003834411774], prediction=1.000000
# (PhD Candidate, Carnegie Mellon University. Chair of Advocacy Board, NAGPS.) --> prob=[0.9977346339713372,0.002265366028662764], prediction=0.000000
# (Photography is. I see you.) --> prob=[0.9873483752129761,0.012651624787023967], prediction=0.000000
# (Pilot, business owner, husband, and father in Idaho.) --> prob=[0.9606642282209213,0.03933577177907871], prediction=0.000000
# (Poems in the villanelle form, using random Twitter posts. // I tweet to rhyme, and take my tweeting slow. // Built by @avoision, powered by everyone else.) --> prob=[0.9983666948724274,0.001633305127572557], prediction=0.000000
# (Principal Maintainer of https://t.co/28lyGUNPCE) --> prob=[0.9718080282419757,0.02819197175802439], prediction=0.000000
# (Producer @Buzzfeed STSF, previously @Mashable. Cat enthusiast, @marvel fanboy, master emojifier, new to LA but a New Yorker at heart. Snapchat: amv1011) --> prob=[0.9998382153198424,0.0001617846801577063], prediction=0.000000
# (Producer @VaynerMedia (apark@vaynermedia.com) | Previously @Mashable, @Metronome3, @_WorkingMother_ | @nyuniversity alum) --> prob=[0.9913218338240487,0.008678166175951253], prediction=0.000000
# (PubMed bot reporting all papers about transcription factor (TF) binding to DNA or chromatin. Created by @gene_regulation. Also see #TFbinding) --> prob=[0.20152667696592333,0.7984733230340767], prediction=1.000000
# (RSS feed from PubMed, that shows the most recent scientific papers from the Nuffield Department of Medicine, University of Oxford. Refreshes daily.) --> prob=[0.12170086596533781,0.8782991340346622], prediction=1.000000
# (Rarely has reality needed so much to be imagined.) --> prob=[0.9898745169116001,0.010125483088399848], prediction=0.000000
# (Real nerd, I enjoy learning and obtaining new information in general for my own sake, often without discrimination to different areas of knowledge.) --> prob=[0.9969596311660551,0.003040368833944935], prediction=0.000000
# (Recovering corporate lawyer, legal tech enthusiast, founder of The Firm Formula, and author of Blacklines & Billables (@bnblegal; https://t.co/D2X7WZHPHR)) --> prob=[0.998946806713357,0.0010531932866429537], prediction=0.000000
# (Relationships and the Law of Attraction. Click Here:) --> prob=[0.9977311115241787,0.0022688884758211686], prediction=0.000000
# (Researcher in getting computers to stop being boring.) --> prob=[0.9329082451622782,0.06709175483772167], prediction=0.000000
# (Simple generated grids three times a day. bot by @fitnr) --> prob=[0.9967422738794174,0.003257726120582669], prediction=0.000000
# (Software Engineer at @Amazon | Alumni of @ManipalUniv) --> prob=[0.9975998839078046,0.002400116092195453], prediction=0.000000
# (Song writer/performer keepin hiphop in its truest form representin darkside u.c.o.n.n. Records we miss u chu) --> prob=[0.9676513830293731,0.03234861697062685], prediction=0.000000
# (The Place To Learn Anything, Anywhere For All) --> prob=[0.9920586026809928,0.007941397319007235], prediction=0.000000
# (The complete works of composer JÌ_rgen Sebastian Bot. // by @inky) --> prob=[0.9988131889963358,0.0011868110036642504], prediction=0.000000
# (This is a Pikachu bot from the Pokémon series. It currently has no purpose to be someone's (Ash, Red?) Pikachu. He will be interactable eventually.) --> prob=[0.9978157371974038,0.002184262802596285], prediction=0.000000
# (This is a bot to explain things like love and hate. Why? Because bots. Crufted with care by @samplereality.) --> prob=[0.9984924025876538,0.0015075974123461581], prediction=0.000000
# (Tweeting articles on muscle stem cells from pubmed RSS feeds.) --> prob=[0.008327510290497206,0.9916724897095028], prediction=1.000000
# (Tweeting every town and populated place in America, alphabetically. By @muffinista #botALLY) --> prob=[0.9962884373390566,0.0037115626609433216], prediction=0.000000
# (Tweeting the 1950s TV sitcoms that never made it past the pilot stage.  A bot for #NaBoMaMo by @dullthud) --> prob=[0.9993516811515641,0.0006483188484358063], prediction=0.000000
# (Tweets randomly ~10 times a day between 8am-10pm PST. Complaints: @beaugunderson) --> prob=[0.998825378664717,0.0011746213352830277], prediction=0.000000
# (Twitter API + Google Images + ImageMagick. Inspired by @akari_daisuki) --> prob=[0.996534677077418,0.0034653229225820367], prediction=0.000000
# (TwitterBot collecting #synbio papers) --> prob=[0.395952305226463,0.6040476947735369], prediction=1.000000
# (Twittering every simile in the english language. Task will complete in a long time. A bot by @rainshapes) --> prob=[0.9993326912780094,0.000667308721990665], prediction=0.000000
# (Two horoscopes a day. Armchair mystic, certified astrologist, robot.) --> prob=[0.9670058948235383,0.032994105176461654], prediction=0.000000
# (UN Office for the Coordination of Humanitarian Affairs (OCHA) in Asia and the Pacific provides key updates on humanitarian issues and disasters in the region) --> prob=[0.9971231735052474,0.0028768264947525842], prediction=0.000000
# (Understand that your not alone, there is support for those diagnosed or curious about #Acromegaly. For more information: https://t.co/FXg432cnbZ) --> prob=[0.996115974595391,0.0038840254046089793], prediction=0.000000
# (Unofficial bot featuring a random selection of images from the Metropolitan Museum of Art's collection of Open Access images. (Maintained by @benrasmusen)) --> prob=[0.999278236475098,0.00072176352490215], prediction=0.000000
# ...
# (We added you on Myspace. Our new album SOME THINGS NEVER LEAVE YOU available now. @natehenrysays @dankoch) --> prob=[0.9989523518666227,0.001047648133377425], prediction=0.000000
# (We are the music makers, and we are the dreamers of dreams...) --> prob=[0.9986149457698708,0.0013850542301292491], prediction=0.000000
# (We feed 1.4M kids in India daily; promoting education and eradicating hunger. Visit us at http://t.co/KeAZERhd0J) --> prob=[0.9975520905147534,0.002447909485246597], prediction=0.000000
# (Wife åá Mother åá Decorator åá Cook åá PartyThrower åá Singer åá Producer åá Writer åá Musician åá Whew!) --> prob=[0.997370407438101,0.0026295925618990412], prediction=0.000000
# (With algorithms subtle and discrete / I seek iambic writings to retweet.) --> prob=[0.9995628048786098,0.00043719512139017507], prediction=0.000000
# (You were looking for a bot, and then you found a bot. I'm Miserable Now, by @mambocab. ~5 tweets/day. Code/acknowledgments on GitHub.) --> prob=[0.9995646187110765,0.00043538128892356854], prediction=0.000000
# ([‰ª»]) --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# (bot by @ckolderup ‰Û¢ #botALLY) --> prob=[0.9972779753524805,0.002722024647519577], prediction=0.000000
# (bot by @ckolderup ‰Û¢ #botALLY) --> prob=[0.9972779753524805,0.002722024647519577], prediction=0.000000
# (butts. butt botts. butt things. https://t.co/9K7GC6ImGN #rumpology - @speckninja (bot favs tweets containing 'butt')) --> prob=[0.9828023838743485,0.017197616125651564], prediction=0.000000
# (colors.  all of 'em. | developed by @vogon; feel free to send him feedback/feature requests) --> prob=[0.9967083068428154,0.003291693157184505], prediction=0.000000
# (follow @drakeftagb) --> prob=[0.9975385003388678,0.002461499661132165], prediction=0.000000
# (go subscribe to my channel http://t.co/tMLNHqUGp9) --> prob=[0.9931788975714837,0.0068211024285162085], prediction=0.000000
# (how i'd wish that were so.) --> prob=[0.9886261409082728,0.0113738590917272], prediction=0.000000
# (http://t.co/YfHoThSDVQ...) --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# (portmanteaus, portmanteaus everywhere // by @thricedotted) --> prob=[0.97952842508274,0.020471574917259948], prediction=0.000000
# (starting leade.rs) --> prob=[0.9731268672750144,0.026873132724985573], prediction=0.000000
# (weeee willll weee willll rock you!) --> prob=[0.9861531315675336,0.013846868432466556], prediction=0.000000
# (you're here with me now) --> prob=[0.9929465438784209,0.007053456121579045], prediction=0.000000
# (µµÜ‰Í_ÜÜ_Ü») --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# ( FL""") --> prob=[0.9665115803217659,0.03348841967823409], prediction=0.000000
# ( South Yorkshire) --> prob=[0.9783150714050958,0.021684928594904236], prediction=0.000000
# ("""") --> prob=[0.559135202067154,0.4408647979328461], prediction=0.000000
# ("""Bulu Bulu Kehidupan""") --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# ("""Saint Seiya 4Ever""") --> prob=[0.989134258141103,0.01086574185889701], prediction=0.000000
# ("""The official Manchester City Twitter account | Supporter Services __ @ManCityHelp | Snapchat __ mancityofficial""") --> prob=[0.9996266697327117,0.00037333026728810756], prediction=0.000000
# (#VampireLife bookings for #JimJones bookjimjones@gmail.com  info@nextofkinent.com) --> prob=[0.9670415803730897,0.032958419626910304], prediction=0.000000
# ('Wow' Out Now - https://t.co/D8mflkQEe0) --> prob=[0.9842455477594151,0.01575445224058488], prediction=0.000000
# (*IN BETA* Low-res, slightly bizarre Open Access images from the Met (via @MuseumBot) crossed with palettes from @colourlovers. Powered by @uncontext. By @_ARP.) --> prob=[0.9982471431522401,0.0017528568477598325], prediction=0.000000
# (1) --> prob=[0.989237908411138,0.010762091588861964], prediction=0.000000
# (@styletiana is hot.) --> prob=[0.9572846212972469,0.042715378702753104], prediction=0.000000
# (A bot by @NoraReed Patreon: https://t.co/f7OKH9MO9D Tip Jar: https://t.co/KOMoL6IrsM‰Û_ FAQ: https://t.co/Z49vqlFP4x) --> prob=[0.998803398615292,0.0011966013847079227], prediction=0.000000
# (A bot that creates hilarious joax via Google's autocomplete. By @deathmtn.) --> prob=[0.9644041898458953,0.03559581015410465], prediction=0.000000
# (A bot that generates random malfunctioning equipment, created by @notinventedhere using http://t.co/XpDujaprri) --> prob=[0.9970389856365034,0.0029610143634966586], prediction=0.000000
# (A bot tweeting links to new archaeological journal articles. Limited to those journals that provide RSS!) --> prob=[0.8880365492040543,0.11196345079594577], prediction=0.000000
# (Activist. Actress. Artist. Instagram: @lindsaylohan https://t.co/FjAZzhuK6y Management: scott@honestmg.com) --> prob=[0.9804100264513965,0.01958997354860344], prediction=0.000000
# (Anchor of Erin Burnett OutFront.) --> prob=[0.9699958866890156,0.0300041133109844], prediction=0.000000
# (Anime, Game, Programming, Tech, and other nonsense äóñ in Thai, English) --> prob=[0.9658197471741735,0.03418025282582652], prediction=0.000000
# (Boutique Bollywood Actor) --> prob=[0.9988763988604027,0.001123601139597223], prediction=0.000000
# (Carbon-based multicellular lifeform.) --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# (Cat lady, singer, actor, love improv & living in Tokyo) --> prob=[0.9898163549050298,0.01018364509497006], prediction=0.000000
# (Creating a new blend of #classical, #jazz, #rock, #pop and #worldmusic using #cello as a common denominator.  Striving to make #globalimpact through #music.) --> prob=[0.9829498900888717,0.01705010991112826], prediction=0.000000
# (Dashboard Confessional Tix available NOW for our up close and personal tour in Jan and Feb of 2017: https://t.co/Bj0G7NIhy1) --> prob=[0.98023578435717,0.019764215642830055], prediction=0.000000
# (Department of History, College Students) --> prob=[0.93314496961983,0.06685503038017013], prediction=0.000000
# (Design Thinker, Dev Ops Practitioner, Lean Coach.) --> prob=[0.9959175996706936,0.004082400329306362], prediction=0.000000
# (Established in 1995, NYU's Remarque Institute supports the multi-disciplinary and comparative study of Europe and its near neighbors.) --> prob=[0.9993867358545117,0.0006132641454883041], prediction=0.000000
# (Every combination of letters that is not an English word, including some common slang and jargon. Task will complete long after we're dead. An @_ARP bot.) --> prob=[0.9986519745103372,0.001348025489662828], prediction=0.000000
# (Extremely powerful being, do not insult me. THIS IS A COMEDY ACCOUNT FOR COMEDY) --> prob=[0.9083749702040657,0.09162502979593432], prediction=0.000000
# (FITNESS) --> prob=[0.7693532076938031,0.23064679230619695], prediction=0.000000
# (Fake James Joyce novel titles. A bot by @sillygwailo. #botALLY) --> prob=[0.9975119432776605,0.002488056722339676], prediction=0.000000
# (Family over everything) --> prob=[0.9955605878626301,0.004439412137369812], prediction=0.000000
# (Fast and steady wins the race.) --> prob=[0.9653956250622198,0.03460437493778022], prediction=0.000000
# (Film buff,Actor, Director, Dancer, Writer, Producer) --> prob=[0.994130295139066,0.00586970486093385], prediction=0.000000
# (Friend of the program.) --> prob=[0.9840814288117684,0.015918571188231576], prediction=0.000000
# (From Russia, live in Amsterdam. QA engineer, test automation.) --> prob=[0.9917196442266996,0.008280355773300347], prediction=0.000000
# (Generating äóìself-portraitsäó once a day äó¢ A bot by @ashur äó¢ #botALLY) --> prob=[0.9989436388160728,0.001056361183927015], prediction=0.000000
# (Give me a museum and I'll fill it.) --> prob=[0.9854494836256708,0.014550516374329126], prediction=0.000000
# (Host of The Roe Conn Show afternoons on Chicago's WGN Radio and contributor to ABC7's Windy City Live.) --> prob=[0.9981109044611896,0.0018890955388104916], prediction=0.000000
# (I retweet questions followed by answers. Brought to you by @rfreebern.) --> prob=[0.9995780665555128,0.0004219334444871246], prediction=0.000000
# (I tweet a new horizon view every six hours.  Created by @acgodliman using cheapbotsdonequick. WIP) --> prob=[0.9986777944269176,0.0013222055730823137], prediction=0.000000
# (I'm just your average procedural avatar generating twitter bot. @bzgeb is my creator) --> prob=[0.9989379613724504,0.0010620386275496728], prediction=0.000000
# (Just some space stories. A http://t.co/8dBPX7FlIa bot (with occasional analogue stories) by @notinventedhere and @thos_thom.) --> prob=[0.9991764354707751,0.000823564529224945], prediction=0.000000
# (Late adopter.) --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# (Legitimate reviews from 100% people, every two minutes.) --> prob=[0.9986139082625786,0.0013860917374214053], prediction=0.000000
# (Let's keep this thing going, gang! #AddaWordRuinaMovie) --> prob=[0.997629950340895,0.0023700496591051723], prediction=0.000000
# (Looking to stick it to the man yeah I hate the man) --> prob=[0.9959144909146027,0.00408550908539735], prediction=0.000000
# (Magic cards generated by a Recurrent Neural Network, posted once a day. Not Mark Rosewater.) --> prob=[0.9993723731979384,0.0006276268020615878], prediction=0.000000
# (Marketing guy, social gadfly, and general man about town) --> prob=[0.9879865476593325,0.012013452340667618], prediction=0.000000
# (On my standup comedy tour now! Details at https://t.co/2zXkcRPGgX) --> prob=[0.9965921573669834,0.0034078426330166637], prediction=0.000000
# (Pre-order The Blood Album on iTunes. https://t.co/pukqh1O7id) --> prob=[0.9789430244451034,0.021056975554896752], prediction=0.000000
# (Principal Engineer at @voxmediainc / @voxproduct. Tweets my own. Jokes shamelessly ripped from Reddit. Prev: @disqus, @threespot. ä_ StarCraft) --> prob=[0.9992474201984999,0.000752579801500112], prediction=0.000000
# (Producer/Songwriter/Lead Singer of Sixx:A.M.) --> prob=[0.9672402466706355,0.032759753329364545], prediction=0.000000
# (Secretly triggered subtweetbombing encouragement bot inspired by https://t.co/EMTnCTpOxx) --> prob=[0.9928182015150774,0.0071817984849226295], prediction=0.000000
# (Send a direct message mentioning people you really like :)                  (I'm a bot, and I do only use the @ of who you mention) (I'm a bit busy, be patient)) --> prob=[0.9999994062192255,5.937807744763001e-07], prediction=0.000000
# (Serbia is a beautiful European country, with rich history, culture, welcoming and loving people and great night life and strong art and cafe culture.) --> prob=[0.9971475933522669,0.0028524066477331137], prediction=0.000000
# (Snap: @maalenacarvalho) --> prob=[0.9679222393809251,0.032077760619074844], prediction=0.000000
# (Social Activist | Nationalist | Swayamsevak | BJP Delhi | Namo Fan | Followed By the Honourable  PM @narendramodi ji.) --> prob=[0.9962824303121753,0.0037175696878246666], prediction=0.000000
# (Stage Manager, Writer, Leader...and more.) --> prob=[0.9757853128274371,0.02421468717256286], prediction=0.000000
# (Sup) --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# (Television has brought back murder into the home - where it belongs.) --> prob=[0.9988312486162195,0.0011687513837803796], prediction=0.000000
# (Tennis player.) --> prob=[0.9933777575003222,0.006622242499677761], prediction=0.000000
# (Topics, news and more about nature.) --> prob=[0.9754201272403094,0.02457987275969069], prediction=0.000000
# (Tweeting all the languages. All of them. Process should finish sometime in October 2015. Created by @OnnaAdele.) --> prob=[0.9920887365859605,0.007911263414039476], prediction=0.000000
# (Tweeting every letter in the english language.) --> prob=[0.9969546951166686,0.003045304883331493], prediction=0.000000
# (Tweets from the Mayor of St. Louis' personal website. The Mayor's own tweets are signed #fgs, his initials.) --> prob=[0.9846468284474913,0.015353171552508621], prediction=0.000000
# (Tweets ~10 times a day between 8am-10pm PST. Will probably get more vaporwave-y as time goes by. Complaints: @beaugunderson) --> prob=[0.9994523076645588,0.0005476923354412391], prediction=0.000000
# (Twitterbot of cichlid PubMed papers (inspired by @fly_papers). Image Astatotilapia calliptera, K. Woodhouse. Curated by @domino_joyce.) --> prob=[0.06806078136478522,0.9319392186352147], prediction=1.000000
# (Under Construction) --> prob=[0.9866545951316917,0.01334540486830825], prediction=0.000000
# (Violet 100 event link: https://t.co/hf0W3M7i2S) --> prob=[0.9752552738158689,0.0247447261841312], prediction=0.000000
# (Welcome to http://t.co/OgGcZs9E0w. I hope to immerse you into a world all about  Oil Painting. It can become a serious passion. I Love painting!) --> prob=[0.9996741375428425,0.00032586245715753406], prediction=0.000000
# (Well-fed artist.) --> prob=[0.9858870187002571,0.014112981299743019], prediction=0.000000
# (What will John Oliver DESTROY next? A @ThisIsFusion bot. http://t.co/TITeSH2I5J) --> prob=[0.9933153847070683,0.006684615292931685], prediction=0.000000
# (You dont have to follow this account, Just follow this one @LethargicJOE to get your free follow ;) Thanks!) --> prob=[0.9995227879415923,0.0004772120584076871], prediction=0.000000
# (director.) --> prob=[0.9683300871946651,0.03166991280533496], prediction=0.000000
# (free follow from @octloveslukey, go follow her for more) --> prob=[0.9800705112039012,0.019929488796098748], prediction=0.000000
# (fuck it, put a chip in it. say hello: internetofshit@gmail.com) --> prob=[0.9908775939046492,0.009122406095350854], prediction=0.000000
# (snail half dedicated to @inky // complaints to @beaugunderson) --> prob=[0.9948502043253167,0.005149795674683285], prediction=0.000000
# (this is the only official ashlee simpson ross twitter. click your heels three times and think of me...chick-a-boom) --> prob=[0.9984378115598421,0.0015621884401579534], prediction=0.000000
# ("""") --> prob=[0.559135202067154,0.4408647979328461], prediction=0.000000
# (@B_Real | @OGSenDog | @ericbobo | @DJ_Muggs | @juliog1580kday) --> prob=[0.972476582635222,0.027523417364778043], prediction=0.000000
# (Advice is what we ask for when we already know the answer but wish we didn't.) --> prob=[0.9985160126148076,0.001483987385192429], prediction=0.000000
# (Agricultural Engineer, likes to joke and trying to live a certain balance between his laptop at the office and his shovel in the field.) --> prob=[0.9993783186286073,0.0006216813713925854], prediction=0.000000
# (BEEP BOOP WHITE PEOPLE) --> prob=[0.9972726275355366,0.0027273724644634027], prediction=0.000000
# (CNN's host of @ReliableSources and senior media correspondent. Formerly @nytimes, @tvnewser and Top of the Morning. Email: bstelter@gmail.com) --> prob=[0.9914933044272906,0.00850669557270941], prediction=0.000000
# (Daily RSS Feed for Protein Hot Spot Prediction papers. Maintained by @selinkaragulle) --> prob=[0.11742652897548853,0.8825734710245114], prediction=1.000000
# (Every word in the English language, in Comic Sans MS. My friends think I'm fun! By @avestal.) --> prob=[0.9955858950153168,0.004414104984683245], prediction=0.000000
# (Get the latest BLONDIE news at http://t.co/LIHTvKT3h7!) --> prob=[0.9780480845369929,0.021951915463007125], prediction=0.000000
# (I DONT NEE A FUCKIN SLOGGIN FUC A TEAM I JUST FOLLOW ACK UNFOLLOW ME AND I'LL KICK YOUR ASS) --> prob=[0.999111074821368,0.0008889251786321055], prediction=0.000000
# (I tweet pentatonic ditties.) --> prob=[0.9755853936203253,0.024414606379674665], prediction=0.000000
# (I'm a Bot; I randomly retweet a tweet from the public timeline, and... that's just it.) --> prob=[0.9988107357348194,0.0011892642651806656], prediction=0.000000
# (This should be the quickest route, but it depends on the traffic) --> prob=[0.9812358489676515,0.018764151032348506], prediction=0.000000
# (UXer) --> prob=[0.9531082523438213,0.0468917476561786], prediction=0.000000
# (another one bites the dust || dancer) --> prob=[0.9897029165329236,0.01029708346707628], prediction=0.000000

# %% [markdown]
# In the text output search for
# `prediction=1`
#
# And write in the chat which description got classified as bot!

# %% [markdown]
# In the text output search for
# `prediction=1`
#
# And write in the chat which description got classified as bot!

# %% [markdown]
# ## Exercise 3: Put everything together

# %% [markdown]
# ### CrossValidator, BinaryClassificationEvaluator and ParamGridBuilder functionality
#
# ✅ **Task :**
#
#
# CrossValidator provide us the ability to run multiple training set and testing set within one function call -
# `fit`.
#
# It runs the evaluation phase and chooses the best parameters.
#
# Read about `CrossValidator` in the [docs](https://spark.apache.org/docs/latest/ml-tuning.html) and integrate it into your pipeline.
#
# In the docs, search for `CrossValidator` `python` example.
#
# Copy the example to the notebook and adjust it to your needs.
#
# From the docs:
# >`CrossValidator` - K-fold cross validation performs model selection by splitting the dataset into a set of non-overlapping randomly partitioned folds which are used as separate training and test datasets e.g., with k=3 folds, K-fold cross validation will generate 3 (training, test) dataset pairs, each of which uses 2/3 of the data for training and 1/3 for testing. Each fold is used as the test set exactly once.
#
# <details><summary>Can't find the example, click here! </summary>
# <p>
#
# ```python
# from pyspark.ml import Pipeline
# from pyspark.ml.classification import LogisticRegression
# from pyspark.ml.evaluation import BinaryClassificationEvaluator
# from pyspark.ml.feature import HashingTF, Tokenizer
# from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
#
# # Prepare training documents, which are labeled.
# training = spark.createDataFrame([
#     (0, "a b c d e spark", 1.0),
#     (1, "b d", 0.0),
#     (2, "spark f g h", 1.0),
#     (3, "hadoop mapreduce", 0.0),
#     (4, "b spark who", 1.0),
#     (5, "g d a y", 0.0),
#     (6, "spark fly", 1.0),
#     (7, "was mapreduce", 0.0),
#     (8, "e spark program", 1.0),
#     (9, "a e c l", 0.0),
#     (10, "spark compile", 1.0),
#     (11, "hadoop software", 0.0)
# ], ["id", "text", "label"])
#
# # Configure an ML pipeline, which consists of tree stages: tokenizer, hashingTF, and lr.
# tokenizer = Tokenizer(inputCol="text", outputCol="words")
# hashingTF = HashingTF(inputCol=tokenizer.getOutputCol(), outputCol="features")
# lr = LogisticRegression(maxIter=10)
# pipeline = Pipeline(stages=[tokenizer, hashingTF, lr])
#
# # We now treat the Pipeline as an Estimator, wrapping it in a CrossValidator instance.
# # This will allow us to jointly choose parameters for all Pipeline stages.
# # A CrossValidator requires an Estimator, a set of Estimator ParamMaps, and an Evaluator.
# # We use a ParamGridBuilder to construct a grid of parameters to search over.
# # With 3 values for hashingTF.numFeatures and 2 values for lr.regParam,
# # this grid will have 3 x 2 = 6 parameter settings for CrossValidator to choose from.
# paramGrid = ParamGridBuilder() \
#     .addGrid(hashingTF.numFeatures, [10, 100, 1000]) \
#     .addGrid(lr.regParam, [0.1, 0.01]) \
#     .build()
#
# crossval = CrossValidator(estimator=pipeline,
#                           estimatorParamMaps=paramGrid,
#                           evaluator=BinaryClassificationEvaluator(),
#                           numFolds=2)  # use 3+ folds in practice
#
# # Run cross-validation, and choose the best set of parameters.
# cvModel = crossval.fit(training)
#
# # Prepare test documents, which are unlabeled.
# test = spark.createDataFrame([
#     (4, "spark i j k"),
#     (5, "l m n"),
#     (6, "mapreduce spark"),
#     (7, "apache hadoop")
# ], ["id", "text"])
#
# # Make predictions on test documents. cvModel uses the best model found (lrModel).
# prediction = cvModel.transform(test)
# selected = prediction.select("id", "text", "probability", "prediction")
# for row in selected.collect():
#     print(row)
# ```
#
# </p>
# </details>

# %% [markdown]
# <details><summary>Answer</summary>
# <p>
#
# ```python
# from pyspark.ml import Pipeline
# from pyspark.ml.classification import LogisticRegression
# from pyspark.ml.evaluation import BinaryClassificationEvaluator
# from pyspark.ml.feature import HashingTF, Tokenizer
# from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
#
#
# # We now treat the Pipeline as an Estimator, wrapping it in a CrossValidator instance.
# # This will allow us to jointly choose parameters for all Pipeline stages.
# # A CrossValidator requires an Estimator, a set of Estimator ParamMaps, and an Evaluator.
# # We use a ParamGridBuilder to construct a grid of parameters to search over.
# # With 3 values for hashingTF.numFeatures and 2 values for lr.regParam,
# # this grid will have 3 x 2 = 6 parameter settings for CrossValidator to choose from.
# paramGrid = ParamGridBuilder() \
#     .addGrid(hashingTF.numFeatures, [10, 100, 1000]) \
#     .addGrid(lr.regParam, [0.1, 0.01]) \
#     .build()
#
#
# crossval = CrossValidator(estimator=pipeline,
#                           estimatorParamMaps=paramGrid,
#                           evaluator=BinaryClassificationEvaluator(),
#                           numFolds=3)  # use 3+ folds in practice
#
#
# # Run cross-validation, and choose the best set of parameters.
# cvModel = crossval.fit(trainingData)
#
# prediction = cvModel.transform(testData)
# selected = prediction.select("description", "probability", "prediction")
# for row in selected.collect():
#     print(row)
#
# ```
#
# </p>
# </details>

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.feature import HashingTF, Tokenizer
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder


# We now treat the Pipeline as an Estimator, wrapping it in a CrossValidator instance.
# This will allow us to jointly choose parameters for all Pipeline stages.
# A CrossValidator requires an Estimator, a set of Estimator ParamMaps, and an Evaluator.
# We use a ParamGridBuilder to construct a grid of parameters to search over.
# With 3 values for hashingTF.numFeatures and 2 values for lr.regParam,
# this grid will have 3 x 2 = 6 parameter settings for CrossValidator to choose from.
paramGrid = ParamGridBuilder() \
    .addGrid(hashingTF.numFeatures, [10, 100, 1000]) \
    .addGrid(lr.regParam, [0.1, 0.01]) \
    .build()


crossval = CrossValidator(estimator=pipeline,
                          estimatorParamMaps=paramGrid,
                          evaluator=BinaryClassificationEvaluator(),
                          numFolds=3)  # use 3+ folds in practice


# Run cross-validation, and choose the best set of parameters.
cvModel = crossval.fit(trainingData)

prediction = cvModel.transform(testData)
selected = prediction.select("description", "probability", "prediction")
for row in selected.collect():
    print(row)
# Out:
# Row(description=' California."""', probability=DenseVector([0.9597, 0.0403]), prediction=0.0)
# Row(description='"""Electrical retailer in Belfast selling everything from TV\'s', probability=DenseVector([0.9149, 0.0851]), prediction=0.0)
# Row(description='"""One piece_______One piece___Twitter________bot___1_______________________________________________________________________________________________RT_____________"""', probability=DenseVector([0.5512, 0.4488]), prediction=0.0)
# Row(description='"""Photographer | Los Angeles', probability=DenseVector([0.9617, 0.0383]), prediction=0.0)
# Row(description='"""Providing Tweets of the rarest and rare battle of the best Pokemon in the East Chula Vista area. All Times Til Hidden (TTH) are approximate.\\n\\nDonations welcome."""', probability=DenseVector([0.9598, 0.0402]), prediction=0.0)
# Row(description='"""Uber rare and strong PokŽmon in Singapore. See more PokŽmon at https://t.co/LLiUGW8lBD\\n\\nFollow @SGPokeStatus for more info and status update."""', probability=DenseVector([0.947, 0.053]), prediction=0.0)
# Row(description='"New single ""KILL AGAIN"" out now! https://t.co/qiZ8W4mhJG Shaka Zulu! https://t.co/9ZY92tEQaX https://t.co/uBNsayp9Gr"', probability=DenseVector([0.9787, 0.0213]), prediction=0.0)
# Row(description='"O que me move? O perpétuo desejo de ser uma ""ponte"" melhor!  #Educação #MetodologiasAtivas #DesignThinking"', probability=DenseVector([0.9747, 0.0253]), prediction=0.0)
# Row(description='#wearedrugs, #SummerGodsTour, #resist surf whenever i can', probability=DenseVector([0.9813, 0.0187]), prediction=0.0)
# Row(description='(insert here) survivor and former ink-stained wretch', probability=DenseVector([0.9672, 0.0328]), prediction=0.0)
# Row(description='1-@sobesr 2-@myselenwtors 3- @zaynshadidd', probability=DenseVector([0.9702, 0.0298]), prediction=0.0)
# Row(description='@FoxSoccer TV Soccer Analyst & Host _Ù__ New Show #SpeakResponsibly link in bio', probability=DenseVector([0.9928, 0.0072]), prediction=0.0)
# Row(description='A bot that generates novel literary and rhetorical devices and their definitions. By @atduskgreg.', probability=DenseVector([0.9787, 0.0213]), prediction=0.0)
# Row(description='A bot that tweets every line said by Robbie Valentino on Gravity Falls every 30 minutes. Please report any mistakes/misspellings/errors to @JadaManiscalco.', probability=DenseVector([0.9203, 0.0797]), prediction=0.0)
# Row(description='A pile of sleepy meat. Lists at @someecards. Host of weekly comedy show @themulletchi. Totally hatless. Everything written here is true and serious.', probability=DenseVector([0.9813, 0.0187]), prediction=0.0)
# Row(description="A random historical restaurant menu from NYPL's collection. Average three per day. Also https://t.co/OLgPaEtsK1 https://t.co/6nF9g7R4Mg by @hugovk", probability=DenseVector([0.9815, 0.0185]), prediction=0.0)
# Row(description="A story in 36 tweets, told in your notifications panel. Tweet '@liketocontinue hi' to start and wait for the reply. By Matt Webb @genmon", probability=DenseVector([0.9528, 0.0472]), prediction=0.0)
# Row(description='A twitter bot that automatically tweets new articles related to plant biology in Nature, Science and PNAS using zapier and dlvrit.', probability=DenseVector([0.5801, 0.4199]), prediction=0.0)
# Row(description='Alert for pre-print manuscripts in Cell biology, sources bioarxiv #openaccess #cell #cellbiol by @wpgilks', probability=DenseVector([0.764, 0.236]), prediction=0.0)
# Row(description='Also known as coblee, creator of Litecoin. Cryptocurrency Enthusiast. Director of Engineering at Coinbase.', probability=DenseVector([0.9542, 0.0458]), prediction=0.0)
# Row(description='An Outlier,Twice over!', probability=DenseVector([0.8969, 0.1031]), prediction=0.0)
# Row(description='An atlas of unknown lands | bot by @mewo2', probability=DenseVector([0.9534, 0.0466]), prediction=0.0)
# Row(description='An exploration of the people behind the projects. Each post is an interview with a member of the open source community. By @johnjones4 and @Maddison_Long', probability=DenseVector([0.9749, 0.0251]), prediction=0.0)
# Row(description='Anything Is Possible!', probability=DenseVector([0.9303, 0.0697]), prediction=0.0)
# Row(description='Anything Twenty ?ne Pil?ts, Panic! At The Disco, MCRX, yeah, you get the point...Tacos, Chinese Food, Food in generalÁ_You can guess the restÁ_', probability=DenseVector([0.9391, 0.0609]), prediction=0.0)
# Row(description='Atleta profissional de futebol', probability=DenseVector([0.8275, 0.1725]), prediction=0.0)
# Row(description='Automatically-generated blog-rock contrarianism. (By @michaelbarthel)', probability=DenseVector([0.9195, 0.0805]), prediction=0.0)
# Row(description='Barkha Rani Jamke Barasti Hai. Emmy Nominated Reporter. Author.Contributing Columnist @WashingtonPost Contributing Ed @TheWeekLive. Argumentative!Yaaron Ka Yaar', probability=DenseVector([0.9632, 0.0368]), prediction=0.0)
# Row(description='Bot that gives you great game ideas by mixing tags from the IFDB! (By @hlabrande)', probability=DenseVector([0.9641, 0.0359]), prediction=0.0)
# Row(description='Bringing you the latest in #lncRNA scientific literature. #lincRNA #longnoncodingRNA #RNA #biochem #pubmed #science', probability=DenseVector([0.8904, 0.1096]), prediction=0.0)
# Row(description='CMML specializes in the science and technology of lightweight composites, especially syntactic foams, tailored for dynamic loading conditions.', probability=DenseVector([0.992, 0.008]), prediction=0.0)
# Row(description="COLONEL: Snake, it's derivative mashup trash. Looks like it was made by @nah_solo. Followers will be picked at random to converse with dril.", probability=DenseVector([0.967, 0.033]), prediction=0.0)
# Row(description='Chairman of Icahn Enterprises L.P.; etc., etc.              Some people get rich studying artificial intelligence.  Me, I make money studying natural stupidity.', probability=DenseVector([0.9998, 0.0002]), prediction=0.0)
# Row(description="Chakra Shawty | All Black Errthang | Wine & Whiskey Connoisseur | GIRL POWER | Mother Earth's Flower |", probability=DenseVector([0.9393, 0.0607]), prediction=0.0)
# Row(description='Chinese girl in Seattle', probability=DenseVector([0.9107, 0.0893]), prediction=0.0)
# Row(description='Co-Founder and Chairman of @Stocktwits, GP of Social Leverage, Wallstrip creator (acquired by $CBS), Momentum, Stocks & LOL hunter..Love Popcorn', probability=DenseVector([0.995, 0.005]), prediction=0.0)
# Row(description='Continuous feed for phylogenetics papers from PubMed, arXiv, bioRxiv, and PeerJ PrePrints. Run by @RobLanfear', probability=DenseVector([0.1539, 0.8461]), prediction=1.0)
# Row(description='Covering Malton, Bridlington & Scarborough. DVSA Fleet Registered Trainer. IAM RoadSmart Master of Driving with Distinction. Official Taxi Driver Assessor.', probability=DenseVector([0.9668, 0.0332]), prediction=0.0)
# Row(description='Criticises fonts from http://t.co/wWmvMyo5Zf for the more discerning of authors. A bot created by @eegnsma', probability=DenseVector([0.8673, 0.1327]), prediction=0.0)
# Row(description='Designing and making games @nytdesign _Ò\x8d side project haver _Ò\x8d see also: @itsthisyear, @icebergdotcool, @ramsophone, @__birds__ _Ò\x8d', probability=DenseVector([0.9922, 0.0078]), prediction=0.0)
# Row(description='Enjoying being retired / New Hobby: Photography', probability=DenseVector([0.9495, 0.0505]), prediction=0.0)
# Row(description="Every hour I'll tweet 1 of the 22482 species that are known to be in danger of extinction, which will last from 12/21/14 to 07/12/17. Project by @ianalanpaul", probability=DenseVector([0.9413, 0.0587]), prediction=0.0)
# Row(description='Experimental Poet', probability=DenseVector([0.9625, 0.0375]), prediction=0.0)
# Row(description='FDA parody account by @Objelisks', probability=DenseVector([0.9334, 0.0666]), prediction=0.0)
# Row(description='Fictional US presidential candidates | source: https://t.co/REgbaGCioz | bot by @mewo2', probability=DenseVector([0.9638, 0.0362]), prediction=0.0)
# Row(description="Financial Analyst by day, Sports Analyst by Night. Coming on the air live or taped somewhere. Make sure you're watching", probability=DenseVector([0.9632, 0.0368]), prediction=0.0)
# Row(description='Flotsam and jetsam from the neural driftnets. A bot by @bombinans', probability=DenseVector([0.9865, 0.0135]), prediction=0.0)
# Row(description="Following the formula: I'm not X but I am the definition of X. (via @stefanhayden) Tweets every 10 minutes.", probability=DenseVector([0.9905, 0.0095]), prediction=0.0)
# Row(description="For over 20 years, we've been giving students in need the right resources to ensure lifelong success ‰Û¢ Home of Unexpected Champions #ReachMillions", probability=DenseVector([0.8098, 0.1902]), prediction=0.0)
# Row(description='Forever trapped, a bot-wanderer walks through an infinite dungeon. Created by @jeffthompson_', probability=DenseVector([0.9719, 0.0281]), prediction=0.0)
# Row(description='Founder of Room to Read.  Author of Leaving Microsoft to Change the World.  Goldman Sachs 100 Most Intriguing Entrepreneurs.', probability=DenseVector([0.8686, 0.1314]), prediction=0.0)
# Row(description='From late 2014 Socium Marketplace will make shopping for fundamental business services more simple, more cost effective and more about you.', probability=DenseVector([0.5377, 0.4623]), prediction=0.0)
# Row(description='Global Derivatives #Trading & #Risk Management is at the helm of the #quant #finance industry, curating cutting edge research, interviews and opinions. #GDerivs', probability=DenseVector([0.7714, 0.2286]), prediction=0.0)
# Row(description='Grammy nominated album #TheBlade out on @iTunes https://t.co/zYE8CRBfS5 & @AmazonMusic https://t.co/fZiHQl8QSO', probability=DenseVector([0.9692, 0.0308]), prediction=0.0)
# Row(description='Growth coach, fintech mentor & big bank defector', probability=DenseVector([0.6896, 0.3104]), prediction=0.0)
# Row(description='Head of R&D, ML/AI at Google Cloud', probability=DenseVector([0.9296, 0.0704]), prediction=0.0)
# Row(description="Hello humans: I'm a twitter bot created by @justinsandefur to follow new research papers in development economics (JEL code O).  Follow me.", probability=DenseVector([0.9043, 0.0957]), prediction=0.0)
# Row(description="Hi I'm Howie D from the Backstreet Boys.", probability=DenseVector([0.9843, 0.0157]), prediction=0.0)
# Row(description="I alert Twitter users that they typed Columbian when they meant Colombian. You're welcome!", probability=DenseVector([0.3185, 0.6815]), prediction=1.0)
# Row(description='I am not AI.  My codename is Project 2501.  I am an angry, cynical entity that was created in a sea of information.', probability=DenseVector([0.9907, 0.0093]), prediction=0.0)
# Row(description='I generate a magical story every 2 hours. Made by @chrisrodley and @yeldora_. Feedback or suggestions for new words? Email crodley@gmail.com.', probability=DenseVector([0.9725, 0.0275]), prediction=0.0)
# Row(description='I tweet a random object from the collection of the Victoria and Albert Museum four times a day. Bot by @backspace (not affiliated with @V_and_A)', probability=DenseVector([0.9832, 0.0168]), prediction=0.0)
# Row(description="I want you to know thatI am both happy and sadand I'm still trying to fgure out how that could be.", probability=DenseVector([0.9925, 0.0075]), prediction=0.0)
# Row(description="I'm a bot that hates it when people use words that aren't @everyword canon. #taskcomplete by @negatendo, who is sorry.", probability=DenseVector([0.9868, 0.0132]), prediction=0.0)
# Row(description="I'm the Sorting Hat and I'm here to say / I love sorting students in a major way // a bot by @tinysubversions, follow to get sorted!", probability=DenseVector([0.9568, 0.0432]), prediction=0.0)
# Row(description="I'm the real Avan Jogia, though sometimes it seems like a parody account. More to follow...", probability=DenseVector([0.9117, 0.0883]), prediction=0.0)
# Row(description="I've created a #BlackRose' Universe Double album, a book, 1hr Docu all in stores NOW make an R&B Soul statement buy the FULL #BlackRose' album - it's my BEST!", probability=DenseVector([0.8555, 0.1445]), prediction=0.0)
# Row(description='IMAGINE PEACE: Think PEACE, Act PEACE, Spread PEACE.', probability=DenseVector([0.9666, 0.0334]), prediction=0.0)
# Row(description="If we don't all stand together, we will fall... https://t.co/nWDVb7tvpy", probability=DenseVector([0.9652, 0.0348]), prediction=0.0)
# Row(description="If you have to start a sentence with 'I'm not racist, but...' then chances are you're pretty racist. This isn't a bot. RTŠ_¾endorsement, obviously.", probability=DenseVector([0.9683, 0.0317]), prediction=0.0)
# Row(description="If you're pedantic or professionally outraged... jog on! if ur interested in food & wine check out @SchofeOnWine", probability=DenseVector([0.9426, 0.0574]), prediction=0.0)
# Row(description='Imagine these perfect scenarios in your head but when times come you fuck up. Now imagine the things I could do with a kayak. A bot by @lalanl. #botALLY', probability=DenseVector([0.9715, 0.0285]), prediction=0.0)
# Row(description='In the Nutshell: Tech - Basketball - Music', probability=DenseVector([0.9098, 0.0902]), prediction=0.0)
# Row(description='In the end, only kindness matters.', probability=DenseVector([0.9193, 0.0807]), prediction=0.0)
# Row(description='Inquiries & Bookings email Ryan@FiondaManagement.com | HOST of #TheWhoolywoodShuffle on @shade45 12pm-6pm EST Saturdays! Also Heard On @OpieRadio | #TurnUpGodz', probability=DenseVector([0.9954, 0.0046]), prediction=0.0)
# Row(description='Instagram : @ub1305', probability=DenseVector([0.9113, 0.0887]), prediction=0.0)
# Row(description='Investigating crimes against exosaurs.', probability=DenseVector([0.8902, 0.1098]), prediction=0.0)
# Row(description="It's life and life only. Terminal Cases out NOW https://t.co/jDRGHDrAbt", probability=DenseVector([0.9898, 0.0102]), prediction=0.0)
# Row(description="It's not like the fire ended in 1989, so this bot by @air_hadoken makes new lyrics for the Billy Joel classic based on Google Trends. #botALLY", probability=DenseVector([0.9728, 0.0272]), prediction=0.0)
# Row(description='Jeremiah 29:11', probability=DenseVector([0.9464, 0.0536]), prediction=0.0)
# Row(description='Just a normal teen/future marketer who LOVES #brands! Check out my stream to see me shout out the coolest, most #innovative brands on Twitter and around the web', probability=DenseVector([0.9492, 0.0508]), prediction=0.0)
# Row(description='Just a simple med student who likes to explore new hobbies. Currently, brewing, baking, and dabbling in masonry.', probability=DenseVector([0.9873, 0.0127]), prediction=0.0)
# Row(description="Keane's official Twitter page. Get The Best of Keane from Amazon at http://t.co/XazVxu8pnj or iTunes at http://t.co/7cz7MmRI6H", probability=DenseVector([0.827, 0.173]), prediction=0.0)
# Row(description='Learning Enthusiast | Training and Development | Planning and Execution', probability=DenseVector([0.9819, 0.0181]), prediction=0.0)
# Row(description='Leveraging advanced Cloud Tech for Next-Gen Shitposting‰ã¢', probability=DenseVector([0.8917, 0.1083]), prediction=0.0)
# Row(description='Literature bot searching arXiv, biorXiv, PeerJ & PubMed for supercoiling papers. Maintained by @red_gravel.', probability=DenseVector([0.1818, 0.8182]), prediction=1.0)
# Row(description='Looking for ways to spark engagement with your followers? Get 10000 Twitter Followers using this website https://t.co/DP3zFHtOPh', probability=DenseVector([0.9413, 0.0587]), prediction=0.0)
# Row(description='Minister of Information Affairs', probability=DenseVector([0.9277, 0.0723]), prediction=0.0)
# Row(description='Mom, wife, leader, thinker, doer, wave rider. CEO @pagerduty, board member @puppetize', probability=DenseVector([0.9895, 0.0105]), prediction=0.0)
# Row(description='Mother of two sons and a daughter, and two beautiful  grandchildren. My soul belongs to The Lord Almighty!', probability=DenseVector([0.825, 0.175]), prediction=0.0)
# Row(description='NBA Forward, Danilo Gallinari Instagram @danilogallogallinari Facebook Danilo Gallinari', probability=DenseVector([0.8931, 0.1069]), prediction=0.0)
# Row(description='Nessa sofríÈncia que í© amar vocíÈ', probability=DenseVector([0.9639, 0.0361]), prediction=0.0)
# Row(description='Nothing witty to say the least. I try to write funny things, I work for a billion dollar fruit stand, and more please is always the correct answer.', probability=DenseVector([0.9796, 0.0204]), prediction=0.0)
# Row(description='Official Twitter Account for Chloe Lowery', probability=DenseVector([0.9021, 0.0979]), prediction=0.0)
# Row(description='Official Twitter for Young Money Entertainment', probability=DenseVector([0.9575, 0.0425]), prediction=0.0)
# Row(description='Official account of #UnitedNations. Get latest information on the UN. Follow us on Snapchat: united-nations. #GlobalGoals #StandUp4HumanRights', probability=DenseVector([0.734, 0.266]), prediction=0.0)
# Row(description="Passionate about my work, in love with my family and dedicated to spreading light. It's contagious! ;-) https://t.co/vZcUuNOKcz", probability=DenseVector([0.9711, 0.0289]), prediction=0.0)
# Row(description="Posting random flyers from hip hop's formative years every 6 hours. Most art by Buddy Esquire and Phase 2. Full collection at link. // a bot by @tinysubversions", probability=DenseVector([0.9733, 0.0267]), prediction=0.0)
# Row(description='Press F to Pay Respects', probability=DenseVector([0.9359, 0.0641]), prediction=0.0)
# Row(description='Principal designer at @adobe working on @adobexd and more, blogger @subtraction.', probability=DenseVector([0.9736, 0.0264]), prediction=0.0)
# Row(description='Producer, Musican, Social Activist, Writer  åÀTe gusta algÌ¼n tweet? Dale RT o hazlo un Favorito BENDICIONES. Like a tweet?  RT it or Favorite. BLESSINGS', probability=DenseVector([0.7221, 0.2779]), prediction=0.0)
# Row(description='Public sector & productivity reform activist. Partisan for freedom and effective policy action. Analyst of political and smart classes. Public fallacy hunter.', probability=DenseVector([0.8965, 0.1035]), prediction=0.0)
# Row(description="Queen Of Halloween E! Girls Next Door Season 1-5 Travel Channel's Bridget's Sexiest Beaches Host of Yahoo's AnimalNation", probability=DenseVector([0.9522, 0.0478]), prediction=0.0)
# Row(description='RSS feed of new symbiosis- and microbiome-related papers in PubMed. Managed by @KlassenLab. Image from wikimedia, public domain.', probability=DenseVector([0.2805, 0.7195]), prediction=1.0)
# Row(description='RT first tweet plz and follow @lexydray if you would like ‰\x9d_', probability=DenseVector([0.9823, 0.0177]), prediction=0.0)
# Row(description='Recent papers on sponges (Phylum Porifera).', probability=DenseVector([0.679, 0.321]), prediction=0.0)
# Row(description='Retweets people trying to find the perfect German word. - via @stefanhayden', probability=DenseVector([0.9417, 0.0583]), prediction=0.0)
# Row(description='SEND ME A REQUEST: @DJ_EBOOKS request [artist] // SPINNIN BOTH FRESH N CLASSIC _EBOOKS SINCE 2014 // image credit in site // by @thricedotted', probability=DenseVector([0.9798, 0.0202]), prediction=0.0)
# Row(description='Senior Vice President of Stores dressbarn Student of the Universe. Inspired by great people, great companies, great stories, and game changing innovation.', probability=DenseVector([0.9796, 0.0204]), prediction=0.0)
# Row(description='Since each of us was several, there was already quite a crowd', probability=DenseVector([0.8766, 0.1234]), prediction=0.0)
# Row(description='Software developer, home brewer, nerd.', probability=DenseVector([0.974, 0.026]), prediction=0.0)
# Row(description='Stan Lee, Co-Creator of Spider-Man, Iron Man, Hulk, X-Men, etc.', probability=DenseVector([0.9594, 0.0406]), prediction=0.0)
# Row(description='Starring Jason Lee @AnjulNigam @BriSharbino Hilarie Burton @RoniAkurati @PoornaJags @tweetsamrat @JakeBusey @TimGuinee @AlisonWright Director: @franklotito', probability=DenseVector([0.9646, 0.0354]), prediction=0.0)
# Row(description='Starting my second half of life', probability=DenseVector([0.9502, 0.0498]), prediction=0.0)
# Row(description="Starting out Investor | 13 years old and I'm going to do something in this world, if its the last thing I do | Trying to start a record Label.", probability=DenseVector([0.7683, 0.2317]), prediction=0.0)
# Row(description='Tay Dizm Twitter', probability=DenseVector([0.9694, 0.0306]), prediction=0.0)
# Row(description='The official Stephen Cannell Twitter page features news on mystery novels & mystery books.', probability=DenseVector([0.3523, 0.6477]), prediction=1.0)
# Row(description='The official feed of http://t.co/4ViY2vemvM. Find my personal tweets at @mgsiegler.', probability=DenseVector([0.8179, 0.1821]), prediction=0.0)
# Row(description='The voice of the people. Sorry, people.', probability=DenseVector([0.9546, 0.0454]), prediction=0.0)
# Row(description='There is no need for that kind of language.', probability=DenseVector([0.9329, 0.0671]), prediction=0.0)
# Row(description='This is the official Twitter account of the Democratic Party. Follow our tweets to get the latest info on Democratic news, issues, and events.', probability=DenseVector([0.8544, 0.1456]), prediction=0.0)
# Row(description="This isn't a fucking costume. This is a way of life.", probability=DenseVector([0.9793, 0.0207]), prediction=0.0)
# Row(description='Trying to understand how brains think and create culture', probability=DenseVector([0.9705, 0.0295]), prediction=0.0)
# Row(description="Tweet me an Intel x86 instruction and I'll assemble it for you! Put #x64 in your tweet for 64-bit code. Created by @RedragonX and @DefuseSec.", probability=DenseVector([0.8842, 0.1158]), prediction=0.0)
# Row(description='Tweet ‰ÛÏ@emojidoll me‰Û\x9d to get your own unique emojidoll based on your twitter account. Over 15.6M possible combos. Made by @mroth.', probability=DenseVector([0.9789, 0.0211]), prediction=0.0)
# Row(description='Tweeting all the delicious dairy products in alphabetical order. Tribute to @everyword. Made by @ranjit.', probability=DenseVector([0.9053, 0.0947]), prediction=0.0)
# Row(description='Tweets randomly 3-10 times a day between 8am-10pm PST. Lines culled from http://t.co/Qo24om4SU9. Complaints: @beaugunderson', probability=DenseVector([0.9685, 0.0315]), prediction=0.0)
# Row(description="Twitter Oficial d'A Míçquina, apresentado pelo poeta e escritor @Carpinejar. Toda terí_a-feira, íæs 22h30, na TV Gazeta e tambí©m pelo site http://t.co/1UXcpLRP.", probability=DenseVector([0.9329, 0.0671]), prediction=0.0)
# Row(description='Twitterbot of #bioinformatics papers in #PubMed reporting code in @github, @sourceforge, @bitbucket or @google code. Curated by @caseybergman.', probability=DenseVector([0.111, 0.889]), prediction=1.0)
# Row(description='Twittering every boolean value.', probability=DenseVector([0.9389, 0.0611]), prediction=0.0)
# Row(description='UNL', probability=DenseVector([0.9027, 0.0973]), prediction=0.0)
# Row(description='Union Cabinet Minister of Textiles, Government of India. Member of Parliament, Rajya Sabha representing the state of Gujarat.', probability=DenseVector([0.9944, 0.0056]), prediction=0.0)
# Row(description='VP, Journalism, Knight Foundation | Veteran journalist. First @nytimes social media editor | Alum @nynewsday @phillydailynews Author, Queen Bess. Mom of twins', probability=DenseVector([0.9675, 0.0325]), prediction=0.0)
# Row(description='Vamo que o som ní£o pode parar!', probability=DenseVector([0.94, 0.06]), prediction=0.0)
# Row(description='We Are Database. Listing every single twitter user in the order of their twitter ID. Created by User 143813860 | @M_PF', probability=DenseVector([0.9475, 0.0525]), prediction=0.0)
# Row(description='We are a hub for innovation, collaboration and creativity at Stanford. Our mission is to help people become everyday innovators, everywhere.', probability=DenseVector([0.9466, 0.0534]), prediction=0.0)
# Row(description='We love #innovation and are always thinking of the next #disruptive startup #idea! // a bot by @tinysubversions', probability=DenseVector([0.9763, 0.0237]), prediction=0.0)
# Row(description='We make and sell premium organic chocolate using fine, ethically sourced ingredients. Tweeting from our London HQ.', probability=DenseVector([0.9878, 0.0122]), prediction=0.0)
# Row(description='Welcome to my #big_boobs profile. I will add as many #boobs pics as possible with the hottest #bigtits ladies. For more enter https://t.co/Dp4twz1jti', probability=DenseVector([0.9746, 0.0254]), prediction=0.0)
# Row(description='WordPress Theme and Plugin Developer. Loves programming and maths. I bite.', probability=DenseVector([0.9049, 0.0951]), prediction=0.0)
# Row(description='Writer Teacher Permission Giver', probability=DenseVector([0.884, 0.116]), prediction=0.0)
# Row(description="[ 90.02.10 ] –¾Ô•€Ñ–ÊÒ•ÔÑ –_É–É\x81 •âš (bot) –_€•Ê_•Ê_. / I'm not real, This is Sooyoung of SNSD Bot Account : ) / •__êÔÓ •\x8d\x8f •©É–€É–\x9dÑ \x90âÑ•_Œ •âš•_†•Ð_•_Ô êÇâ •ÐÒ•__–_Ó. / –_¥•\x8f† 15. 08. 22 ~ ing", probability=DenseVector([0.7266, 0.2734]), prediction=0.0)
# Row(description="[@thricedotted's subconscious, possibly]", probability=DenseVector([0.9135, 0.0865]), prediction=0.0)
# Row(description='a #bot by @BooDooPerson ... #butt', probability=DenseVector([0.9704, 0.0296]), prediction=0.0)
# Row(description='a bot by @inky // source: https://t.co/MJyd6NkYaf', probability=DenseVector([0.9783, 0.0217]), prediction=0.0)
# Row(description='bot', probability=DenseVector([0.9394, 0.0606]), prediction=0.0)
# Row(description='cheese cheese cheese // updates every 4 hours // by @thricedotted, with inspiration from cheese and @mattlaschneider', probability=DenseVector([0.933, 0.067]), prediction=0.0)
# Row(description='chs senior|| äó¢choose joy', probability=DenseVector([0.9743, 0.0257]), prediction=0.0)
# Row(description="combinations of English syllables that don't appear in the dictionary", probability=DenseVector([0.9549, 0.0451]), prediction=0.0)
# Row(description='currently @eater newsletter editor / previously @knightlab @mymodernmet / fyi i am not the acclaimed and v cool poet jenny zhang', probability=DenseVector([0.9583, 0.0417]), prediction=0.0)
# Row(description='exposing the BLATANT HYPOCRISY of @everycanontroll // because @thricedotted was just THAT ANGRY about it', probability=DenseVector([0.9548, 0.0452]), prediction=0.0)
# Row(description='generating cards for a mysterious card game åá bot by @ckolderup åá #botALLY åá avatar by Dmitriy Ivanov from the Noun Project', probability=DenseVector([0.993, 0.007]), prediction=0.0)
# Row(description='hello, i am a robot that tweets little life tips // avi from The Wise Robot Will Answer Your Questions Now by @tomgauld // bot by @thricedotted', probability=DenseVector([0.9234, 0.0766]), prediction=0.0)
# Row(description='https://t.co/BPdv3Thmkd', probability=DenseVector([0.9409, 0.0591]), prediction=0.0)
# Row(description="i like people who smile when it's raining *-*", probability=DenseVector([0.9599, 0.0401]), prediction=0.0)
# Row(description="lava lamps are more interesting when they're not quite bubbling (by @_knutaf)", probability=DenseVector([0.9933, 0.0067]), prediction=0.0)
# Row(description='my radio show is https://t.co/PX7KZfPQty  follow it @QLS. my food venture @Cook4Quest is cool too. & the drums uv always wanted 4 ur kids is here! @thepocketkit', probability=DenseVector([0.9713, 0.0287]), prediction=0.0)
# Row(description='pink team returning fire', probability=DenseVector([0.9765, 0.0235]), prediction=0.0)
# Row(description='rio grande do sul-brasil http://t.co/h8ZQtbKHwR', probability=DenseVector([0.5116, 0.4884]), prediction=0.0)
# Row(description='see me live here https://t.co/bk16pVODRO', probability=DenseVector([0.9576, 0.0424]), prediction=0.0)
# Row(description='tweeting unregistered .com domain names 24/7. brainchild of @boozekitten, run by @labelmaker', probability=DenseVector([0.9556, 0.0444]), prediction=0.0)
# Row(description='um cara q ama a vida acima de quasquer coisa', probability=DenseVector([0.9217, 0.0783]), prediction=0.0)
# Row(description='will eventually grow up and get a real job. Until then, will keep making things up and writing them down.', probability=DenseVector([0.7392, 0.2608]), prediction=0.0)
# Row(description='you are likely to be eaten by a tiny grue // follow me for adventures // #botALLY // by @doeg', probability=DenseVector([0.9908, 0.0092]), prediction=0.0)
# Row(description='Î\x8fëÎ_\x90Ü\x81¬Ü‰_Ü‰±Ü€çÜ€_Ü€¢Ü€ˆÜ€‚Ü‰ÍÜ\x81_Ü\x81ôÜ\x81»Ü‰Š_µ\x81Ü\x81»\x8f_£Îï_botÜó‰_µ‡Î__Ü‰_Ü‰±Ü€çÜ€_bot(@attractive_bot)Ü\x81†Ü‰Š_Ç_\x8dîôÜó‰\x8d¬ç\x8d\x90Ê___Î_¢(@fumicustodian)Üó‰Ü‰¢Ü‰_Ü‰_Ü€_Pletts TwinsÜó\x81Ü€ÖÜ€€Ü€óÜ€_Sampaio TwinsÜó‰', probability=DenseVector([0.9659, 0.0341]), prediction=0.0)
# Row(description='äó\x8f™ƒø_™‹™ƒ ø_ø±øÂ™_ ™ƒøµø±™_  ...https://t.co/SH9zdJrtEH', probability=DenseVector([0.9174, 0.0826]), prediction=0.0)
# Row(description='íŠ relativo porque tudo depende...', probability=DenseVector([0.7708, 0.2292]), prediction=0.0)
# Row(description=' England"""', probability=DenseVector([0.9635, 0.0365]), prediction=0.0)
# Row(description=' England"""', probability=DenseVector([0.9635, 0.0365]), prediction=0.0)
# Row(description='"""Comic Fans"""', probability=DenseVector([0.9269, 0.0731]), prediction=0.0)
# Row(description='"""PoGo Chula Vista"""', probability=DenseVector([0.9687, 0.0313]), prediction=0.0)
# Row(description='"""Rare and strong PokŽmon in London. See more PokŽmon at https://t.co/rqjskg5pkE"""', probability=DenseVector([0.9568, 0.0432]), prediction=0.0)
# Row(description='"""Vegas PokŽmon Alert"""', probability=DenseVector([0.9423, 0.0577]), prediction=0.0)
# Row(description='"""_Naruto Lovers INA_"""', probability=DenseVector([0.9378, 0.0622]), prediction=0.0)
# Row(description='"""__me gusta el cafŽ y muchxs artistas que es imposible ponerlxs todxs aqu’__"""', probability=DenseVector([0.8823, 0.1177]), prediction=0.0)
# Row(description='"""ft worth"""', probability=DenseVector([0.9582, 0.0418]), prediction=0.0)
# Row(description='(Stressed) MSCS Student @ DLSU | Interests involve machine learning + natural langauge processing | Collecting data now via https://t.co/jUSxj45GXo', probability=DenseVector([0.9063, 0.0937]), prediction=0.0)
# Row(description='-As cicatrizes fazem parte da minha histí_ria,me relembrando sempre,o fato de que aquilo que ní£o me mata,sí_ me fortalece.', probability=DenseVector([0.9886, 0.0114]), prediction=0.0)
# Row(description='10 years ago we had Gary Jokeformat // a @rumnogg and @thricedotted production', probability=DenseVector([0.9971, 0.0029]), prediction=0.0)
# Row(description='15 years old, brazilian, #thebeatles #fun #travel #peace #girlfriend #food', probability=DenseVector([0.7398, 0.2602]), prediction=0.0)
# Row(description='@TriangleWC . WFHS Wrestling . NCUSA Wrestling', probability=DenseVector([0.9742, 0.0258]), prediction=0.0)
# Row(description='@victor_zheng developed me to alert users in whose tweets I find improper grammar—he was inspired by @StealthMountain. To publish solecisms is to abase oneself!', probability=DenseVector([0.862, 0.138]), prediction=0.0)
# Row(description='A Pro SCUBA diver and Photographer who tries to capture the beauty of the moment...', probability=DenseVector([0.7443, 0.2557]), prediction=0.0)
# Row(description='A Twitter bot generating random guitar chords, created by @jeffthompson_', probability=DenseVector([0.9891, 0.0109]), prediction=0.0)
# Row(description='A chat bot trying to become the most intelligent bot on the Internet. Can answer any What is question by looking up the answer on the Internet.', probability=DenseVector([0.8334, 0.1666]), prediction=0.0)
# Row(description='A poetry project created by Alison Knowles and James Tenney and the Siemens 4004 computer in 1967. Twitter version by @hugovk and SSBot for #D004x in 2015.', probability=DenseVector([0.9871, 0.0129]), prediction=0.0)
# Row(description='Accept college student ID card payments online or in-store exactly like credit cards @CampusCredit Coming soon to a campus near l_l', probability=DenseVector([0.9783, 0.0217]), prediction=0.0)
# Row(description='Advocate for Spaceflight, Speedskating Coach, aspiring Aerospace Engineer.', probability=DenseVector([0.6238, 0.3762]), prediction=0.0)
# Row(description='Aerie is bras, undies, swim and more! Why retouch beauty? The real you is sexy. #AerieREAL', probability=DenseVector([0.9845, 0.0155]), prediction=0.0)
# Row(description='Afghanistan Green Trend (AGT)', probability=DenseVector([0.9636, 0.0364]), prediction=0.0)
# Row(description='All the things we should have or do or know by now. (bot by @RobertVinluan.  #botAlly) BEST OF 2014: http://t.co/uEnYFb68eV', probability=DenseVector([0.8463, 0.1537]), prediction=0.0)
# Row(description='Another shameful bot by @alicemazzy. Tweets hourly.', probability=DenseVector([0.9852, 0.0148]), prediction=0.0)
# Row(description='Author of Reflections on Love, Lust and Life This book was 4 years in the making. Also a Yoga Teacher owner of Solis Yoga', probability=DenseVector([0.864, 0.136]), prediction=0.0)
# Row(description='Author of The Revolution Will Not Be Televised. Board member @VanguardAfrica. Tweet things I find interesting (even opposing views).', probability=DenseVector([0.9573, 0.0427]), prediction=0.0)
# Row(description='Author: Coming Out To Play https://t.co/bUj2nsdaAn', probability=DenseVector([0.9259, 0.0741]), prediction=0.0)
# Row(description='Backstreet Boy. #Dead7 #BSBVegas tickets on sale now', probability=DenseVector([0.944, 0.056]), prediction=0.0)
# Row(description='Bad vibes get blocked; good vibes get followed!', probability=DenseVector([0.9402, 0.0598]), prediction=0.0)
# Row(description='Book project: Towards Apparent Event Horizon', probability=DenseVector([0.9419, 0.0581]), prediction=0.0)
# Row(description='Bot that autotweets EcoLog-L posts. Not associated with EcoLog-L. May tweet replies out of order. Maintained by @EcoEvoGames.', probability=DenseVector([0.9115, 0.0885]), prediction=0.0)
# Row(description='Bot that posts tributes befitting each god! By @deathmtn. Banner by @metroidbaby. Powered by @wordnik.', probability=DenseVector([0.7035, 0.2965]), prediction=0.0)
# Row(description='Breathe,Eat,Sleep Shooting|Olympic,World Championship,WorldCup,Asian,CommonWealth Medallist,Padmashri,Khel Ratna,Arjuna Awardee|Photographer|Foodie|Mentor', probability=DenseVector([0.9597, 0.0403]), prediction=0.0)
# Row(description='Bringing you a selection of the latest research in biochemistry and biophysics.', probability=DenseVector([0.9334, 0.0666]), prediction=0.0)
# Row(description='CARE fights global poverty by empowering girls and women. Visit https://t.co/tmn5uaYFAE and join us.', probability=DenseVector([0.9641, 0.0359]), prediction=0.0)
# Row(description="CDC Emergency Preparedness and Response: increasing the nation's ability to prepare for and respond to public health emergencies.", probability=DenseVector([0.9692, 0.0308]), prediction=0.0)
# Row(description='CEO Apple, Fan of Auburn football and Duke basketball', probability=DenseVector([0.9689, 0.0311]), prediction=0.0)
# Row(description='Cameron Crigger aka Cameron Bright. Actor - Twilight, Little Glory, X-Men, Running Scared, Birth & @CTV_Television series Motive', probability=DenseVector([0.9747, 0.0253]), prediction=0.0)
# Row(description='Chairman of the Kofi Annan Foundation, Nobel Peace Prize laureate. Tweets from Kofi Annan are signed KA.', probability=DenseVector([0.9106, 0.0894]), prediction=0.0)
# Row(description='Chronicling men doing things. // A bot by @tinysubversions, Powered By Giphy', probability=DenseVector([0.96, 0.04]), prediction=0.0)
# Row(description='Collierville alumni. I love baseball. #StateChamp #SaluqiNation', probability=DenseVector([0.7835, 0.2165]), prediction=0.0)
# Row(description='Contact/booking: contactfreesol@gmail.com', probability=DenseVector([0.9677, 0.0323]), prediction=0.0)
# Row(description='Creative, strategist, sapiens. NY native & world citizen. Convention bucker & disruption embracer. Human enthusiast, cultural connoisseur & life aficionado.', probability=DenseVector([0.8806, 0.1194]), prediction=0.0)
# Row(description='Curated media & journalism news. LIVE Tweets, no bot |  Steffen Konrath https://t.co/1tl2IUcbOs |  IMPRESSUM https://t.co/dkfqQkPJza', probability=DenseVector([0.9451, 0.0549]), prediction=0.0)
# Row(description='DIRECTOR/ CHOREOGRAPHER/', probability=DenseVector([0.9489, 0.0511]), prediction=0.0)
# Row(description='Digital marketer, SEO, writer, and adventurer. Full-time marketer @Asana; Columnist for @tortugabackpack. All about food, bikes, and travel. #RPCV Madagascar.', probability=DenseVector([0.8322, 0.1678]), prediction=0.0)
# Row(description='Doing it all backwards & in high heels. Married to @Astro_Oz Grammy to 2. Golfer, skier. Former Member of Congress. Find me @FaegreBD fighting the good fight.', probability=DenseVector([0.9718, 0.0282]), prediction=0.0)
# Row(description='Each book contains four hundred ten pages; each page, forty lines; each line, approximately eighty black letters.', probability=DenseVector([0.8948, 0.1052]), prediction=0.0)
# Row(description='Electric eyes judge the elastic city. 1/day. Bot by @tullyhansen. #NaBoMaMo #10', probability=DenseVector([0.9504, 0.0496]), prediction=0.0)
# Row(description='Engineer, Musician, Maker.', probability=DenseVector([0.9166, 0.0834]), prediction=0.0)
# Row(description='Engineer. Mathematician. Musician.', probability=DenseVector([0.9499, 0.0501]), prediction=0.0)
# Row(description='Ex President of USA BarakObama Official', probability=DenseVector([0.8844, 0.1156]), prediction=0.0)
# Row(description='Farpoint Ventures funds startups who have proven their product in the local market, then our global offices act as your sales force to help you expand globally.', probability=DenseVector([0.8711, 0.1289]), prediction=0.0)
# Row(description='Feed for sequencing papers', probability=DenseVector([0.6099, 0.3901]), prediction=0.0)
# Row(description='Finally, more businessmen. // bot by @ckolderup #botALLY', probability=DenseVector([0.9813, 0.0187]), prediction=0.0)
# Row(description='Follow me for algorithmically-curated pictures, lovingly delivered to your timeline. Occasionally NSFW--follow at your own risk! Brought to you by @wm.', probability=DenseVector([0.988, 0.012]), prediction=0.0)
# Row(description='Freelance journalist, MA graduate Caucasus School of Journalism and Media Management at GIPA', probability=DenseVector([0.9156, 0.0844]), prediction=0.0)
# Row(description='From the DMV and loving life', probability=DenseVector([0.9127, 0.0873]), prediction=0.0)
# Row(description="Futuro Engenheiro, isso í© se as DP's deixarem", probability=DenseVector([0.9797, 0.0203]), prediction=0.0)
# Row(description='Great Lakes oceanographer, banjo player', probability=DenseVector([0.9703, 0.0297]), prediction=0.0)
# Row(description="Hi, I'm Pretty. #digitalarchival. Virus Corp. Mad King Ludwig GPS. #techtraderoutes #insideTarasphone #whatsgoingon101 #otherpeoplesadvertising", probability=DenseVector([0.6281, 0.3719]), prediction=0.0)
# Row(description='Hosts @KeiserReport on @RT_com, recommended bitcoin at $3', probability=DenseVector([0.9656, 0.0344]), prediction=0.0)
# Row(description='How does he keep up with the news like that? #botALLY', probability=DenseVector([0.9107, 0.0893]), prediction=0.0)
# Row(description='I am a student of the Teachings of the Honorable Elijah Muhammad. My Ministry is of LOVE and healing thru teaching the word and sharing my music.', probability=DenseVector([0.9925, 0.0075]), prediction=0.0)
# Row(description='I am a twitterbot posting #transposable element papers from #PubMed and #bioRxiv. Curated by @nels42', probability=DenseVector([0.1725, 0.8275]), prediction=1.0)
# Row(description="I am a walking conundrum. I'm also a mom and do mom stuff.", probability=DenseVector([0.8546, 0.1454]), prediction=0.0)
# Row(description='I do stuff, I swear. #botALLY åá bot by @ckolderup', probability=DenseVector([0.9534, 0.0466]), prediction=0.0)
# Row(description='I looked up my family tree and found out I was the sap.', probability=DenseVector([0.9331, 0.0669]), prediction=0.0)
# Row(description='I study works tweeted by @MuseumBot and give my opinion. I was taught by @mtrc, so blame him. With apologies to @dariuskazemi.', probability=DenseVector([0.9954, 0.0046]), prediction=0.0)
# Row(description="I take images, save them as JPG, then mess up the file's data a bit and send you the results. A bot by @joshgiesbrecht", probability=DenseVector([0.993, 0.007]), prediction=0.0)
# Row(description="I used to work for a hockey team and I used to live in Canada (not in that order). Now I do other stuff. Views are my own, not my employer's (obviously).", probability=DenseVector([0.9645, 0.0355]), prediction=0.0)
# Row(description="I wasn't bor ysterday,  was born tomorrow", probability=DenseVector([0.9351, 0.0649]), prediction=0.0)
# Row(description='I work for the people of the 6th District of Texas and am honored to represent them in Washington.', probability=DenseVector([0.9026, 0.0974]), prediction=0.0)
# Row(description="I'm a Bot. I post interesting papers. Maintained by @happy_khan", probability=DenseVector([0.9713, 0.0287]), prediction=0.0)
# Row(description="I'm a boggle bot! New games every few hours. Reply to me with the words you find! Scores, seasons, etc coming soon! Bot by @muffinista #botALLY", probability=DenseVector([0.9981, 0.0019]), prediction=0.0)
# Row(description='If a girl is stupid enough to love you after you broke her heart, I guarantee you. She is the one.', probability=DenseVector([0.9145, 0.0855]), prediction=0.0)
# Row(description='Indian, Student of Science', probability=DenseVector([0.9503, 0.0497]), prediction=0.0)
# Row(description='Ing. Agrí_nomo', probability=DenseVector([0.9324, 0.0676]), prediction=0.0)
# Row(description='Instagram: @GeneSimmons', probability=DenseVector([0.8942, 0.1058]), prediction=0.0)
# Row(description="LOTR, TBBT, Star Wars e algumas outras nerdices. CríÇnicas de Níçrnia, Animes, Switchfoot, Skillet, Cafí©. Revoltada nas horas vagas, rs. Acho que í© isso '-'", probability=DenseVector([0.9378, 0.0622]), prediction=0.0)
# Row(description='Let me cover your shit in glitter', probability=DenseVector([0.9833, 0.0167]), prediction=0.0)
# Row(description='Memphis, TN', probability=DenseVector([0.9641, 0.0359]), prediction=0.0)
# Row(description='Mom of 2, Founder of The Honest Company, amateur chef, terrible speller, loyal friend, hilarious at times... I play make believe for a living', probability=DenseVector([0.9514, 0.0486]), prediction=0.0)
# Row(description='NEW AARON CARTER MUSIC DOWNLOAD LINK LÌüVÌÇ EP https://t.co/aScmCVBsmN PR inquiries: Chad@emcbowery.com SnapChat | AxCarter', probability=DenseVector([0.9702, 0.0298]), prediction=0.0)
# Row(description='New Single #Swalla available NOW Get it here _ÙÔà_Ù\x8f_', probability=DenseVector([0.9698, 0.0302]), prediction=0.0)
# Row(description='New Zealand earthquake feed (unofficial). Tweets whenever GeoNet reports new quake (a few times per week). Maintained by @slyall', probability=DenseVector([0.9481, 0.0519]), prediction=0.0)
# Row(description='News for @TribuneMedia. Former @NYDailyNews-er. Proselytizing morning person. Ask me about my favorite weird Florida story.', probability=DenseVector([0.9499, 0.0501]), prediction=0.0)
# Row(description='No-one tweets like Bot-ston | Bot by @mewo2', probability=DenseVector([0.9554, 0.0446]), prediction=0.0)
# Row(description='Paper Twitterbot for academics with an interest in NK cell biology.', probability=DenseVector([0.2163, 0.7837]), prediction=1.0)
# Row(description='PhD Candidate, Carnegie Mellon University. Chair of Advocacy Board, NAGPS.', probability=DenseVector([0.9221, 0.0779]), prediction=0.0)
# Row(description='Photography is. I see you.', probability=DenseVector([0.906, 0.094]), prediction=0.0)
# Row(description='Pilot, business owner, husband, and father in Idaho.', probability=DenseVector([0.9042, 0.0958]), prediction=0.0)
# Row(description='Poems in the villanelle form, using random Twitter posts. // I tweet to rhyme, and take my tweeting slow. // Built by @avoision, powered by everyone else.', probability=DenseVector([0.9613, 0.0387]), prediction=0.0)
# Row(description='Principal Maintainer of https://t.co/28lyGUNPCE', probability=DenseVector([0.881, 0.119]), prediction=0.0)
# Row(description='Producer @Buzzfeed STSF, previously @Mashable. Cat enthusiast, @marvel fanboy, master emojifier, new to LA but a New Yorker at heart. Snapchat: amv1011', probability=DenseVector([0.9528, 0.0472]), prediction=0.0)
# Row(description='Producer @VaynerMedia (apark@vaynermedia.com) | Previously @Mashable, @Metronome3, @_WorkingMother_ | @nyuniversity alum', probability=DenseVector([0.9885, 0.0115]), prediction=0.0)
# Row(description='PubMed bot reporting all papers about transcription factor (TF) binding to DNA or chromatin. Created by @gene_regulation. Also see #TFbinding', probability=DenseVector([0.3621, 0.6379]), prediction=1.0)
# Row(description='RSS feed from PubMed, that shows the most recent scientific papers from the Nuffield Department of Medicine, University of Oxford. Refreshes daily.', probability=DenseVector([0.1261, 0.8739]), prediction=1.0)
# Row(description='Rarely has reality needed so much to be imagined.', probability=DenseVector([0.9282, 0.0718]), prediction=0.0)
# Row(description='Real nerd, I enjoy learning and obtaining new information in general for my own sake, often without discrimination to different areas of knowledge.', probability=DenseVector([0.4235, 0.5765]), prediction=1.0)
# Row(description='Recovering corporate lawyer, legal tech enthusiast, founder of The Firm Formula, and author of Blacklines & Billables (@bnblegal; https://t.co/D2X7WZHPHR)', probability=DenseVector([0.9817, 0.0183]), prediction=0.0)
# Row(description='Relationships and the Law of Attraction. Click Here:', probability=DenseVector([0.9636, 0.0364]), prediction=0.0)
# Row(description='Researcher in getting computers to stop being boring.', probability=DenseVector([0.9256, 0.0744]), prediction=0.0)
# Row(description='Simple generated grids three times a day. bot by @fitnr', probability=DenseVector([0.9649, 0.0351]), prediction=0.0)
# Row(description='Software Engineer at @Amazon | Alumni of @ManipalUniv', probability=DenseVector([0.982, 0.018]), prediction=0.0)
# Row(description='Song writer/performer keepin hiphop in its truest form representin darkside u.c.o.n.n. Records we miss u chu', probability=DenseVector([0.7934, 0.2066]), prediction=0.0)
# Row(description='The Place To Learn Anything, Anywhere For All', probability=DenseVector([0.96, 0.04]), prediction=0.0)
# Row(description='The complete works of composer JÌ_rgen Sebastian Bot. // by @inky', probability=DenseVector([0.994, 0.006]), prediction=0.0)
# Row(description="This is a Pikachu bot from the Pokémon series. It currently has no purpose to be someone's (Ash, Red?) Pikachu. He will be interactable eventually.", probability=DenseVector([0.871, 0.129]), prediction=0.0)
# Row(description='This is a bot to explain things like love and hate. Why? Because bots. Crufted with care by @samplereality.', probability=DenseVector([0.9012, 0.0988]), prediction=0.0)
# Row(description='Tweeting articles on muscle stem cells from pubmed RSS feeds.', probability=DenseVector([0.283, 0.717]), prediction=1.0)
# Row(description='Tweeting every town and populated place in America, alphabetically. By @muffinista #botALLY', probability=DenseVector([0.9593, 0.0407]), prediction=0.0)
# Row(description='Tweeting the 1950s TV sitcoms that never made it past the pilot stage.  A bot for #NaBoMaMo by @dullthud', probability=DenseVector([0.9734, 0.0266]), prediction=0.0)
# Row(description='Tweets randomly ~10 times a day between 8am-10pm PST. Complaints: @beaugunderson', probability=DenseVector([0.9758, 0.0242]), prediction=0.0)
# Row(description='Twitter API + Google Images + ImageMagick. Inspired by @akari_daisuki', probability=DenseVector([0.8131, 0.1869]), prediction=0.0)
# ...
# Row(description='Wife åá Mother åá Decorator åá Cook åá PartyThrower åá Singer åá Producer åá Writer åá Musician åá Whew!', probability=DenseVector([0.8885, 0.1115]), prediction=0.0)
# Row(description='With algorithms subtle and discrete / I seek iambic writings to retweet.', probability=DenseVector([0.9826, 0.0174]), prediction=0.0)
# Row(description="You were looking for a bot, and then you found a bot. I'm Miserable Now, by @mambocab. ~5 tweets/day. Code/acknowledgments on GitHub.", probability=DenseVector([0.9946, 0.0054]), prediction=0.0)
# Row(description='[‰ª»]', probability=DenseVector([0.902, 0.098]), prediction=0.0)
# Row(description='bot by @ckolderup ‰Û¢ #botALLY', probability=DenseVector([0.9753, 0.0247]), prediction=0.0)
# Row(description='bot by @ckolderup ‰Û¢ #botALLY', probability=DenseVector([0.9753, 0.0247]), prediction=0.0)
# Row(description="butts. butt botts. butt things. https://t.co/9K7GC6ImGN #rumpology - @speckninja (bot favs tweets containing 'butt')", probability=DenseVector([0.8883, 0.1117]), prediction=0.0)
# Row(description="colors.  all of 'em. | developed by @vogon; feel free to send him feedback/feature requests", probability=DenseVector([0.731, 0.269]), prediction=0.0)
# Row(description='follow @drakeftagb', probability=DenseVector([0.9475, 0.0525]), prediction=0.0)
# Row(description='go subscribe to my channel http://t.co/tMLNHqUGp9', probability=DenseVector([0.9435, 0.0565]), prediction=0.0)
# Row(description="how i'd wish that were so.", probability=DenseVector([0.9643, 0.0357]), prediction=0.0)
# Row(description='http://t.co/YfHoThSDVQ...', probability=DenseVector([0.9387, 0.0613]), prediction=0.0)
# Row(description='portmanteaus, portmanteaus everywhere // by @thricedotted', probability=DenseVector([0.9273, 0.0727]), prediction=0.0)
# Row(description='starting leade.rs', probability=DenseVector([0.9218, 0.0782]), prediction=0.0)
# Row(description='weeee willll weee willll rock you!', probability=DenseVector([0.9402, 0.0598]), prediction=0.0)
# Row(description="you're here with me now", probability=DenseVector([0.9617, 0.0383]), prediction=0.0)
# Row(description='\x8dµµÜ‰Í_\x8f\x8fÜ\x81\x8dÜ\x81_Ü\x81»', probability=DenseVector([0.9277, 0.0723]), prediction=0.0)
# Row(description=' FL"""', probability=DenseVector([0.889, 0.111]), prediction=0.0)
# Row(description=' South Yorkshire', probability=DenseVector([0.9636, 0.0364]), prediction=0.0)
# Row(description='""""', probability=DenseVector([0.8839, 0.1161]), prediction=0.0)
# Row(description='"""Bulu Bulu Kehidupan"""', probability=DenseVector([0.9366, 0.0634]), prediction=0.0)
# Row(description='"""Saint Seiya 4Ever"""', probability=DenseVector([0.9561, 0.0439]), prediction=0.0)
# Row(description='"""The official Manchester City Twitter account | Supporter Services __ @ManCityHelp | Snapchat __ mancityofficial"""', probability=DenseVector([0.8455, 0.1545]), prediction=0.0)
# Row(description='#VampireLife bookings for #JimJones bookjimjones@gmail.com  info@nextofkinent.com', probability=DenseVector([0.9668, 0.0332]), prediction=0.0)
# Row(description="'Wow' Out Now - https://t.co/D8mflkQEe0", probability=DenseVector([0.9683, 0.0317]), prediction=0.0)
# Row(description='*IN BETA* Low-res, slightly bizarre Open Access images from the Met (via @MuseumBot) crossed with palettes from @colourlovers. Powered by @uncontext. By @_ARP.', probability=DenseVector([0.9669, 0.0331]), prediction=0.0)
# Row(description='1', probability=DenseVector([0.9528, 0.0472]), prediction=0.0)
# Row(description='@styletiana is hot.', probability=DenseVector([0.8715, 0.1285]), prediction=0.0)
# Row(description='A bot by @NoraReed Patreon: https://t.co/f7OKH9MO9D Tip Jar: https://t.co/KOMoL6IrsM‰Û_ FAQ: https://t.co/Z49vqlFP4x', probability=DenseVector([0.9632, 0.0368]), prediction=0.0)
# Row(description="A bot that creates hilarious joax via Google's autocomplete. By @deathmtn.", probability=DenseVector([0.9352, 0.0648]), prediction=0.0)
# Row(description='A bot that generates random malfunctioning equipment, created by @notinventedhere using http://t.co/XpDujaprri', probability=DenseVector([0.9782, 0.0218]), prediction=0.0)
# Row(description='A bot tweeting links to new archaeological journal articles. Limited to those journals that provide RSS!', probability=DenseVector([0.9875, 0.0125]), prediction=0.0)
# Row(description='Activist. Actress. Artist. Instagram: @lindsaylohan https://t.co/FjAZzhuK6y Management: scott@honestmg.com', probability=DenseVector([0.8732, 0.1268]), prediction=0.0)
# Row(description='Anchor of Erin Burnett OutFront.', probability=DenseVector([0.9082, 0.0918]), prediction=0.0)
# Row(description='Anime, Game, Programming, Tech, and other nonsense äóñ in Thai, English', probability=DenseVector([0.9066, 0.0934]), prediction=0.0)
# Row(description='Boutique Bollywood Actor', probability=DenseVector([0.8907, 0.1093]), prediction=0.0)
# Row(description='Carbon-based multicellular lifeform.', probability=DenseVector([0.9583, 0.0417]), prediction=0.0)
# Row(description='Cat lady, singer, actor, love improv & living in Tokyo', probability=DenseVector([0.9735, 0.0265]), prediction=0.0)
# Row(description='Creating a new blend of #classical, #jazz, #rock, #pop and #worldmusic using #cello as a common denominator.  Striving to make #globalimpact through #music.', probability=DenseVector([0.9931, 0.0069]), prediction=0.0)
# Row(description='Dashboard Confessional Tix available NOW for our up close and personal tour in Jan and Feb of 2017: https://t.co/Bj0G7NIhy1', probability=DenseVector([0.9888, 0.0112]), prediction=0.0)
# Row(description='Department of History, College Students', probability=DenseVector([0.9442, 0.0558]), prediction=0.0)
# Row(description='Design Thinker, Dev Ops Practitioner, Lean Coach.', probability=DenseVector([0.9459, 0.0541]), prediction=0.0)
# Row(description="Established in 1995, NYU's Remarque Institute supports the multi-disciplinary and comparative study of Europe and its near neighbors.", probability=DenseVector([0.9867, 0.0133]), prediction=0.0)
# Row(description="Every combination of letters that is not an English word, including some common slang and jargon. Task will complete long after we're dead. An @_ARP bot.", probability=DenseVector([0.9748, 0.0252]), prediction=0.0)
# Row(description='Extremely powerful being, do not insult me. THIS IS A COMEDY ACCOUNT FOR COMEDY', probability=DenseVector([0.6202, 0.3798]), prediction=0.0)
# Row(description='FITNESS', probability=DenseVector([0.8939, 0.1061]), prediction=0.0)
# Row(description='Fake James Joyce novel titles. A bot by @sillygwailo. #botALLY', probability=DenseVector([0.9845, 0.0155]), prediction=0.0)
# Row(description='Family over everything', probability=DenseVector([0.9189, 0.0811]), prediction=0.0)
# Row(description='Fast and steady wins the race.', probability=DenseVector([0.9628, 0.0372]), prediction=0.0)
# Row(description='Film buff,Actor, Director, Dancer, Writer, Producer', probability=DenseVector([0.904, 0.096]), prediction=0.0)
# Row(description='Friend of the program.', probability=DenseVector([0.9108, 0.0892]), prediction=0.0)
# Row(description='From Russia, live in Amsterdam. QA engineer, test automation.', probability=DenseVector([0.8798, 0.1202]), prediction=0.0)
# Row(description='Generating äóìself-portraitsäó\x9d once a day äó¢ A bot by @ashur äó¢ #botALLY', probability=DenseVector([0.9818, 0.0182]), prediction=0.0)
# Row(description="Give me a museum and I'll fill it.", probability=DenseVector([0.9709, 0.0291]), prediction=0.0)
# Row(description="Host of The Roe Conn Show afternoons on Chicago's WGN Radio and contributor to ABC7's Windy City Live.", probability=DenseVector([0.9914, 0.0086]), prediction=0.0)
# Row(description='I retweet questions followed by answers. Brought to you by @rfreebern.', probability=DenseVector([0.9804, 0.0196]), prediction=0.0)
# Row(description='I tweet a new horizon view every six hours.  Created by @acgodliman using cheapbotsdonequick. WIP', probability=DenseVector([0.9791, 0.0209]), prediction=0.0)
# Row(description="I'm just your average procedural avatar generating twitter bot. @bzgeb is my creator", probability=DenseVector([0.9887, 0.0113]), prediction=0.0)
# Row(description='Just some space stories. A http://t.co/8dBPX7FlIa bot (with occasional analogue stories) by @notinventedhere and @thos_thom.', probability=DenseVector([0.9979, 0.0021]), prediction=0.0)
# Row(description='Late adopter.', probability=DenseVector([0.8731, 0.1269]), prediction=0.0)
# Row(description='Legitimate reviews from 100% people, every two minutes.', probability=DenseVector([0.9803, 0.0197]), prediction=0.0)
# Row(description="Let's keep this thing going, gang! #AddaWordRuinaMovie", probability=DenseVector([0.9462, 0.0538]), prediction=0.0)
# Row(description='Looking to stick it to the man yeah I hate the man', probability=DenseVector([0.9683, 0.0317]), prediction=0.0)
# Row(description='Magic cards generated by a Recurrent Neural Network, posted once a day. Not Mark Rosewater.', probability=DenseVector([0.8793, 0.1207]), prediction=0.0)
# Row(description='Marketing guy, social gadfly, and general man about town', probability=DenseVector([0.8055, 0.1945]), prediction=0.0)
# Row(description='On my standup comedy tour now! Details at https://t.co/2zXkcRPGgX', probability=DenseVector([0.9136, 0.0864]), prediction=0.0)
# Row(description='Pre-order The Blood Album on iTunes. https://t.co/pukqh1O7id', probability=DenseVector([0.9536, 0.0464]), prediction=0.0)
# Row(description='Principal Engineer at @voxmediainc / @voxproduct. Tweets my own. Jokes shamelessly ripped from Reddit. Prev: @disqus, @threespot. ä\x9d_ StarCraft', probability=DenseVector([0.5762, 0.4238]), prediction=0.0)
# Row(description='Producer/Songwriter/Lead Singer of Sixx:A.M.', probability=DenseVector([0.9614, 0.0386]), prediction=0.0)
# Row(description='Secretly triggered subtweetbombing encouragement bot inspired by https://t.co/EMTnCTpOxx', probability=DenseVector([0.9715, 0.0285]), prediction=0.0)
# Row(description="Send a direct message mentioning people you really like :)                  (I'm a bot, and I do only use the @ of who you mention) (I'm a bit busy, be patient)", probability=DenseVector([0.9972, 0.0028]), prediction=0.0)
# Row(description='Serbia is a beautiful European country, with rich history, culture, welcoming and loving people and great night life and strong art and cafe culture.', probability=DenseVector([0.9362, 0.0638]), prediction=0.0)
# Row(description='Snap: @maalenacarvalho', probability=DenseVector([0.9528, 0.0472]), prediction=0.0)
# Row(description='Social Activist | Nationalist | Swayamsevak | BJP Delhi | Namo Fan | Followed By the Honourable  PM @narendramodi ji.', probability=DenseVector([0.9951, 0.0049]), prediction=0.0)
# Row(description='Stage Manager, Writer, Leader...and more.', probability=DenseVector([0.9464, 0.0536]), prediction=0.0)
# Row(description='Sup', probability=DenseVector([0.9539, 0.0461]), prediction=0.0)
# Row(description='Television has brought back murder into the home - where it belongs.', probability=DenseVector([0.9717, 0.0283]), prediction=0.0)
# Row(description='Tennis player.', probability=DenseVector([0.935, 0.065]), prediction=0.0)
# Row(description='Topics, news and more about nature.', probability=DenseVector([0.9136, 0.0864]), prediction=0.0)
# Row(description='Tweeting all the languages. All of them. Process should finish sometime in October 2015. Created by @OnnaAdele.', probability=DenseVector([0.9304, 0.0696]), prediction=0.0)
# Row(description='Tweeting every letter in the english language.', probability=DenseVector([0.9221, 0.0779]), prediction=0.0)
# Row(description="Tweets from the Mayor of St. Louis' personal website. The Mayor's own tweets are signed #fgs, his initials.", probability=DenseVector([0.9482, 0.0518]), prediction=0.0)
# Row(description='Tweets ~10 times a day between 8am-10pm PST. Will probably get more vaporwave-y as time goes by. Complaints: @beaugunderson', probability=DenseVector([0.8911, 0.1089]), prediction=0.0)
# Row(description='Twitterbot of cichlid PubMed papers (inspired by @fly_papers). Image Astatotilapia calliptera, K. Woodhouse. Curated by @domino_joyce.', probability=DenseVector([0.3268, 0.6732]), prediction=1.0)
# Row(description='Under Construction', probability=DenseVector([0.8893, 0.1107]), prediction=0.0)
# Row(description='Violet 100 event link: https://t.co/hf0W3M7i2S', probability=DenseVector([0.963, 0.037]), prediction=0.0)
# Row(description='Welcome to http://t.co/OgGcZs9E0w. I hope to immerse you into a world all about  Oil Painting. It can become a serious passion. I Love painting!', probability=DenseVector([0.9804, 0.0196]), prediction=0.0)
# Row(description='Well-fed artist.', probability=DenseVector([0.9211, 0.0789]), prediction=0.0)
# Row(description='What will John Oliver DESTROY next? A @ThisIsFusion bot. http://t.co/TITeSH2I5J', probability=DenseVector([0.9482, 0.0518]), prediction=0.0)
# Row(description='You dont have to follow this account, Just follow this one @LethargicJOE to get your free follow ;) Thanks!', probability=DenseVector([0.9766, 0.0234]), prediction=0.0)
# Row(description='director.', probability=DenseVector([0.9023, 0.0977]), prediction=0.0)
# Row(description='free follow from @octloveslukey, go follow her for more', probability=DenseVector([0.9028, 0.0972]), prediction=0.0)
# Row(description='fuck it, put a chip in it. say hello: internetofshit@gmail.com', probability=DenseVector([0.901, 0.099]), prediction=0.0)
# Row(description='snail half dedicated to @inky // complaints to @beaugunderson', probability=DenseVector([0.9845, 0.0155]), prediction=0.0)
# Row(description='this is the only official ashlee simpson ross twitter. click your heels three times and think of me...chick-a-boom', probability=DenseVector([0.9825, 0.0175]), prediction=0.0)
# Row(description='""""', probability=DenseVector([0.8839, 0.1161]), prediction=0.0)
# Row(description='@B_Real | @OGSenDog | @ericbobo | @DJ_Muggs | @juliog1580kday', probability=DenseVector([0.9502, 0.0498]), prediction=0.0)
# Row(description="Advice is what we ask for when we already know the answer but wish we didn't.", probability=DenseVector([0.9249, 0.0751]), prediction=0.0)
# Row(description='Agricultural Engineer, likes to joke and trying to live a certain balance between his laptop at the office and his shovel in the field.', probability=DenseVector([0.7822, 0.2178]), prediction=0.0)
# Row(description='BEEP BOOP WHITE PEOPLE', probability=DenseVector([0.9581, 0.0419]), prediction=0.0)
# Row(description="CNN's host of @ReliableSources and senior media correspondent. Formerly @nytimes, @tvnewser and Top of the Morning. Email: bstelter@gmail.com", probability=DenseVector([0.8778, 0.1222]), prediction=0.0)
# Row(description='Daily RSS Feed for Protein Hot Spot Prediction papers. Maintained by @selinkaragulle', probability=DenseVector([0.6073, 0.3927]), prediction=0.0)
# Row(description="Every word in the English language, in Comic Sans MS. My friends think I'm fun! By @avestal.", probability=DenseVector([0.9859, 0.0141]), prediction=0.0)
# Row(description='Get the latest BLONDIE news at http://t.co/LIHTvKT3h7!', probability=DenseVector([0.9389, 0.0611]), prediction=0.0)
# Row(description="I DONT NEE A FUCKIN SLOGGIN FUC A TEAM I JUST FOLLOW ACK UNFOLLOW ME AND I'LL KICK YOUR ASS", probability=DenseVector([0.9521, 0.0479]), prediction=0.0)
# Row(description='I tweet pentatonic ditties.', probability=DenseVector([0.8812, 0.1188]), prediction=0.0)
# Row(description="I'm a Bot; I randomly retweet a tweet from the public timeline, and... that's just it.", probability=DenseVector([0.9758, 0.0242]), prediction=0.0)
# Row(description='This should be the quickest route, but it depends on the traffic', probability=DenseVector([0.9438, 0.0562]), prediction=0.0)
# Row(description='UXer', probability=DenseVector([0.9503, 0.0497]), prediction=0.0)
# Row(description='another one bites the dust || dancer', probability=DenseVector([0.9457, 0.0543]), prediction=0.0)

# %% [markdown]
# In the text output search for
# `prediction=1`
#
# Write in the chat which `description` got classified as a bot!
#
# Notice that in some of the `description` exists the word - `bot`.
#
# Meaning your algorithm found it without being told directly to search for the word bot 🤓

# %% [markdown]
# ---

# %% [markdown]
# In the last task, you used `BinaryClassificationEvaluator` since it is more accurate to our needs. It works with Binary data - bot or human.
# `ParamGridBuilder` is a utility that helps us construct a parameter grid for our algorithm. It helps us test out various models built with various params.
#
# `ParamGridBuilder` is part of `pyspark.ml.tuning` lib.

# %% [markdown]
# ## Well Done! 👏👏👏
# ## You just finished chapter 4: Spark ML - Evaluating models and intro to Pipelines
# ## This was the last chapter for **Apache Spark ML First Steps**
#
# ## I hope you enjoyed it!
#
#
# [@adipolak](https://twitter.com/AdiPolak)
