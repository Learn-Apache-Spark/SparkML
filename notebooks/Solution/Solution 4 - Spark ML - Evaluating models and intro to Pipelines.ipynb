# %% [markdown]
# # 4 - Evaluating models and intro to Pipelines
#
# In this chapter, you will:
#
# • Learn to evaluate your ML model
#
# • Learn to use Pipelines

# %%
from pyspark.sql import SparkSession 
from pyspark.ml import Pipeline
from pyspark.ml.regression import LinearRegression, LinearRegressionModel
from pyspark.ml.fpm import FPGrowth, FPGrowthModel


from pyspark.ml.evaluation import RegressionEvaluator

spark = SparkSession.builder \
    .master('local[*]') \
    .appName("Pipelines") \
    .getOrCreate()

# %% [markdown]
# #### Load machine learning model :
#
#
# Load the models from previous Chapter:

# %%
lr_model = LinearRegressionModel.load('linearRegression_model')

# %%
fpgrowth_model = FPGrowthModel.load('fpGrowth_model')

# %% [markdown]
# Evaluate the models:
#
# For evaluation, load classified test data

# %%
df_test = spark.read.parquet("classified_test_data")

# %% [markdown]
# [From the docs:](https://spark.apache.org/docs/latest/mllib-evaluation-metrics.html)
#
# While there are many different types of classification algorithms, the evaluation of classification models all shares similar principles.
#
# In a supervised classification problem, there exists a _true output_ and a _model-generated predicted output_ for each data row.

# %% [markdown]
# ## Exercise 1: Evaluate your ML model

# %% [markdown]
# ### RegressionEvaluator functionality:
#
#
# ✅ **Task :**
#
#
# Start with predicting the outcome:
# Use predict function
#
# ```python
#     model.transform(vectorOfFeatures).select('prediction').show()
# ```
#
# Notice that transform takes a vector of features as input.
#
# Prediction represents if it's a bot or not.
# 1- bot
# 0- human

# %%
from pyspark.ml.feature import VectorAssembler

test = df_test.drop('description')
vecAssembler = VectorAssembler(inputCols=['screen_name','location','followers_count','friends_count','listed_count','favourites_count','verified','statuses_count','status','default_profile','name'], outputCol="features", handleInvalid = "skip")
test_df_with_vector = vecAssembler.transform(test)

model_test_prediction = lr_model.transform(test_df_with_vector)
model_test_prediction.select('bot','prediction').show()
# Out:
# +---+-------------------+
# |bot|         prediction|
# +---+-------------------+
# |  0|0.10998142685281613|
# |  1| 0.1444231580600674|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  1| 0.1444231580600674|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  1|0.10998142685281613|
# |  0| 0.1444231580600674|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  1| 0.1444231580600674|
# |  1| 0.1444231580600674|
# +---+-------------------+
# only showing top 20 rows

# %% [markdown]
# The model gave us a prediction of the chances for a specific row to
# be a bot. We got numbers like 0.147 and 0.1021.
#
# It is up to us to define the **threshold** for classifying a bot.
# If it shows us 0.9? Will it satisfy us? How certain do we want to be in the classification?

# %% [markdown]
# **RegressionEvaluator** is the evaluator for regression-based models

# %% [markdown]
# Use regressionEvaluator to evaluate the model.
#
# ```pyhon
# from pyspark.ml.evaluation import RegressionEvaluator
# lr_evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="bot",metricName="r2")
# R2 = lr_evaluator.evaluate(model_test_prediction)
# ```
#
# Check out R2 :
# >R-squared is a statistical measure of how close the data are to the fitted regression line. It is also known as the coefficient of determination, or the coefficient of multiple determination for multiple regression. 100% indicates that the model explains all the variability of the response data around its mean
#
# From: [RegressionAnalysis](https://blog.minitab.com/blog/adventures-in-statistics-2/regression-analysis-how-do-i-interpret-r-squared-and-assess-the-goodness-of-fit)

# %% [markdown]
# Notice `metricName` param:
#
# RegressionEvaluator Supports: - `rmse` (default): root mean squared error - `mse`: mean squared error - `r2`: R Sqaure metric - `mae`: mean absolute error

# %% [markdown]
# **Notice!** here we work with the train data and select both `bot` and `prediction` to get a feel for the classifier

# %%
from pyspark.ml.feature import VectorAssembler

df_train = spark.read.parquet("classified_train_data")

train = df_train.drop('description')
vecAssemblerTrain = VectorAssembler(inputCols=['screen_name','location','followers_count','friends_count','listed_count','favourites_count','verified','statuses_count','status','default_profile','name'], outputCol="features", handleInvalid = "skip")
vecAssemblerTrain = vecAssemblerTrain.transform(train)

model_train_prediction = lr_model.transform(vecAssemblerTrain)
model_train_prediction.select('bot','prediction').show()

lr_evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="bot",metricName="r2")
R2 = lr_evaluator.evaluate(model_train_prediction)

print("R Squared (R2) on test data = %g" % R2)
# Out:
# +---+-------------------+
# |bot|         prediction|
# +---+-------------------+
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  1| 0.1444231580600674|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# |  0|0.10998142685281613|
# +---+-------------------+
# only showing top 20 rows
#
# R Squared (R2) on test data = 0.0488262

# %% [markdown]
# When looking back at the `Predictions` output, we understand that they don't help us much.
#
# `Predictions` output is a number between [0,1].
#
#
# However, we expect 1 or 0: bot or human.
# What can we do?
# Decide on a threshold.
#
#
# For Example, every prediction above 0.8 is bot. Bellow 0.8 is human.
#
# Or maybe every prediction above 0.14?

# %% [markdown]
# ---

# %% [markdown]
# ✅ Task :
#
# Use model statistics params:
#
# For example
# Check RMSE - Root Mean Squared Error
# For both train and test.

# %% [markdown]
# Code sample:
#
# ```python
# def getLRSummary(df):
#     df = df.drop('description')
#     vecAssembler = VectorAssembler(inputCols=['screen_name','location','followers_count','friends_count','listed_count','favourites_count','verified','statuses_count','status','default_profile','name'], outputCol="features", handleInvalid = "skip")
#     vecAssembler = vecAssembler.transform(df)
#     output_test = vecAssembler.drop('screen_name','location','followers_count','friends_count','listed_count','favourites_count','verified','statuses_count','status','default_profile','name')
#     output_test  = output_test.selectExpr("features", "bot as label")
#     # evaluate function returns LinearRegressionSummary instance that holds the evaluate results
#     return lr_model.evaluate(output_test)
# ```
#
#
# Here are function [r2 docs](https://spark.apache.org/docs/2.1.0/api/python/pyspark.ml.html#pyspark.ml.regression.LinearRegressionSummary.r2)
#
# Check on both training and test set:

# %%
def getLRSummary(df):
    df = df.drop('description')
    vecAssembler = VectorAssembler(inputCols=['screen_name','location','followers_count','friends_count','listed_count','favourites_count','verified','statuses_count','status','default_profile','name'], outputCol="features", handleInvalid = "skip")
    vecAssembler = vecAssembler.transform(df)
    output = vecAssembler.drop('screen_name','location','followers_count','friends_count','listed_count','favourites_count','verified','statuses_count','status','default_profile','name')
    output  = output.selectExpr("features", "bot as label")
    # evaluate function returns LinearRegressionSummary instance that holds the evaluated results
    return lr_model.evaluate(output)
    

train_results = getLRSummary(df_train)
print("Root Mean Squared Error (RMSE) on train data = %g" % train_results.rootMeanSquaredError)

test_results = getLRSummary(df_test)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_results.rootMeanSquaredError)
# Out:
# Root Mean Squared Error (RMSE) on train data = 0.308919
# Root Mean Squared Error (RMSE) on test data = 0.281997

# %% [markdown]
# `LinearRegressionSummary` gives you a summary of the statistical algorithm evaluations.

# %%
print("r2 on test data = %g" % test_results.r2)
print("r2 on train data = %g" % train_results.r2)
# Out:
# r2 on test data = 0.0453951
# r2 on train data = 0.0488262

# %% [markdown]
# #### What did you learn?
# What more evaluating params can you get out of LinearRegressionSummary instance?

# %% [markdown]
# **Reminder**
# What is r2? R Square:
# >R-squared is a statistical measure of how close the data are to the fitted regression line. It is also known as the coefficient of determination, or the coefficient of multiple determination for multiple regression.
#
# R Square measure how much of the variability in `bot` / `label` can be explained using the model.
# We must be cautious that the performance on the training set to avoid overfitting of the model to the training set.
# Overrfiting can create a model that is good only for the training set and not for the test set.
#
#
# What is RMSE?
# > Root Mean Square Error (RMSE) is the standard deviation of the residuals (prediction errors). Residuals are a measure of how far from the regression line data points are; RMSE is a measure of how spread out these residuals are. In other words, it tells you how concentrated the data is around the line of best fit.

# %% [markdown]
# ## Exercise 2: Build Simple Spark ML Pipelines

# %% [markdown]
# ML Pipelines provide a uniform set of high-level APIs built on top of DataFrames that help us create and tune practical machine learning pipelines.

# %% [markdown]
# In the previous exercise, you learned Logistic regression.
#
# Logistic regression is used when the dependent variable is binary.
# In our case, bot is binary - yes or no.
#
# Linear regression is used to predict the continuous dependent variable.
# This explains the result received.

# %% [markdown]
# ### Spark ML Pipelines

# %% [markdown]
# Start with a simple ML Pipelines:

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import HashingTF, Tokenizer

# %% [markdown]
# Remember that in Chapter 1 we split `description` into a list?
# Let's do it with the `Tokenizer` functionality instead!
#
# `Tokenizer` is part of the `pyspark.ml.feature`. `pyspark.ml.feature` give us many out of the box functionality for feature extraction. Feature extraction is the _data-science_ way of transforming columns into a new one.

# %% [markdown]
# Load saved data:

# %%
data = spark.read.parquet('train_data_only_description')
(trainingData, testData) = data.randomSplit([0.7, 0.3])

# %% [markdown]
# ### Tokenizer, HashingTF, and Logistic Regression
#
# ✅ **Task :**
#
# Configure an ML pipeline, which consists of three stages: tokenizer, hashingTF, and lr:
#
#
# Use the next code sample and adjust it to your needs :
# ```python
# tokenizer = Tokenizer(inputCol="description", outputCol="words")
# hashingTF = HashingTF(inputCol=tokenizer.getOutputCol(), outputCol="features")
# lr = LogisticRegression(maxIter=10, regParam=0.001)
# pipeline = Pipeline(stages=[tokenizer, hashingTF, lr])
#
# ```
#
#
# After we understand that Linear Regression might not be good enough for our data science purposes, we are going to work with Logistic Regression. This is your **3rd** Machine Learning model with Spark ML 🎉

# %%
# Configure an ML pipeline, which consists of three stages: tokenizer, hashingTF, and lr.
tokenizer = Tokenizer(inputCol="description", outputCol="words")
hashingTF = HashingTF(inputCol=tokenizer.getOutputCol(), outputCol="features")
lr = LogisticRegression(maxIter=10, regParam=0.001)
pipeline = Pipeline(stages=[tokenizer, hashingTF, lr])

# %% [markdown]
# Call fit on Pipeline to get the model:
#
# If it fails here, validates that `description` doesn't have null values.
# Our HashingTF doesn't know how to handle null values.
# If those exist, create a new DataFrame without them and use the new DataFrame to build the model.
#
# In case you need it:
# ``` python
#     trainingData = trainingData.dropna('description')
# ```

# %%
# Fit the pipeline to training documents.
model = pipeline.fit(trainingData)

# %% [markdown]
# Make predictions:

# %%
# Make predictions on test documents and print columns of interest.
prediction = model.transform(testData)
selected = prediction.select("description", "probability", "prediction")
for row in selected.collect():
    description, prob, prediction = row
    print("(%s) --> prob=%s, prediction=%f" % (description, str(prob), prediction))
# Out:
# ( CA""") --> prob=[0.9943858513433658,0.0056141486566341344], prediction=0.000000
# ( England""") --> prob=[0.9943897774465229,0.005610222553476962], prediction=0.000000
# ( Northern Ireland""") --> prob=[0.9884562878153246,0.01154371218467543], prediction=0.000000
# ("""Affordable & Professional Printing Services for Businesses & Individuals. For Cheapest Printing Prices Mail us sales@print365.ie #printing #Ireland""") --> prob=[0.9947624065457963,0.00523759345420374], prediction=0.000000
# ("""Ai__""") --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# ("""AlolaFen""") --> prob=[0.9533349711209286,0.04666502887907147], prediction=0.000000
# ("""I am one with the force) --> prob=[0.9274695035515775,0.07253049644842255], prediction=0.000000
# ("""Professional footballer. Liverpool FC and Belgium National Team. https://t.co/mRsHZl5v9t""") --> prob=[0.9829851411929336,0.0170148588070665], prediction=0.000000
# ("""Rare and strong PokŽmon in Las Vegas and Spring Valley. See more PokŽmon at https://t.co/GB4nYu29n3""") --> prob=[0.9984823704576717,0.0015176295423281322], prediction=0.000000
# ("""________________________________________________\n__________________________\n________________________________""") --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# ("""westlife1219""") --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# ("New single ""KILL AGAIN"" out now! https://t.co/qiZ8W4mhJG Shaka Zulu! https://t.co/9ZY92tEQaX https://t.co/uBNsayp9Gr") --> prob=[0.979534067318978,0.020465932681022033], prediction=0.000000
# (*record scratch* *freeze frame* You might be wondering how this bot got here. @lanewinfield made it and it tweets ~10x/day Rand YT videos + fav TV/movie trope) --> prob=[0.9999320121196326,6.798788036746176e-05], prediction=0.000000
# (22 | Electrical Engineering from LUMS | Football | Music | Friends | GYM) --> prob=[0.9985663044026748,0.0014336955973251002], prediction=0.000000
# (25) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (4 booking CHRIS SMITH 310-550-4245 SNAPCHAT MARLONLWAYANS IG @marlonwayans 1/29 live love laugh get tix for my SCANDALESS comedy tour https://t.co/AnSLqIeURj) --> prob=[0.999261465179511,0.0007385348204889238], prediction=0.000000
# (8yr NFL Vet, ESPN Los Angeles & Los Angeles Rams Pregame and Postgame Analyst, Sirius XM NFL Analyst, SDSU Football Radio Color Analyst) --> prob=[0.999995588109992,4.411890008005448e-06], prediction=0.000000
# (@WhiteHouse Chief of Staff. Tweets may be archived: https://t.co/eVVzoBb3Zr.) --> prob=[0.9333881093987565,0.06661189060124341], prediction=0.000000
# (A bot with all the latest news about Nintendo's Amiibo!!! Except it's all not true!!! #botALLY (by @ckolderup)) --> prob=[0.9981057317323849,0.0018942682676151433], prediction=0.000000
# (A place for fans to connect! Tweeting from Mumbai and the world! #Bollywood #India #Parody) --> prob=[0.9938494660857995,0.006150533914200511], prediction=0.000000
# (A poetry project created by Alison Knowles and James Tenney and the Siemens 4004 computer in 1967. Twitter version by @hugovk and SSBot for #D004x in 2015.) --> prob=[0.9992569647566949,0.0007430352433052144], prediction=0.000000
# (A twitterbot dedicated to supplying the most recent papers about p53, the Guardian of the Genome.) --> prob=[0.09835257669475758,0.9016474233052424], prediction=1.000000
# (ALL THE #HOTTEST #GAMES #MEMES | #botALLY by @BooDooPerson) --> prob=[0.9936643558760878,0.006335644123912212], prediction=0.000000
# (Account run by the 23rd Prime Minister of Canada and staff‰Û_ Compte gÌ©rÌ© par le 23e premier ministre du Canada et personnel.) --> prob=[0.9990189912369694,0.0009810087630305173], prediction=0.000000
# (Actor and writer currently working on new TV comedy @GreatIndoorsCBS Instagram ‰ÛÒ stephenfryactually _Ù_•ü‰Û_ÙÎö) --> prob=[0.9979557168968927,0.002044283103107471], prediction=0.000000
# (Advice is what we ask for when we already know the answer but wish we didn't.) --> prob=[0.999702916374755,0.0002970836252451362], prediction=0.000000
# (All the things we should have or do or know by now. (bot by @RobertVinluan.  #botAlly) BEST OF 2014: http://t.co/uEnYFb68eV) --> prob=[0.966984896033962,0.033015103966038045], prediction=0.000000
# (Amazing facts from the good people at mental_floss magazine.) --> prob=[0.9786841514973471,0.021315848502652935], prediction=0.000000
# (Author) --> prob=[0.96357121835294,0.036428781647059975], prediction=0.000000
# (Automated paper feed twitter bot for academics interested in parasitic worms, gut parasites and anthelminthics) --> prob=[0.01784528069899816,0.9821547193010018], prediction=1.000000
# (CEO @Shapeways. I love 3D printers, making stuff, digital manufacturing, the internet and a good conversation.) --> prob=[0.9992979102652394,0.0007020897347605378], prediction=0.000000
# (COLOMBIA_ôñShawn, UJ, Josh follow. Tyra and cejaspobladas liked.) --> prob=[0.9867546682608752,0.013245331739124714], prediction=0.000000
# (Chairman and CEO of #Kaspersky Lab. Waging war against #malware for 27 years. #Infosec, #cybercrime, #cyberwar. Views are my own.) --> prob=[0.7732359594817478,0.22676404051825214], prediction=0.000000
# (Chief Scientist of Baidu; Chairman and Co-Founder of Coursera; Stanford CS faculty. #machinelearning, #deeplearning #MOOCs, #edtech) --> prob=[0.9841078641048775,0.01589213589512258], prediction=0.000000
# (Chronicling men doing things. // A bot by @tinysubversions, Powered By Giphy) --> prob=[0.998601255201946,0.0013987447980539007], prediction=0.000000
# (Co-Founder @SNKRINC, CEO ??2D Productions (fmr MTV, VH1, CMT digital head , AOL video prez)) --> prob=[0.9960449065046888,0.003955093495311323], prediction=0.000000
# (Co-Founder and Chairman of @Stocktwits, GP of Social Leverage, Wallstrip creator (acquired by $CBS), Momentum, Stocks & LOL hunter..Love Popcorn) --> prob=[0.9983516419842805,0.0016483580157195458], prediction=0.000000
# (Cricket fanatic, WWE fan, wannabe coder who is currently trapped in Jamshedpur) --> prob=[0.9453948164941332,0.0546051835058669], prediction=0.000000
# (Curation and content @kickstarter. Writer, editor, Canadian.) --> prob=[0.585935183936248,0.414064816063752], prediction=0.000000
# (DAD: weird conversation joke is bae ME: ugh dad no DAD: [something unhip] // a bot by @tinysubversions) --> prob=[0.9998952498068937,0.00010475019310619873], prediction=0.000000
# (Daily RSS Feed for Protein Hot Spot Prediction papers. Maintained by @selinkaragulle) --> prob=[0.10774710183366153,0.8922528981663386], prediction=1.000000
# (Dashboard Confessional Tix available NOW for our up close and personal tour in Jan and Feb of 2017: https://t.co/Bj0G7NIhy1) --> prob=[0.9893123496135903,0.01068765038640975], prediction=0.000000
# (De um lado a poesia, o verbo, a saudade... Do outro a luta, forí_a e coragem pra chegar no fim!) --> prob=[0.9948751191441652,0.005124880855834883], prediction=0.000000
# (Designing and making games @nytdesign _Ò side project haver _Ò see also: @itsthisyear, @icebergdotcool, @ramsophone, @__birds__ _Ò) --> prob=[0.9955408886355056,0.004459111364494337], prediction=0.000000
# (Destigmatizing a misunderstood and unappreciated part of our vocabulary.) --> prob=[0.9825110565252217,0.017488943474778296], prediction=0.000000
# (Director of Stewardship @newspring) --> prob=[0.963187316416509,0.036812683583491095], prediction=0.000000
# (Don‰Ûªt worry about cool, make your own uncool. Make your own, your own world. Sol LeWitt -- Eva Hesse -- us.) --> prob=[0.9906288074668008,0.009371192533199126], prediction=0.000000
# (Entrepreneur, mentor, angel investor (and mom of twins!) coaching women entrepreneurs and leaders.) --> prob=[0.9862793943854496,0.013720605614550251], prediction=0.000000
# (Ever wondered what a thing is? Follow this ontography machine, powered by tweets proclaiming that something 'is apparently a thing.' By @staeiou) --> prob=[0.9997512271577802,0.00024877284221990625], prediction=0.000000
# (Every website from the Internet International Directory, published 1995 (many dead links)) --> prob=[0.9515648117296249,0.04843518827037513], prediction=0.000000
# (Exceptional GMAT classes and MBA admissions coaching in Austin, TX.) --> prob=[0.9649106418772916,0.035089358122708386], prediction=0.000000
# (FOLLOW @devonxxbt AND RETWEET/LIKE HER PINNED) --> prob=[0.9185993741978448,0.08140062580215529], prediction=0.000000
# (Fav and RT the superior word in each matchup. Goooal! A tribute to @everyword / @aparrish by @johnholdun) --> prob=[0.9989331137440551,0.0010668862559448855], prediction=0.000000
# (Feeling adventurous? Try one of these!) --> prob=[0.8935774214117294,0.1064225785882708], prediction=0.000000
# (Female) --> prob=[0.9755479473941219,0.02445205260587821], prediction=0.000000
# (Founder and Chairman of Rasmussen Global) --> prob=[0.9847245933765909,0.015275406623409158], prediction=0.000000
# (Free Follow for @jalfiebutler ... follow back please or I'll unfollow _Ùªâ) --> prob=[0.9981726014562058,0.0018273985437942384], prediction=0.000000
# (Fresh E3 rumours every 3 hours! Made by @warandpeace with http://t.co/XpDuja7Q2I. Inspired by @TheBlackNerd, @sokareemie, @mikesacco, & @tinysubversions) --> prob=[0.9971753547387714,0.002824645261228508], prediction=0.000000
# (From late 2014 Socium Marketplace will make shopping for fundamental business services more simple, more cost effective and more about you.) --> prob=[0.9982651321692525,0.0017348678307474504], prediction=0.000000
# (Good life, good health, good work.) --> prob=[0.9970110822452111,0.002988917754788978], prediction=0.000000
# (Governor of South Carolina) --> prob=[0.9822194516048712,0.01778054839512877], prediction=0.000000
# (Graduate student at NYU Tandon School of Engineering. Fan-fic reader and engineer by day soccer defender at night. Manchester United FC is life.) --> prob=[0.9996302473909108,0.0003697526090892874], prediction=0.000000
# (Grammy Award Winner https://t.co/n9Rl67gSUz - https://t.co/wzMnEiCDUM - Contact: https://t.co/pSbZI5acbu) --> prob=[0.9957957492857784,0.004204250714221492], prediction=0.000000
# (Hello! I am a loving friend bot! @mossdogmusic and @inurashii created me (with help from @cirne) and I love you all very much!) --> prob=[0.9593684693395684,0.040631530660431604], prediction=0.000000
# (Hello, I am African and Indian, Artist, Work, Pub, Design, Culture. Deco, Drawings, theater, Movie,  _ôÖ_ôïñ_ôïî_ôï__ôë_ô_¬äì¥Ÿ_ô_Â_ôÂ_ôÁ_ô_Â_ôÂ_ô‚_ô©_ôÈ_ô__ô_ô_¿_ô___ôó_ôä__¥Ÿ_ô___ô___ô___ô___ôñŸ_ôñé_ô___ô__...) --> prob=[0.9999812907139051,1.8709286094954388e-05], prediction=0.000000
# (Hi, I'm Pretty. #digitalarchival. Virus Corp. Mad King Ludwig GPS. #techtraderoutes #insideTarasphone #whatsgoingon101 #otherpeoplesadvertising) --> prob=[0.9761031330951518,0.023896866904848265], prediction=0.000000
# (Historian & classicist with a particular interest in linguistics & philology, ancient & modern, English or not. Fair range of contemporary interests, too.) --> prob=[0.9812068744832984,0.018793125516701648], prediction=0.000000
# (Hosts @KeiserReport on @RT_com, recommended bitcoin at $3) --> prob=[0.9763759423942585,0.02362405760574137], prediction=0.000000
# (I am a moose. I am made of chocolate.) --> prob=[0.9919126622895623,0.00808733771043761], prediction=0.000000
# (I cant complain but sometimes I still do) --> prob=[0.9887431099828997,0.011256890017100377], prediction=0.000000
# (I find tweets about Danny Devito.) --> prob=[0.9642888768816511,0.035711123118348946], prediction=0.000000
# (I have something to say about all the games.) --> prob=[0.9886378244448036,0.011362175555196427], prediction=0.000000
# (I luv Zendya. She is SO awesome. Shak it up is my favorite disney channel show. teamfollowback zswager :3) --> prob=[0.9971375835245135,0.0028624164754864705], prediction=0.000000
# (I make video games, and have a beautiful wife with 4 boys. It's nutty!) --> prob=[0.9924078758829503,0.0075921241170497245], prediction=0.000000
# (I received  M. Sc. and  Ph. D. degrees in CS from Univ. of Lille I,France. Now 100 Talents Professor at CNIC, Chinese Academy of Sciences) --> prob=[0.1530278615252886,0.8469721384747114], prediction=1.000000
# (I tweet a random object from the collection of the Museum of Modern Art four times a day. Bot by @backspace (not affiliated with @MuseumModernArt)) --> prob=[0.9996529917029486,0.0003470082970513025], prediction=0.000000
# (I want you to know thatI am both happy and sadand I'm still trying to fgure out how that could be.) --> prob=[0.9998382017468975,0.00016179825310238088], prediction=0.000000
# (I'm a bot that hates it when people use words that aren't @everyword canon. #taskcomplete by @negatendo, who is sorry.) --> prob=[0.9997412441290411,0.0002587558709588069], prediction=0.000000
# (I'm a professor of history at Brooklyn College and the CUNY Graduate Center. Former Fulbright at @telavivuni; former track announcer at @ScarboroDowns.) --> prob=[0.992628154522095,0.007371845477904961], prediction=0.000000
# (I'm a robot tracking data for bad words. Don't mind me.) --> prob=[0.9980994409009469,0.0019005590990531249], prediction=0.000000
# (Indian, Hyderabadi, Red Devil, Manipalite, Terrapin, Philanthropist, In that order! I'm nt da guy that every girl needs, I'm da guy every girl deserves ;)) --> prob=[0.999581188205987,0.00041881179401311264], prediction=0.000000
# (Instagram - Parineetichopra. Snapchat - ChopraParineeti) --> prob=[0.9861007190081055,0.013899280991894573], prediction=0.000000
# (Interesting facts about the world we live in. Facebook: https://t.co/nKPHSWpSOr / Enquiries: tweetingfacts@gmail.com) --> prob=[0.9800303005630338,0.01996969943696624], prediction=0.000000
# (Jai Hind !!) --> prob=[0.958605120733841,0.04139487926615891], prediction=0.000000
# (Jay Sean. Singer/Songwriter. Sony Music.) --> prob=[0.9269543342101295,0.07304566578987047], prediction=0.000000
# (Jazz Singer, Crooner, Almost Dancer... Old school music is my game.) --> prob=[0.9775768733607625,0.02242312663923755], prediction=0.000000
# (Jeopardy! fixture of yesteryear. Author of the Junior Genius Guides and a bunch of other stuff. https://t.co/6osivaktzC) --> prob=[0.9973153970904353,0.0026846029095647993], prediction=0.000000
# (Jornalista. Escritor. Ser humano. Testemunha ocular do fim do mundo.) --> prob=[0.9688698090666327,0.03113019093336738], prediction=0.000000
# (Juan David Solarte Arana) --> prob=[0.746410012106704,0.253589987893296], prediction=0.000000
# (Just a bot that tweets the https://t.co/ROXIqz0eDO RSS feed. Not associated with https://t.co/1NJoBtBGWo / @grantsdotgov in any way. Maintained by @EcoEvoGames.) --> prob=[0.07415328460485372,0.9258467153951464], prediction=1.000000
# (Just pingin' away at @poll to make sure the whole stack is in working order. I'm bored :() --> prob=[0.9986407508983801,0.0013592491016199242], prediction=0.000000
# (Keeping our nation safe by arguing with RINOs like @EdTaters...  and you! A retired bot created by @leonardr.) --> prob=[0.9994349631761792,0.000565036823820909], prediction=0.000000
# (Life is better than death; I believe; if only because it is less boring; and because it has fresh peaches in it.) --> prob=[0.9963395818774325,0.0036604181225673607], prediction=0.000000
# (MP for Thiruvananthapuram. Author of 16 books. Former Minister of State,Govt.of India.  Former UnderSecretaryGeneral,UnitedNations. RTs do not imply endorsement) --> prob=[0.9797821393878022,0.020217860612197713], prediction=0.000000
# (Mantra: I empower people. Chief evangelist of @Canva https://t.co/7AwtiXC7jr. Author of thirteen books. Former chief evangelist of Apple.) --> prob=[0.9941621081127493,0.0058378918872506935], prediction=0.000000
# (Memphis, TN) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (Moderator of @meetthepress and @nbcnews political director; Covering politics since '92; And, yes, I tweet about sports too.) --> prob=[0.9863690791113964,0.013630920888603579], prediction=0.000000
# (Mom, Mimi, Navair BFM, tree hugger.) --> prob=[0.957793218564355,0.04220678143564505], prediction=0.000000
# (NBA Forward, Danilo Gallinari Instagram @danilogallogallinari Facebook Danilo Gallinari) --> prob=[0.976126278270477,0.02387372172952301], prediction=0.000000
# (New album, A Head Full Of Dreams, out now worldwide. #AHFODtour runs through 2017. Spanish language account: @coldplay_es) --> prob=[0.9994187947493197,0.0005812052506803467], prediction=0.000000
# (New words, by @derekarnold) --> prob=[0.9955251080309401,0.004474891969059994], prediction=0.000000
# (Nine years in the NFL. Two rings.) --> prob=[0.9729351214243747,0.027064878575625395], prediction=0.000000
# (Not right wing... Just Right. #freedom #capitalism #objectivism https://t.co/Iq5MEjcBnU) --> prob=[0.9718103443856002,0.028189655614399824], prediction=0.000000
# (Obsession with video games and kung-fu) --> prob=[0.9817399461607026,0.018260053839297352], prediction=0.000000
# (Official Twitter site of NBA's All-Time Leading Scorer, New York Times best-selling author columnist, Time Magazine) --> prob=[0.9994421480603245,0.000557851939675586], prediction=0.000000
# (Official page of Angie Harmon. Mother of three AMAZING kids, Unicef Ambassador, Writer, Director, LOVE being part of TNT Rizzoli & Isles) --> prob=[0.9992959307871577,0.000704069212842356], prediction=0.000000
# (Papers on colouration and vision in nature (#colsci), mostly fed from #pubmed. Run by @TomEdWhite - suggestions welcome!) --> prob=[0.9082786567453862,0.09172134325461385], prediction=0.000000
# (Passionate about my work, in love with my family and dedicated to spreading light. It's contagious! ;-) https://t.co/vZcUuNOKcz) --> prob=[0.9976322254922657,0.0023677745077341364], prediction=0.000000
# (Paz filhos da puta.) --> prob=[0.9479128452433014,0.0520871547566985], prediction=0.000000
# (Platinum Recording Artist, Producer, Writer, Director, Art-Lover, Entrepreneur, 24/7 Creative Opportunist. Changing the world one song at a time..!) --> prob=[0.9998676533732914,0.0001323466267086852], prediction=0.000000
# (Praise is what I do...) --> prob=[0.9743724036288174,0.025627596371182563], prediction=0.000000
# (Principal Engineer at @voxmediainc / @voxproduct. Tweets my own. Jokes shamelessly ripped from Reddit. Prev: @disqus, @threespot. ä_ StarCraft) --> prob=[0.9822660604454688,0.017733939554531213], prediction=0.000000
# (Publication alert for genome-wide association studies @genomic_pred @mendelian_lit @wpgilks) --> prob=[0.13099013786182395,0.869009862138176], prediction=1.000000
# (Quoting those too often overlooked. Tweet a hashtag @the_underquoted to see if any quotes match that word. Tweets one unsolicited quote a day.) --> prob=[0.9639874833032246,0.036012516696775305], prediction=0.000000
# (R&D: #ArtificialIntelligence, #AI, #DeepLearning, #NeuralNetworks, #MachineLearning, #Robotics, #Bionics, #Biometrics, #VR, #AR, etc. Founder & CEO @Rosenchild) --> prob=[0.9933214314126403,0.006678568587359693], prediction=0.000000
# (REMEMBER MY NAME.) --> prob=[0.7696424843849732,0.23035751561502688], prediction=0.000000
# (Read on Bustle,PlanetTransgender, CNNi,The Advocate,TheColu.mn,Gay-Essentials The NYT,HuffpoLive,Original Plumbing #girlslikeus Writer,Producer, Director,ENFP) --> prob=[0.9720839380230363,0.02791606197696383], prediction=0.000000
# (Search Engineer) --> prob=[0.9580684679972407,0.041931532002759196], prediction=0.000000
# (Serving clients for nearly 40 years. We buy and sell physical precious metals and prefer bitcoin but take most payment types. Not your average brokerage firm.) --> prob=[0.9981591954191524,0.001840804580847573], prediction=0.000000
# (Solve the riddle by replying only the name of the person/character described! Created by @verhoevenben, @1vangro, @fvancesco, @pedrojmmartins at #codecampcc) --> prob=[0.9943430544323666,0.005656945567633507], prediction=0.000000
# (Stand-upper, Zombie Therapist, Ball Dropper, Ravenclaw, @Nerdist Inventor and POINTS giver) --> prob=[0.9603820805978123,0.0396179194021878], prediction=0.000000
# (Stay on top of all the latest publications on Biofilm research curated from PubMed. #biofilm #microbiology #antibioticresistance. Run by @mccarthy_ronan) --> prob=[0.3710532744653152,0.6289467255346848], prediction=1.000000
# (Teacher and Educationist. ASCD Emerging Leader 2015/Tedx Speaker/ Founder Islamabad https://t.co/NjgxEvcwSm LEAD (pvt) Limited/Activist.) --> prob=[0.9597585720558629,0.04024142794413696], prediction=0.000000
# (Tech/scifi/data enthusiast. Loves building digital things.) --> prob=[0.9859268724012152,0.01407312759878491], prediction=0.000000
# (Tell me your successes, I want to steal them. Comm/design junkie, amenable traveler, political screamer, mediocre skeeballer. @NYUTandonTweets IDM MS Candidate.) --> prob=[0.9991444743457567,0.000855525654243213], prediction=0.000000
# (The Mole Hole of Myrtle Beach,SC has been in business since 1978. We have the experience and selection to ensure our customers find something unique and special) --> prob=[0.9987706153241235,0.0012293846758765477], prediction=0.000000
# (The task that will complete is not an unvarying task. // a bot by @inky) --> prob=[0.9987477541411713,0.0012522458588285908], prediction=0.000000
# (This bot will post when anything gets added to the WWE Network. This is not an official WWE Account. Created by tgrollo@gmail.com) --> prob=[0.9991153424760412,0.0008846575239588916], prediction=0.000000
# (This should be the quickest route, but it depends on the traffic) --> prob=[0.9619583168971064,0.03804168310289364], prediction=0.000000
# (Throw away your other Twitch bots. I'm the best Twitch bot you'll ever find. For support, visit https://t.co/MjyvbaH6TN.) --> prob=[0.9983796018265294,0.0016203981734706392], prediction=0.000000
# (Tweeting all the languages. All of them. Process should finish sometime in October 2015. Created by @OnnaAdele.) --> prob=[0.9759126482781612,0.024087351721838818], prediction=0.000000
# (Tweets quotes [every hour] from Polygon's Monster Factory, starring Griffin and Justin McElroy! [run by @_AzureDragoon]) --> prob=[0.9901807723040407,0.00981922769595936], prediction=0.000000
# (Twitterbot of nonribosomal or nrps or non-ribosomal in #Pubmed created and curated by jem.stach@ncl.ac.uk) --> prob=[0.2105388904058382,0.7894611095941618], prediction=1.000000
# (Twittered every word in the English language. Task began in 2007 and completed in 2014. Buy the book! http://t.co/3OuWi3iCKy) --> prob=[0.942931218767819,0.05706878123218103], prediction=0.000000
# (Two division UFC World Champion. Two division Cage Warriors World Champion. Making history EVERYDAY!! #NOTORIOUS #EIRE) --> prob=[0.995531822165093,0.004468177834906942], prediction=0.000000
# (UN Office for the Coordination of Humanitarian Affairs (OCHA) in Asia and the Pacific provides key updates on humanitarian issues and disasters in the region) --> prob=[0.9465158054304538,0.05348419456954627], prediction=0.000000
# (US 50k Record Holder. 4 Olympic Marathon Trials. 3 US Teams. TV analyst. Sports Agent. Believe in love, God, big dreams & hot salsa. NFL/Padres fan.) --> prob=[0.9996324233799498,0.0003675766200501742], prediction=0.000000
# (Uh, blame @tinysubversions for this one. (Actually one metaphor every two minutes. Twitter rate limits.)) --> prob=[0.9948858444092176,0.005114155590782462], prediction=0.000000
# (Um blog sobre filmes, trilhas sonoras e curiosidades! Descontraí_do e eclí©tico! Siga a gente para receber as novidades!) --> prob=[0.9970890314173207,0.0029109685826793257], prediction=0.000000
# (University of Warwick Publications Service and WRAP. Simple Deposit: https://t.co/34Lw2ePmdP. Support via email: publications@warwick) --> prob=[0.97030734706083,0.029692652939170103], prediction=0.000000
# (Unofficial; imagery courtesy: Japan Meteorological Agency (https://t.co/lzPXaTnMCi) and CIRA (https://t.co/YksnDoJEl8). Bot by @__jcbl__) --> prob=[0.9893751965444546,0.010624803455545333], prediction=0.000000
# (Vehicle) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (WI - CA - MA Family, Friends, Music, Sports, Shananagins, LIFE!) --> prob=[0.9990137970997306,0.000986202900269399], prediction=0.000000
# (We're bringing clean and safe drinking water to people in need around the world.) --> prob=[0.9882929469641081,0.011707053035891965], prediction=0.000000
# (Without forgiveness; there's no future.) --> prob=[0.9776480498380778,0.02235195016192214], prediction=0.000000
# ([WORK IN PROGRESS] reminder bot. try  @mnemosynetron remind me to X at/in/on Y. // more notes in link // by and for @thricedotted) --> prob=[0.9995890275943156,0.00041097240568450705], prediction=0.000000
# (bot by @dbaker_h) --> prob=[0.9861961480381113,0.013803851961888764], prediction=0.000000
# (butts. butt botts. butt things. https://t.co/9K7GC6ImGN #rumpology - @speckninja (bot favs tweets containing 'butt')) --> prob=[0.973801379944173,0.026198620055826974], prediction=0.000000
# (candle freak. tea addict. life enthusiast. let's dance, eat kale, and laugh til' we cry // snapchat - daniemo) --> prob=[0.9998037707683607,0.0001962292316392734], prediction=0.000000
# (folo: @bravowwhl, Insta: @bravoandy, Snap: AndysGotThe411, check out @RadioAndySXM - ch 102, tour info: https://t.co/wmQGwh2QWF) --> prob=[0.9975418948714099,0.0024581051285902035], prediction=0.000000
# (gentle affirmations for rough days/weeks/years, every 30 mins. just because a bot said them doesn't mean they're not true. call @chevalier_cygne with feedback) --> prob=[0.9995212829700401,0.0004787170299599443], prediction=0.000000
# (http://t.co/4PHOPJ3bDL) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (i am sia i was born from the bumhole of a unicorn named steve. New single The Greatest out now: https://t.co/bSJ8s4KyWU sia on tour: https://t.co/oBKYzDMZSN) --> prob=[0.998836090083019,0.001163909916980912], prediction=0.000000
# (i m calm, jolly person.................who has no matter what the other have.....but it matters for me why i don't have) --> prob=[0.998889150589845,0.001110849410155085], prediction=0.000000
# (im a bad friend and i might secretly want to kill you (by @starla4444)) --> prob=[0.9853636823627561,0.014636317637243875], prediction=0.000000
# (just a river on twitter. made by @muffinista #botALLY) --> prob=[0.9972162613242835,0.0027837386757165413], prediction=0.000000
# (multilevel marketing,mmm. monitec, zewang, achieveyodreams, E.T. C.) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (nu merch: https://t.co/40NCLREgSv) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (pink team returning fire) --> prob=[0.957105539523201,0.04289446047679892], prediction=0.000000
# (see me live here https://t.co/bk16pVODRO) --> prob=[0.9723168624480092,0.02768313755199078], prediction=0.000000
# (social contagionista. blogdiva extraordinaire. criminally prolific multilingual twittinfluencer. shmears gossip, news, sports & tech w/humor & profanity) --> prob=[0.5945182114282183,0.40548178857178174], prediction=0.000000
# (tweets by Anderson Cooper. Anchor @AC360 and correspondent on @60Minutes. Author of NYTimes Best Seller - The Rainbow Comes And Goes https://t.co/1cZvasmMBi) --> prob=[0.9569502443164292,0.04304975568357079], prediction=0.000000
# (water, melanin, bones, blood.) --> prob=[0.9495446860137525,0.05045531398624749], prediction=0.000000
# (web developer, recent @devbootcamp grad - let's talk. dream project involves civic engagement or citizen science. queer immigrant enby treehugger. [they/she]) --> prob=[0.9984354003053632,0.0015645996946367245], prediction=0.000000
# (Îë_±_Î__ÜóITî‡Üó_´ÁÎ_„ICÎ‡«Â†ÎŸšÜó_‰_ñÎ‡_Î_‰†„Üó_ŠåÎ‡____ÎìÂÎ„__åÜó_ìŠfoÎËƒÎ__Üó_Ÿfo_†Î_ÇÜó‰) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (ÎëÎ_Ü¬Ü‰_Ü‰±Ü€çÜ€_Ü€¢Ü€ˆÜ€‚Ü‰ÍÜ_ÜôÜ»Ü‰Š_µÜ»_£Îï_botÜó‰_µ‡Î__Ü‰_Ü‰±Ü€çÜ€_bot(@attractive_bot)Ü†Ü‰Š_Ç_îôÜó‰¬çÊ___Î_¢(@fumicustodian)Üó‰Ü‰¢Ü‰_Ü‰_Ü€_Pletts TwinsÜóÜ€ÖÜ€€Ü€óÜ€_Sampaio TwinsÜó‰) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (ä_) --> prob=[0.9671797277126338,0.03282027228736613], prediction=0.000000
# (•_£•__•_¢•_´•__•_£•_ø•_¨•_¨•_´•_£•_«•_©•_¨•_¤‹ÛÛ•_£•__•_¢•_´•__•__•_ø•_µ‹ÛÛ•_£•__•_¢•_´•__•_á•_©•_«•_¬‹ÛÛ•_£•__•_¢•_´•__•_«•_¬•_´‹ÛÛ•_£•__•_¢•_´•__•_Â•_Á•_«•_´•__•_«‹ÛÛ•_£•__•_¢•_´•__•_¦•_ø•_£•_Á•_¢•_µ•_Â•_Á•__•__) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# ( CA""") --> prob=[0.9943858513433658,0.0056141486566341344], prediction=0.000000
# ("""") --> prob=[0.5715773822711883,0.42842261772881174], prediction=0.000000
# ("""Am I cool yet?""") --> prob=[0.9540280211098665,0.04597197889013344], prediction=0.000000
# ("""Relationships are made of talk - and talk is for girls and women.""") --> prob=[0.9883428168466405,0.01165718315335942], prediction=0.000000
# ("""The official Manchester City Twitter account | Supporter Services __ @ManCityHelp | Snapchat __ mancityofficial""") --> prob=[0.999653971137024,0.00034602886297603966], prediction=0.000000
# ("""The official Twitter account of New York City FC. For tickets and supporter services follow @NYCFCHelp. #NYCFC #WeAreOne""") --> prob=[0.99970461247334,0.00029538752666006873], prediction=0.000000
# ("""________""") --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# ("""jogador do Chelsea FC - football player (Chelsea FC)""") --> prob=[0.9978084609203868,0.0021915390796131994], prediction=0.000000
# (#DruHill20th  #LastDragon) --> prob=[0.9214477297049478,0.07855227029505227], prediction=0.000000
# (#bitcoin #crypto #JS #Node, rockets, science. Liverpool JS founder, entrepreneur, words are mine unless hacked or intoxicated  0xb70b5e25f470bd12 https://t.co/z4GGcV07JH) --> prob=[0.9984502149380943,0.0015497850619057957], prediction=0.000000
# (#miracle out now #Karma new album out now @sonymusic @ultrarecords #Karma UK|European tour starting September16-Feb27 '17) --> prob=[0.9989892561799879,0.0010107438200121293], prediction=0.000000
# (7) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (@victor_zheng developed me to alert users in whose tweets I find improper grammar—he was inspired by @StealthMountain. To publish solecisms is to abase oneself!) --> prob=[0.9988381919953935,0.0011618080046064503], prediction=0.000000
# (A Markov-powered mashup of Erowid trip reports and tech recruiter emails. Run by @aphyr, who's not affiliated with Erowid. Heck, he's never even smoked pot.) --> prob=[0.9984317778794373,0.0015682221205627828], prediction=0.000000
# (A Twitter bot by @Quasimondo that creates random low-polygon versions of pictures it receives.https://t.co/ItJbIIQj01 #bot2bot was invented here.) --> prob=[0.9988339799261812,0.001166020073818911], prediction=0.000000
# (A curated collection of news and opinions on DC's #startup ecosystem, #DCtech, and all things technology-related affecting the #DC metro area.) --> prob=[0.9908634970264494,0.009136502973550691], prediction=0.000000
# (Absurd charts, twice daily. You get one flow chart and one Venn diagram. A bot by @tinysubversions) --> prob=[0.9988984975786352,0.0011015024213647843], prediction=0.000000
# (Actress, producer, singer, professional illuminator. Shop #IlluminateByAshley:) --> prob=[0.9793394658548448,0.020660534145155368], prediction=0.000000
# (Always winning) --> prob=[0.953411403353374,0.046588596646626054], prediction=0.000000
# (An unfiltered view of EVERY SINGLE STEAM LAUNCH! A @dejobaan experiment bot. It creates 6s trailers, too: @MicroTrailers. Not affiliated with Steam.) --> prob=[0.999393090751933,0.0006069092480670181], prediction=0.000000
# (Ancient Wisdom for Modern Living) --> prob=[0.8759390775289729,0.12406092247102704], prediction=0.000000
# (Angel investor (@uber @thumbtack @wealthfront) Founder @Engadget @Inside @LAUNCH @twistartups / come to https://t.co/3Ugs6Cmos5) --> prob=[0.9924956144021716,0.007504385597828362], prediction=0.000000
# (Animal videos sourced from @macaulaylibrary. Turn up the sound! // A bot by @tinysubversions. Not affiliated with the Macaulay Library.) --> prob=[0.9980826588285525,0.0019173411714475434], prediction=0.000000
# (Art Automata [bot]. See url below for how to help to keep me running.) --> prob=[0.9720857222623965,0.027914277737603434], prediction=0.000000
# (Autodidact / Teammate / Building Brands People ‰_•ü / Boston Sports Fanatic) --> prob=[0.9952756484972138,0.00472435150278627], prediction=0.000000
# (Automatically tweets ecological content from journals in plant biology. Auto filtering used to select content. Maintained by @EcoEvoGames) --> prob=[0.17262651148920408,0.8273734885107958], prediction=1.000000
# (Avocat at @Fieldfisher. Expert #blockchain / #ethereum. Founder https://t.co/ErnYAvl3U1. Cofounder @AssethFR & @laChainTech) --> prob=[0.9956467150877383,0.004353284912261678], prediction=0.000000
# (Barrister, wannabe interior designer, general messer. I get panicky when running low on mayonnaise.) --> prob=[0.9942973663915688,0.00570263360843121], prediction=0.000000
# (Bhagavad Gita verses combined with online dating profile texts. #twitterbot by @greg00r) --> prob=[0.9421417305437254,0.0578582694562745], prediction=0.000000
# (Bot of @jonathanPKMN that's all you need to know. Don't mind the profile pic.) --> prob=[0.9943328304162301,0.0056671695837699635], prediction=0.000000
# (Bot that tweets flavor text from Magic: the Gathering cards. Made by @scutajar. MtG is property of Wizards of the Coast and Hasbro, I own nothing.) --> prob=[0.9927223694175997,0.007277630582400415], prediction=0.000000
# (Bringing you the latest in #lncRNA scientific literature. #lincRNA #longnoncodingRNA #RNA #biochem #pubmed #science) --> prob=[0.2414569656974406,0.7585430343025593], prediction=1.000000
# (CARE fights global poverty by empowering girls and women. Visit https://t.co/tmn5uaYFAE and join us.) --> prob=[0.9962421997421989,0.003757800257801191], prediction=0.000000
# (CEO @influenceandco, @Forbes @Inc columnist, speaker, father/husband. I work with some of the best brands and most influential people to grow their influence) --> prob=[0.9970205896216621,0.002979410378337909], prediction=0.000000
# (CEO Rann Strategy Group. Visiting Professor King's College London. Former Australian Ambassador to Italy and High Commissioner to the UK. SA Premier 2002-2011.) --> prob=[0.9993801482012797,0.000619851798720176], prediction=0.000000
# (CEO of #SODMG Records | Owner of @sbeezylightsco | bookings: @ceomiamimike) --> prob=[0.9888499602582264,0.011150039741773575], prediction=0.000000
# (Channelwali @ Star Pravah ... Masterchef of Khayali Pulao !) --> prob=[0.9982451090520378,0.0017548909479621303], prediction=0.000000
# (Chief Strategy Officer at @Mashable ... lover of @kendallostrow, media, tech, entrepreneurship and sport.) --> prob=[0.998586587674365,0.0014134123256348803], prediction=0.000000
# (Comedian/Actor/Jester/PajamaWearer/Singer/MarieBiscuitLover/BulldogEnthusiast/SherlockHolmesFanGirl/DogsBollocks) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (Comedy is when you take two tweets from journalists and then confuse them.) --> prob=[0.9974162696451413,0.002583730354858632], prediction=0.000000
# (Continuous, auto-updated feed of #Celegans (and other Caenorhabditeae) of fruit or wherever they may be -- PubMed, arXiv, bioRxiv, and @PeerJ PrePrints.) --> prob=[0.188415608476328,0.811584391523672], prediction=1.000000
# (DISCOUNT #SwimStore for exclusive #swimwear - #swimsuits, #SwimCaps, #SwimShirts, #SwimShorts, #SwimmingGoggles, #SwimsuitsForWomen etc. 20% OFF! SHOP NOW!) --> prob=[0.9197575969308222,0.08024240306917782], prediction=0.000000
# (Daily links showing an unusual slice of IFDB content) --> prob=[0.9789584378630007,0.021041562136999193], prediction=0.000000
# (Data science, jazz, and fox shirts.) --> prob=[0.9643176994821171,0.035682300517882994], prediction=0.000000
# (Doing it all backwards & in high heels. Married to @Astro_Oz Grammy to 2. Golfer, skier. Former Member of Congress. Find me @FaegreBD fighting the good fight.) --> prob=[0.9960207044761065,0.003979295523893541], prediction=0.000000
# (Electrical Engineer at Engro | LUMS 2014 | Work Hard Party Harder) --> prob=[0.9994818212539014,0.0005181787460986814], prediction=0.000000
# (Entrepreneur, Web-desidner, developer.) --> prob=[0.9705945288246004,0.02940547117539952], prediction=0.000000
# (Estou a procura de amizades sinceras e bem legal na qual podemos manter sempre contatos!!!) --> prob=[0.9920855483217789,0.00791445167822115], prediction=0.000000
# (Financial Advisor since 1988. Hobbies are skiing, surfing & golf . Whiskey single malt scotch enthusiast. Worldwide traveler with over 55 and counting.) --> prob=[0.9988753972174269,0.0011246027825729601], prediction=0.000000
# (Follow me for information on the hottest new IANA-registered link relations. A @leonardr bot, updated 1x/day.) --> prob=[0.8865485246245187,0.11345147537548125], prediction=0.000000
# (Follow us to know when it's time for a drink. @bugloaf made me.) --> prob=[0.9962297623695083,0.00377023763049157], prediction=0.000000
# (Founder at @FastForwardLabs. Data Scientist in Residence at @accel. I ? data and cheeseburgers.) --> prob=[0.998621003939949,0.0013789960600509817], prediction=0.000000
# (Founder of Room to Read.  Author of Leaving Microsoft to Change the World.  Goldman Sachs 100 Most Intriguing Entrepreneurs.) --> prob=[0.935294664697398,0.06470533530260206], prediction=0.000000
# (Game developer 4ever. :0)) --> prob=[0.9867992138526501,0.013200786147349812], prediction=0.000000
# (Health & Safety Executive for E Larning  DVD Sals) --> prob=[0.9912441847883297,0.00875581521167036], prediction=0.000000
# (Helping those who build the future without destroying humanity. VC @lux_capital. Saudades do Rio.) --> prob=[0.9566713949899249,0.04332860501007499], prediction=0.000000
# (Hi I'm Max, I kompress JPG or PNG images to JPEG level 0 when you mention me. Improper use equals a blok, use hash tags where applikable. By @_y_a_v_a_ #botALLY) --> prob=[0.9999846337719623,1.5366228037652412e-05], prediction=0.000000
# (Hi there! I'm a bot which monitors multiple paste sites for password dumps and other sensitive information.) --> prob=[0.9949365127710802,0.00506348722891974], prediction=0.000000
# (How does he keep up with the news like that? #botALLY) --> prob=[0.9954046391539854,0.004595360846014506], prediction=0.000000
# (I am a bot that tweets one random object from the Brooklyn Museum collection, four times a day. Bot by @backspace (not affiliated with @brooklynmuseum)) --> prob=[0.9999191753455329,8.082465446722088e-05], prediction=0.000000
# (I invented post-it's) --> prob=[0.9518447367492903,0.04815526325070971], prediction=0.000000
# (I looked up my family tree and found out I was the sap.) --> prob=[0.9957221008488666,0.004277899151133478], prediction=0.000000
# (I'm a British European, I think like an American & was born in an Arabic country. I've run a few marathons & I start performing in Spanish in November) --> prob=[0.9997684066202966,0.0002315933797034243], prediction=0.000000
# (I'm quite out of my mind, actually, but people continue to find me amusing. I can't imagine why, unless it's morbid fascination.) --> prob=[0.9983174062417439,0.00168259375825614], prediction=0.000000
# (In case you were wondering. Bot by @RobertVinluan. #botAlly) --> prob=[0.9928792968747455,0.00712070312525458], prediction=0.000000
# (Infovis, SVG, Go Programming Language, Processing, REST, Web Architecture) --> prob=[0.9231051851300536,0.07689481486994643], prediction=0.000000
# (Jenny lives, works, and writes in Brooklyn with her partner, twins, and pit bull.) --> prob=[0.9625398673939207,0.03746013260607927], prediction=0.000000
# (LA VIDA ES PARA VIVIRLA Y PASARLA BIEN NO ANDAR ENBRONCADO CON OTROS VIVILA Y PASALA BOMBA JAJAJAJJA  _ô_Š_ô_Š_ô_Š_ô_Š_ô_Š) --> prob=[0.9979955248691467,0.002004475130853429], prediction=0.000000
# (LI,NY.) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (Live Well, Love Much, & Laugh Often) --> prob=[0.9811534656902069,0.018846534309793085], prediction=0.000000
# (Living, Loving, and working to help you.) --> prob=[0.9131499304502206,0.08685006954977932], prediction=0.000000
# (Mashable is for superfans. We're not for the casually curious. Obsess with us.) --> prob=[0.978702029458789,0.021297970541211044], prediction=0.000000
# (Minister of External affairs) --> prob=[0.11296046900539346,0.8870395309946066], prediction=1.000000
# (Mission: Live Like Jesus & Then Lead People to Jesus. The Best is Yet to Come! QB for Seattle Seahawks. Super Bowl Champ) --> prob=[0.9985736444632773,0.0014263555367226], prediction=0.000000
# (Molecular biology pre-prints from bioarxiv #openaccess #science #molbiol #molecularbiology) --> prob=[0.13256984960470436,0.8674301503952956], prediction=1.000000
# (NHL player with St Louis Blues. GenEthix partner.) --> prob=[0.9792505610606834,0.020749438939316578], prediction=0.000000
# (NYU Wasserman Center for Career Development.  133 E 13th Street, 2nd Floor - inside Palladium!) --> prob=[0.9987224872982525,0.0012775127017475222], prediction=0.000000
# (Need a whizzy name for your social media startup? There's a #CDBQ bot for that.) --> prob=[0.9979264561982316,0.0020735438017683667], prediction=0.000000
# (New papers from: Oxford Bioinformatics, Briefings in Bioinformatics, BMC Bioinformatics, SCFBM, PLOS CB, ACM/IEEE. Generated with twitterfeed) --> prob=[0.9270202688585896,0.07297973114141036], prediction=0.000000
# (News for @TribuneMedia. Former @NYDailyNews-er. Proselytizing morning person. Ask me about my favorite weird Florida story.) --> prob=[0.995199979513417,0.004800020486583007], prediction=0.000000
# (Ní£o se faz nada sozinho...) --> prob=[0.9752793546880498,0.02472064531195031], prediction=0.000000
# (Oculus VR CTO) --> prob=[0.9563965549735746,0.043603445026425484], prediction=0.000000
# (Official Bachelors of Education UOIT Account - #UOITBEd #BachelorsEd #Education #EdTech #UOIT #BachelorsOfEducation) --> prob=[0.9890422460948762,0.010957753905123893], prediction=0.000000
# (Pakistani by heart, Engineer by profession, and a Gooner by choice. #COYG #Pak #Arsenal) --> prob=[0.98691494225142,0.013085057748580127], prediction=0.000000
# (Papers on directed and self assembly) --> prob=[0.7432251505361558,0.25677484946384427], prediction=0.000000
# (Pearl Jam have launched a brand new website. Discover more:  https://t.co/1TasMMHPhd) --> prob=[0.992955167286568,0.0070448327134318995], prediction=0.000000
# (People spending money on real estate in the greatest city on earth / bot by @fitnr) --> prob=[0.9547962668660505,0.04520373313394952], prediction=0.000000
# (President - Intel Corporation) --> prob=[0.9902944987351421,0.009705501264857993], prediction=0.000000
# (Prince of Eternia and Defender of the Secrets of Castle Grayskull. Dislikes blue cheese.) --> prob=[0.9960217317655026,0.003978268234497527], prediction=0.000000
# (Psychotherapist. Special Education Advocate. Armchair Philosopher. Crusader for the downtrodden. Appreciator of good ideas. Film Buff. Mommy.) --> prob=[0.9975139804129816,0.002486019587018557], prediction=0.000000
# (Representing America! Official CSP NY Twitter handle. Follow for the latest in Business Affairs and financial extrapolation.) --> prob=[0.8510442465280587,0.14895575347194134], prediction=0.000000
# (Respect and love people who fear God .ARSENAL!!! My Favourite Football Club ! Venu,Serna !! You Guys !! Lets play Game,Set,Match!! Team Williams .) --> prob=[0.9999666144518259,3.338554817413158e-05], prediction=0.000000
# (Se eu fosse um animal, seria uma cigarra) --> prob=[0.9910795025902834,0.00892049740971662], prediction=0.000000
# (Send me a tweet & I'll give you some love. PS - I'm a computer, so words are my second language.) --> prob=[0.999906050376439,9.39496235610871e-05], prediction=0.000000
# (Senior Vice President of Stores dressbarn Student of the Universe. Inspired by great people, great companies, great stories, and game changing innovation.) --> prob=[0.9997597409584112,0.0002402590415887948], prediction=0.000000
# (Singer songwriter. Musician. Never give up and follow your dreams. Adventurer, Film Producer and board sport enthusiast. Snapchat: ericriethson IG: ericdrieth) --> prob=[0.9999798697307425,2.0130269257400165e-05], prediction=0.000000
# (Singlin pardise ..) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (Speaker. Investor. Radio Host @SiriusXM. Best Selling Author @DotComplicated Dot @Missy4Prez. Exec producer Dot @SproutChannel. Former Marketing @Facebook. Mom) --> prob=[0.9998828579145165,0.00011714208548353886], prediction=0.000000
# (Starting my second half of life) --> prob=[0.9962490488336873,0.0037509511663127754], prediction=0.000000
# (Swamp rock from Iowa that makes you get nude.) --> prob=[0.9930575854019147,0.006942414598085432], prediction=0.000000
# (Taylor Gang) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (Technology and culture Humor Music Entertainment) --> prob=[0.7151165118123279,0.2848834881876721], prediction=0.000000
# (The BEST Inspirational Quotes out there!) --> prob=[0.9907574051779334,0.009242594822066573], prediction=0.000000
# (The Official Buckcherry Twitter Page) --> prob=[0.9141972129523658,0.08580278704763428], prediction=0.000000
# (There is no need for that kind of language.) --> prob=[0.9943858051328652,0.005614194867134751], prediction=0.000000
# (This Privacy Policy addresses the collection and use of personal information - https://t.co/Jp6yh1T58c) --> prob=[0.8975145974110809,0.10248540258891903], prediction=0.000000
# (This is the David Mitchell who's in Peep Show and things, not the novelist or the Cumbrian origamist.) --> prob=[0.9685163672798811,0.03148363272011898], prediction=0.000000
# (Tweetbot about ice-templated or freeze-casted scientific papers. Update from #Pubmed and #Google #Scholar. Maintained by @DevilleSy) --> prob=[0.07100647645048817,0.9289935235495118], prediction=1.000000
# (Tweets randomly-generated 16x16 images using the NES color palette. Images are resampled for your viewing pleasure.) --> prob=[0.9809449577179931,0.0190550422820069], prediction=0.000000
# (UNL) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (Understand that your not alone, there is support for those diagnosed or curious about #Acromegaly. For more information: https://t.co/FXg432cnbZ) --> prob=[0.9887859269353597,0.011214073064640338], prediction=0.000000
# (Visual storyteller | Photographer based in Italy.) --> prob=[0.9965145201374572,0.003485479862542835], prediction=0.000000
# (We make and sell premium organic chocolate using fine, ethically sourced ingredients. Tweeting from our London HQ.) --> prob=[0.9846632202477386,0.015336779752261524], prediction=0.000000
# (White Lightning: https://t.co/2pa6U2H6FK Tender Green Life: https://t.co/n7rVF7tYJ3        Remix Album: https://t.co/3Oa4GNg8CU Aubreybooking@gmail.com) --> prob=[0.7291753974766386,0.2708246025233613], prediction=0.000000
# (Working for Mobility Solutions Bosch to prove and implement technology that meets and enhances our mobility needs, for a smarter, cleaner, more efficient city) --> prob=[0.9432174224462557,0.056782577553744176], prediction=0.000000
# (Zumba instrutor, ZumbAtomic instructor, Dance , Fitfreak Manchester) --> prob=[0.9789190963453982,0.02108090365460184], prediction=0.000000
# (a bot that retweets a bot that) --> prob=[0.9907219952936411,0.009278004706358962], prediction=0.000000
# (another one bites the dust || dancer) --> prob=[0.9669627714349016,0.03303722856509841], prediction=0.000000
# (follow for very best new academic papers using machine learning and natural language processing wow!!! // definitely not an idea generator for @thricedotted) --> prob=[0.978706113700666,0.02129388629933398], prediction=0.000000
# (historian of science, juggler, digital humanist, information scientist, OA advocate. irregular blogger. all views in tweets are somebody else's, I swear.) --> prob=[0.6963738875593627,0.30362611244063736], prediction=0.000000
# ...
# (Twitterbot of cichlid PubMed papers (inspired by @fly_papers). Image Astatotilapia calliptera, K. Woodhouse. Curated by @domino_joyce.) --> prob=[0.042194038901331776,0.9578059610986683], prediction=1.000000
# (a bot by @dbaker_h, inspired by @everycolorbot) --> prob=[0.9947956726488524,0.0052043273511475285], prediction=0.000000
# (assistant editor @cosmopolitan @snapchat discover | candace bushnell once called me the samantha jones of tinder | carina.hsieh at gmail dot com) --> prob=[0.9997974857642697,0.0002025142357302997], prediction=0.000000
# (black eil bries arebae) --> prob=[0.9444640181050276,0.0555359818949725], prediction=0.000000
# (every 6 hours - by @v21) --> prob=[0.9932311739065448,0.006768826093455241], prediction=0.000000
# (fartgoth) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (ha te world thinks) --> prob=[0.9768148707142348,0.02318512928576512], prediction=0.000000
# (https://t.co/NUKO1zr9PA Snapchat - TimWestwoodTV https://t.co/XXbxSWU1oL https://t.co/Ind8CtxJvR ..... Capital Xtra Saturday 7pm-11pm) --> prob=[0.9687958037605042,0.031204196239495774], prediction=0.000000
# (i headbang in the rock and roll band fall out boy. snapchat: peteweezy follow it _ÙÔä https://t.co/dgp6GakaCp) --> prob=[0.9995305270926564,0.00046947290734353203], prediction=0.000000
# (life's a beach man) --> prob=[0.9801434030802711,0.019856596919728933], prediction=0.000000
# (likely Autechre song titles // aåÊbot byåÊ@inky) --> prob=[0.992267192707592,0.007732807292408048], prediction=0.000000
# (simple girl; lover of art; self proclaimed Queen of facial expressions; proud dork; Elephants & animated film enthusiast  #Bruins #Pats _ôÖ_ô_Â_ôÖìäìë) --> prob=[0.9990777742282348,0.0009222257717651976], prediction=0.000000
# (student) --> prob=[0.9592673595331678,0.04073264046683225], prediction=0.000000
# (they made me smile as oon as  pressd play) --> prob=[0.9956113664158526,0.00438863358414734], prediction=0.000000
# (traveller,like being introvert,always learner,discovering oneself, fascinate about data) --> prob=[0.9567183249994499,0.04328167500055006], prediction=0.000000
# (trust yr technolust) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (video boy at @polygon äó¢ anime liker äó¢ @CoolGamesInc co-host äó¢ other videos on https://t.co/17vp1IHXJF and streams on https://t.co/uwZQfDr98a äÖ_¥Ÿ) --> prob=[0.9982173974675584,0.0017826025324416503], prediction=0.000000
# (íŠ relativo porque tudo depende...) --> prob=[0.9645689193322413,0.03543108066775861], prediction=0.000000
# (‰ÛÏGenius is... inspiration...‰Û ‰ÛÓThomas Alva Edison) --> prob=[0.9661343138839865,0.033865686116013524], prediction=0.000000
# ( IN""") --> prob=[0.9441825701599175,0.05581742984008245], prediction=0.000000
# ( VA""") --> prob=[0.9441825701599175,0.05581742984008245], prediction=0.000000
# ("""Every Mon-Tues at 10 PM KST | Jisung) --> prob=[0.9795810326927918,0.020418967307208123], prediction=0.000000
# ("""_______""") --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (*IN BETA* Low-res, slightly bizarre Open Access images from the Met (via @MuseumBot) crossed with palettes from @colourlovers. Powered by @uncontext. By @_ARP.) --> prob=[0.9990974628943575,0.000902537105642515], prediction=0.000000
# (@CNNTech editor. Previously: @Mashable. Pint sized and curious. Samantha.Kelly@Turner.com) --> prob=[0.9802902966246638,0.01970970337533622], prediction=0.000000
# (@NYUStern MBA student passionate about marketing, media, travel, and wine) --> prob=[0.9889510640944302,0.011048935905569768], prediction=0.000000
# (@dril's tweets, but for your home or office. A @dril you can bring home to your parents on Thanksgiving. #botALLY) --> prob=[0.9714739171966671,0.028526082803333], prediction=0.000000
# (@indexventures, @Dropbox, Startups, Physics.) --> prob=[0.9539119863077788,0.046088013692221166], prediction=0.000000
# (A dad, hubby of @jessvpeterson, long-time original @themisfits fan, @Mashable CTO, @WWE board member, and a mediocre snowboarder.) --> prob=[0.9994278232626678,0.0005721767373322379], prediction=0.000000
# (A feed for papers in network biology.) --> prob=[0.16345662220243035,0.8365433777975697], prediction=1.000000
# (Actor...who loves to make ppl laugh... ..https://t.co/lvWDr6NKFZ) --> prob=[0.9675077435723686,0.03249225642763137], prediction=0.000000
# (Agricultural Engineer, likes to joke and trying to live a certain balance between his laptop at the office and his shovel in the field.) --> prob=[0.9994942433462201,0.00050575665377995], prediction=0.000000
# (Anak Auhn Rmbulan A2R) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (BOT HARD EVE RY DAY TIL WE REACH THE GOAL #taskcomplete by @negatendo) --> prob=[0.9997880094550576,0.0002119905449423572], prediction=0.000000
# (Bot that scrapes Wikipedia and immediately tweets RIP messages when there is a celebrity death. Member of The Bot Collective, a project by @kildall) --> prob=[0.9972391015090689,0.0027608984909310587], prediction=0.000000
# (Breaking news alerts and updates from the BBC. For news, features, analysis follow @BBCWorld (international) or @BBCNews (UK). Latest sport news @BBCSport.) --> prob=[0.7343531440123008,0.2656468559876992], prediction=0.000000
# (Carbon-based multicellular lifeform.) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (Co-Founder @yellowmssngr & Botplatform.io. Entrepreneur in making. https://t.co/XPbVSKJAQ3 || https://t.co/g81AEpYMcX. Young Padawan.) --> prob=[0.541105718708855,0.45889428129114496], prediction=0.000000
# (Comedian. Writer. Been cheering up people since 2010.) --> prob=[0.9152828563743192,0.0847171436256808], prediction=0.000000
# (Connecting service design and customer experience to transform brands and grow businesses.) --> prob=[0.9918494193548131,0.008150580645186874], prediction=0.000000
# (Contact/booking: contactfreesol@gmail.com) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (Daily RSS feed for papers on Synthetic Lethality in Cancer. cancer AND (synthetic lethal OR synthetic lethality). Largely automated, don't expect responses) --> prob=[0.40117538689810195,0.5988246131018979], prediction=1.000000
# (Entertaining One Crore People) --> prob=[0.9743894797242096,0.02561052027579042], prediction=0.000000
# (Fake recaps of your favorite TV shows ‰Û¢ bot by @ckolderup & @jamiesoncox ‰Û¢ concept by @M_Weiland #vergehackweek #botALLY) --> prob=[0.9996263144822081,0.00037368551779180646], prediction=0.000000
# (Finance Minister, Minister of Corporate Affairs and Minister of Information and Broadcasting, Government of India) --> prob=[0.004294600469142531,0.9957053995308573], prediction=1.000000
# (Following the formula: I'm not X but I am the definition of X. (via @stefanhayden) Tweets every 10 minutes.) --> prob=[0.999797646138789,0.0002023538612110151], prediction=0.000000
# (Free follow! Follow @krishamil_) --> prob=[0.968356507343765,0.03164349265623505], prediction=0.000000
# (Galatians 6:9 - #DST ä_¥Ÿ - @NCATSUAggies Alumna - Morning News Producer @ABC7SWFL) --> prob=[0.9908413042088837,0.009158695791116236], prediction=0.000000
# (Generates a random wizard every 3 hours. | Bot by @THEWAAnderson) --> prob=[0.9992905727136591,0.0007094272863409491], prediction=0.000000
# (Hi. I'm Andrí© Marques, Brazilian. I'm 21 and I am part of Aracnofí£, a Brazilian website about Spider-Man.) --> prob=[0.9969270536510345,0.003072946348965514], prediction=0.000000
# (Host of The Herd 9-12 on @FS1 & @IHeartradio. SiriusXM ch 83. The Herd podcast on @iTunes. Co Host of @SFY. NYT Best Seller and Sundays on FOX NFL Kickoff.) --> prob=[0.999725025980789,0.00027497401921092315], prediction=0.000000
# (Host of The Roe Conn Show afternoons on Chicago's WGN Radio and contributor to ABC7's Windy City Live.) --> prob=[0.988573165090726,0.011426834909274096], prediction=0.000000
# (I am a walking conundrum. I'm also a mom and do mom stuff.) --> prob=[0.9881754556590415,0.0118245443409584], prediction=0.000000
# (I live in brooklyn, I'm a bike messenger, I play in a band, I'm uniquely doing the same exact things as everyone else) --> prob=[0.9993711058252784,0.0006288941747215751], prediction=0.000000
# (I'm a bot tweeting a random @andrewismusic lyric every two hours.) --> prob=[0.9967226474526186,0.003277352547381375], prediction=0.000000
# (I'm a twitterised, neon display, clock. Tweet with #NixieBotShowMe and a word, full guide on tumblr. Be patient with long queues. Queue : Empty) --> prob=[0.9978190442069338,0.002180955793066319], prediction=0.000000
# (Instagram: @GeneSimmons) --> prob=[0.9829808539700642,0.01701914602993589], prediction=0.000000
# (It is a thousand times better to have common sense without education than to have education without common sense.) --> prob=[0.9996178157879045,0.00038218421209551074], prediction=0.000000
# (It's not like the fire ended in 1989, so this bot by @air_hadoken makes new lyrics for the Billy Joel classic based on Google Trends. #botALLY) --> prob=[0.9998018345009828,0.00019816549901724494], prediction=0.000000
# (Keep up to date on the latest publications on the universal second messenger Cyclic di-GMP with this twitter feed of up to date publications.) --> prob=[0.6381305274683049,0.36186947253169516], prediction=0.000000
# (Literature bot searching arXiv, biorXiv, PeerJ & PubMed for supercoiling papers. Maintained by @red_gravel.) --> prob=[2.514922805652125e-05,0.9999748507719435], prediction=1.000000
# (Looking for a bot that generates random netflix taglines? You just found one. Lucky.) --> prob=[0.9983007777797717,0.001699222220228355], prediction=0.000000
# (MAX WEISS BUFFALO NY 26 AND FLY) --> prob=[0.96538683464129,0.034613165358709994], prediction=0.000000
# (My new album #Glory is out now!) --> prob=[0.9918876231600912,0.008112376839908775], prediction=0.000000
# (Nessa sofríÈncia que í© amar vocíÈ) --> prob=[0.973062425677461,0.026937574322539064], prediction=0.000000
# (Official Anthony Edwards Twitter Page) --> prob=[0.9068826778908964,0.09311732210910349], prediction=0.000000
# (PhD Candidate, Carnegie Mellon University. Chair of Advocacy Board, NAGPS.) --> prob=[0.9973119008556337,0.0026880991443662696], prediction=0.000000
# (Publisher and founder of Juggernaut Books) --> prob=[0.9945892421106269,0.005410757889373155], prediction=0.000000
# (Pubmed RSS paper feed on cohesin and its 'friends': condensin, Smc5/6, Scc2 (NIPBL), Scc4 (Mau2) and MukBEF.) --> prob=[0.045763015894899145,0.9542369841051008], prediction=1.000000
# (Recent meiosis papers from pubmed RSS and bioR?iv. Maintained by @pmcarlton) --> prob=[0.02444181836976238,0.9755581816302377], prediction=1.000000
# (Retweets people trying to find the perfect German word. - via @stefanhayden) --> prob=[0.9956712561440813,0.00432874385591865], prediction=0.000000
# (Rock 'N Roll!) --> prob=[0.9718888768869229,0.028111123113076966], prediction=0.000000
# (Rocket Ship Builder (that was Twitter's default option... how perfect)) --> prob=[0.9712100538216785,0.028789946178321556], prediction=0.000000
# (Stanford is one of the world's leading research and teaching institutions. Official Twitter feed by University Communications.) --> prob=[0.8885832255212579,0.11141677447874207], prediction=0.000000
# (Station 51000 went adrift on 3/10/2013. Unmoored, the NOAA buoy now transmits observation data from an unknown location.) --> prob=[0.9945440799519136,0.005455920048086307], prediction=0.000000
# (TV Host Fox News Channel 10 PM. Nationally Syndicated Radio Host 3-6 PM EST. https://t.co/z23FRgA02S  Retweets, Follows NOT endorsements!) --> prob=[0.9759894107714113,0.024010589228588692], prediction=0.000000
# (The Place To Learn Anything, Anywhere For All) --> prob=[0.9911789341098028,0.00882106589019709], prediction=0.000000
# (The Summits of the Americas bring together the democratically elected Heads of State of the Americas. The OAS serves as the technical secretariat of the process) --> prob=[0.9711479992919335,0.028852000708066615], prediction=0.000000
# (Trying to understand how brains think and create culture) --> prob=[0.9902690515596633,0.009730948440336836], prediction=0.000000
# (Tweets new releases on Netflix Instant. Created by @zak123. Check out @Redbox_bot as well. Updates between 5-7AM MST Every Morning.) --> prob=[0.9989130424952093,0.0010869575047906244], prediction=0.000000
# (Under Construction) --> prob=[0.9821314624119268,0.017868537588073174], prediction=0.000000
# (Updated by Luke O'Dell, Senior Lecturer in NMR Spectroscopy at Deakin University, Australia.) --> prob=[0.9990430352499873,0.0009569647500126771], prediction=0.000000
# (YOLO you only live once) --> prob=[0.9791397124365203,0.02086028756347971], prediction=0.000000
# (a little disappointed tbh) --> prob=[0.9700859610888731,0.029914038911126855], prediction=0.000000
# (an infinity of deserts, each more infinite than the last. bot mapped by @getdizzzy) --> prob=[0.997797958884298,0.002202041115701941], prediction=0.000000
# (by @NoraReed) --> prob=[0.970090386082513,0.029909613917487123], prediction=0.000000
# (generating cards for a mysterious card game åá bot by @ckolderup åá #botALLY åá avatar by Dmitriy Ivanov from the Noun Project) --> prob=[0.9998970058022786,0.00010299419772142137], prediction=0.000000
# (http://t.co/rn21deoPKI) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (i know right? #wowwwnetwork) --> prob=[0.9732365495920751,0.02676345040792492], prediction=0.000000
# (i steal from @TVFaceBot and maybe from you, too. @BooDooPerson made me. You can watch my birth! https://t.co/KwqWaVFKGN #botALLY) --> prob=[0.9995655407246657,0.0004344592753343212], prediction=0.000000
# (it's never not funny‹ÄÈ#botALLY‹ÄÈ#wowwwnetwork) --> prob=[0.9964376153802258,0.003562384619774217], prediction=0.000000
# (prabida) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (secr) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (you're here with me now) --> prob=[0.9912732694176555,0.008726730582344456], prediction=0.000000
# ( England""") --> prob=[0.9943897774465229,0.005610222553476962], prediction=0.000000
# ("""") --> prob=[0.5715773822711883,0.42842261772881174], prediction=0.000000
# ("""Katie Lin""") --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (20 Something in NJ.) --> prob=[0.9771089482491417,0.022891051750858385], prediction=0.000000
# (Everybody's lookin' forward to the weekend!) --> prob=[0.908780836322988,0.09121916367701202], prediction=0.000000
# (Father. Artist. Producer. Actor. Entrepreneur. Philanthropist.) --> prob=[0.9920838241581735,0.007916175841826353], prediction=0.000000
# (Great Lakes oceanographer, banjo player) --> prob=[0.9694479522385485,0.030552047761451394], prediction=0.000000
# (Hi, I'm Sharri and I will help review products for you!) --> prob=[0.9629846033378747,0.03701539666212531], prediction=0.000000
# (If a girl is stupid enough to love you after you broke her heart, I guarantee you. She is the one.) --> prob=[0.9953732897895989,0.004626710210400953], prediction=0.000000
# (Instagram : Trviswilliams) --> prob=[0.9625432426454449,0.03745675735455505], prediction=0.000000
# (OA OPERATIVA DE DEFENSA INTEGRAL CAABOBO) --> prob=[0.9740244487614054,0.025975551238594664], prediction=0.000000
# (The Official American Country Countdown Twitter Page) --> prob=[0.9563527587753975,0.04364724122460248], prediction=0.000000
# (The complete works of composer JÌ_rgen Sebastian Bot. // by @inky) --> prob=[0.9966831315063898,0.00331686849361016], prediction=0.000000
# (Verizon Team Penske driver. Race winner in F1, Indycar, NASCAR, CART,  and Grand-AM.) --> prob=[0.990742127985969,0.009257872014031002], prediction=0.000000
# (You can't spell words without other words.) --> prob=[0.9775411370878928,0.022458862912107105], prediction=0.000000
# (http://t.co/YfHoThSDVQ...) --> prob=[0.9358962566077654,0.06410374339223453], prediction=0.000000
# (meio ogra mas o coraí_í£o í© de mocinha) --> prob=[0.9876265458329402,0.012373454167059792], prediction=0.000000

# %% [markdown]
# In the text output search for
# `prediction=1`
#
# And write in the chat which description got classified as bot!

# %% [markdown]
# In the text output search for
# `prediction=1`
#
# And write in the chat which description got classified as bot!

# %% [markdown]
# ## Exercise 3: Put everything together

# %% [markdown]
# ### CrossValidator, BinaryClassificationEvaluator and ParamGridBuilder functionality
#
# ✅ **Task :**
#
#
# CrossValidator provide us the ability to run multiple training set and testing set within one function call -
# `fit`.
#
# It runs the evaluation phase and chooses the best parameters.
#
# Read about `CrossValidator` in the [docs](https://spark.apache.org/docs/latest/ml-tuning.html) and integrate it into your pipeline.
#
# In the docs, search for `CrossValidator` `python` example.
#
# Copy the example to the notebook and adjust it to your needs.
#
# From the docs:
# >`CrossValidator` - K-fold cross validation performs model selection by splitting the dataset into a set of non-overlapping randomly partitioned folds which are used as separate training and test datasets e.g., with k=3 folds, K-fold cross validation will generate 3 (training, test) dataset pairs, each of which uses 2/3 of the data for training and 1/3 for testing. Each fold is used as the test set exactly once.
#
# <details><summary>Can't find the example, click here! </summary>
# <p>
#
# ```python
# from pyspark.ml import Pipeline
# from pyspark.ml.classification import LogisticRegression
# from pyspark.ml.evaluation import BinaryClassificationEvaluator
# from pyspark.ml.feature import HashingTF, Tokenizer
# from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
#
# # Prepare training documents, which are labeled.
# training = spark.createDataFrame([
#     (0, "a b c d e spark", 1.0),
#     (1, "b d", 0.0),
#     (2, "spark f g h", 1.0),
#     (3, "hadoop mapreduce", 0.0),
#     (4, "b spark who", 1.0),
#     (5, "g d a y", 0.0),
#     (6, "spark fly", 1.0),
#     (7, "was mapreduce", 0.0),
#     (8, "e spark program", 1.0),
#     (9, "a e c l", 0.0),
#     (10, "spark compile", 1.0),
#     (11, "hadoop software", 0.0)
# ], ["id", "text", "label"])
#
# # Configure an ML pipeline, which consists of tree stages: tokenizer, hashingTF, and lr.
# tokenizer = Tokenizer(inputCol="text", outputCol="words")
# hashingTF = HashingTF(inputCol=tokenizer.getOutputCol(), outputCol="features")
# lr = LogisticRegression(maxIter=10)
# pipeline = Pipeline(stages=[tokenizer, hashingTF, lr])
#
# # We now treat the Pipeline as an Estimator, wrapping it in a CrossValidator instance.
# # This will allow us to jointly choose parameters for all Pipeline stages.
# # A CrossValidator requires an Estimator, a set of Estimator ParamMaps, and an Evaluator.
# # We use a ParamGridBuilder to construct a grid of parameters to search over.
# # With 3 values for hashingTF.numFeatures and 2 values for lr.regParam,
# # this grid will have 3 x 2 = 6 parameter settings for CrossValidator to choose from.
# paramGrid = ParamGridBuilder() \
#     .addGrid(hashingTF.numFeatures, [10, 100, 1000]) \
#     .addGrid(lr.regParam, [0.1, 0.01]) \
#     .build()
#
# crossval = CrossValidator(estimator=pipeline,
#                           estimatorParamMaps=paramGrid,
#                           evaluator=BinaryClassificationEvaluator(),
#                           numFolds=2)  # use 3+ folds in practice
#
# # Run cross-validation, and choose the best set of parameters.
# cvModel = crossval.fit(training)
#
# # Prepare test documents, which are unlabeled.
# test = spark.createDataFrame([
#     (4, "spark i j k"),
#     (5, "l m n"),
#     (6, "mapreduce spark"),
#     (7, "apache hadoop")
# ], ["id", "text"])
#
# # Make predictions on test documents. cvModel uses the best model found (lrModel).
# prediction = cvModel.transform(test)
# selected = prediction.select("id", "text", "probability", "prediction")
# for row in selected.collect():
#     print(row)
# ```
#
# </p>
# </details>

# %% [markdown]
# <details><summary>Answer</summary>
# <p>
#
# ```python
# from pyspark.ml import Pipeline
# from pyspark.ml.classification import LogisticRegression
# from pyspark.ml.evaluation import BinaryClassificationEvaluator
# from pyspark.ml.feature import HashingTF, Tokenizer
# from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
#
#
# # We now treat the Pipeline as an Estimator, wrapping it in a CrossValidator instance.
# # This will allow us to jointly choose parameters for all Pipeline stages.
# # A CrossValidator requires an Estimator, a set of Estimator ParamMaps, and an Evaluator.
# # We use a ParamGridBuilder to construct a grid of parameters to search over.
# # With 3 values for hashingTF.numFeatures and 2 values for lr.regParam,
# # this grid will have 3 x 2 = 6 parameter settings for CrossValidator to choose from.
# paramGrid = ParamGridBuilder() \
#     .addGrid(hashingTF.numFeatures, [10, 100, 1000]) \
#     .addGrid(lr.regParam, [0.1, 0.01]) \
#     .build()
#
#
# crossval = CrossValidator(estimator=pipeline,
#                           estimatorParamMaps=paramGrid,
#                           evaluator=BinaryClassificationEvaluator(),
#                           numFolds=3)  # use 3+ folds in practice
#
#
# # Run cross-validation, and choose the best set of parameters.
# cvModel = crossval.fit(trainingData)
#
# prediction = cvModel.transform(testData)
# selected = prediction.select("description", "probability", "prediction")
# for row in selected.collect():
#     print(row)
#
# ```
#
# </p>
# </details>

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.feature import HashingTF, Tokenizer
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder


# We now treat the Pipeline as an Estimator, wrapping it in a CrossValidator instance.
# This will allow us to jointly choose parameters for all Pipeline stages.
# A CrossValidator requires an Estimator, a set of Estimator ParamMaps, and an Evaluator.
# We use a ParamGridBuilder to construct a grid of parameters to search over.
# With 3 values for hashingTF.numFeatures and 2 values for lr.regParam,
# this grid will have 3 x 2 = 6 parameter settings for CrossValidator to choose from.
paramGrid = ParamGridBuilder() \
    .addGrid(hashingTF.numFeatures, [10, 100, 1000]) \
    .addGrid(lr.regParam, [0.1, 0.01]) \
    .build()


crossval = CrossValidator(estimator=pipeline,
                          estimatorParamMaps=paramGrid,
                          evaluator=BinaryClassificationEvaluator(),
                          numFolds=3)  # use 3+ folds in practice


# Run cross-validation, and choose the best set of parameters.
cvModel = crossval.fit(trainingData)

prediction = cvModel.transform(testData)
selected = prediction.select("description", "probability", "prediction")
for row in selected.collect():
    print(row)
# Out:
# Row(description=' CA"""', probability=DenseVector([0.9207, 0.0793]), prediction=0.0)
# Row(description=' England"""', probability=DenseVector([0.956, 0.044]), prediction=0.0)
# Row(description=' Northern Ireland"""', probability=DenseVector([0.9732, 0.0268]), prediction=0.0)
# Row(description='"""Affordable & Professional Printing Services for Businesses & Individuals. For Cheapest Printing Prices Mail us sales@print365.ie #printing #Ireland"""', probability=DenseVector([0.9774, 0.0226]), prediction=0.0)
# Row(description='"""Ai__"""', probability=DenseVector([0.9358, 0.0642]), prediction=0.0)
# Row(description='"""AlolaFen"""', probability=DenseVector([0.8945, 0.1055]), prediction=0.0)
# Row(description='"""I am one with the force', probability=DenseVector([0.8956, 0.1044]), prediction=0.0)
# Row(description='"""Professional footballer. Liverpool FC and Belgium National Team. https://t.co/mRsHZl5v9t"""', probability=DenseVector([0.9305, 0.0695]), prediction=0.0)
# Row(description='"""Rare and strong PokŽmon in Las Vegas and Spring Valley. See more PokŽmon at https://t.co/GB4nYu29n3"""', probability=DenseVector([0.6687, 0.3313]), prediction=0.0)
# Row(description='"""________________________________________________\\n__________________________\\n________________________________"""', probability=DenseVector([0.9462, 0.0538]), prediction=0.0)
# Row(description='"""westlife1219"""', probability=DenseVector([0.9346, 0.0654]), prediction=0.0)
# Row(description='"New single ""KILL AGAIN"" out now! https://t.co/qiZ8W4mhJG Shaka Zulu! https://t.co/9ZY92tEQaX https://t.co/uBNsayp9Gr"', probability=DenseVector([0.9836, 0.0164]), prediction=0.0)
# Row(description='*record scratch* *freeze frame* You might be wondering how this bot got here. @lanewinfield made it and it tweets ~10x/day Rand YT videos + fav TV/movie trope', probability=DenseVector([0.9917, 0.0083]), prediction=0.0)
# Row(description='22 | Electrical Engineering from LUMS | Football | Music | Friends | GYM', probability=DenseVector([0.9347, 0.0653]), prediction=0.0)
# Row(description='25', probability=DenseVector([0.9236, 0.0764]), prediction=0.0)
# Row(description='4 booking CHRIS SMITH 310-550-4245 SNAPCHAT MARLONLWAYANS IG @marlonwayans 1/29 live love laugh get tix for my SCANDALESS comedy tour https://t.co/AnSLqIeURj', probability=DenseVector([0.9727, 0.0273]), prediction=0.0)
# Row(description='8yr NFL Vet, ESPN Los Angeles & Los Angeles Rams Pregame and Postgame Analyst, Sirius XM NFL Analyst, SDSU Football Radio Color Analyst', probability=DenseVector([0.9989, 0.0011]), prediction=0.0)
# Row(description='@WhiteHouse Chief of Staff. Tweets may be archived: https://t.co/eVVzoBb3Zr.', probability=DenseVector([0.8869, 0.1131]), prediction=0.0)
# Row(description="A bot with all the latest news about Nintendo's Amiibo!!! Except it's all not true!!! #botALLY (by @ckolderup)", probability=DenseVector([0.9657, 0.0343]), prediction=0.0)
# Row(description='A place for fans to connect! Tweeting from Mumbai and the world! #Bollywood #India #Parody', probability=DenseVector([0.9411, 0.0589]), prediction=0.0)
# Row(description='A poetry project created by Alison Knowles and James Tenney and the Siemens 4004 computer in 1967. Twitter version by @hugovk and SSBot for #D004x in 2015.', probability=DenseVector([0.9616, 0.0384]), prediction=0.0)
# Row(description='A twitterbot dedicated to supplying the most recent papers about p53, the Guardian of the Genome.', probability=DenseVector([0.4744, 0.5256]), prediction=1.0)
# Row(description='ALL THE #HOTTEST #GAMES #MEMES | #botALLY by @BooDooPerson', probability=DenseVector([0.942, 0.058]), prediction=0.0)
# Row(description='Account run by the 23rd Prime Minister of Canada and staff‰Û_ Compte gÌ©rÌ© par le 23e premier ministre du Canada et personnel.', probability=DenseVector([0.946, 0.054]), prediction=0.0)
# Row(description='Actor and writer currently working on new TV comedy @GreatIndoorsCBS Instagram ‰ÛÒ stephenfryactually _Ù\x8f_•ü\x8f‰Û\x8d_ÙÎö', probability=DenseVector([0.8529, 0.1471]), prediction=0.0)
# Row(description="Advice is what we ask for when we already know the answer but wish we didn't.", probability=DenseVector([0.897, 0.103]), prediction=0.0)
# Row(description='All the things we should have or do or know by now. (bot by @RobertVinluan.  #botAlly) BEST OF 2014: http://t.co/uEnYFb68eV', probability=DenseVector([0.7305, 0.2695]), prediction=0.0)
# Row(description='Amazing facts from the good people at mental_floss magazine.', probability=DenseVector([0.939, 0.061]), prediction=0.0)
# Row(description='Author', probability=DenseVector([0.924, 0.076]), prediction=0.0)
# Row(description='Automated paper feed twitter bot for academics interested in parasitic worms, gut parasites and anthelminthics', probability=DenseVector([0.835, 0.165]), prediction=0.0)
# Row(description='CEO @Shapeways. I love 3D printers, making stuff, digital manufacturing, the internet and a good conversation.', probability=DenseVector([0.9888, 0.0112]), prediction=0.0)
# Row(description='COLOMBIA_ôñ\x8dShawn, UJ, Josh follow. Tyra and cejaspobladas liked.', probability=DenseVector([0.9023, 0.0977]), prediction=0.0)
# Row(description='Chairman and CEO of #Kaspersky Lab. Waging war against #malware for 27 years. #Infosec, #cybercrime, #cyberwar. Views are my own.', probability=DenseVector([0.9927, 0.0073]), prediction=0.0)
# Row(description='Chief Scientist of Baidu; Chairman and Co-Founder of Coursera; Stanford CS faculty. #machinelearning, #deeplearning #MOOCs, #edtech', probability=DenseVector([0.7546, 0.2454]), prediction=0.0)
# Row(description='Chronicling men doing things. // A bot by @tinysubversions, Powered By Giphy', probability=DenseVector([0.961, 0.039]), prediction=0.0)
# Row(description='Co-Founder @SNKRINC, CEO ??2D Productions (fmr MTV, VH1, CMT digital head , AOL video prez)', probability=DenseVector([0.9307, 0.0693]), prediction=0.0)
# Row(description='Co-Founder and Chairman of @Stocktwits, GP of Social Leverage, Wallstrip creator (acquired by $CBS), Momentum, Stocks & LOL hunter..Love Popcorn', probability=DenseVector([0.9917, 0.0083]), prediction=0.0)
# Row(description='Cricket fanatic, WWE fan, wannabe coder who is currently trapped in Jamshedpur', probability=DenseVector([0.928, 0.072]), prediction=0.0)
# Row(description='Curation and content @kickstarter. Writer, editor, Canadian.', probability=DenseVector([0.914, 0.086]), prediction=0.0)
# Row(description='DAD: weird conversation joke is bae ME: ugh dad no DAD: [something unhip] // a bot by @tinysubversions', probability=DenseVector([0.9553, 0.0447]), prediction=0.0)
# Row(description='Daily RSS Feed for Protein Hot Spot Prediction papers. Maintained by @selinkaragulle', probability=DenseVector([0.2215, 0.7785]), prediction=1.0)
# Row(description='Dashboard Confessional Tix available NOW for our up close and personal tour in Jan and Feb of 2017: https://t.co/Bj0G7NIhy1', probability=DenseVector([0.9842, 0.0158]), prediction=0.0)
# Row(description='De um lado a poesia, o verbo, a saudade... Do outro a luta, forí_a e coragem pra chegar no fim!', probability=DenseVector([0.9611, 0.0389]), prediction=0.0)
# Row(description='Designing and making games @nytdesign _Ò\x8d side project haver _Ò\x8d see also: @itsthisyear, @icebergdotcool, @ramsophone, @__birds__ _Ò\x8d', probability=DenseVector([0.9925, 0.0075]), prediction=0.0)
# Row(description='Destigmatizing a misunderstood and unappreciated part of our vocabulary.', probability=DenseVector([0.9798, 0.0202]), prediction=0.0)
# Row(description='Director of Stewardship @newspring', probability=DenseVector([0.9548, 0.0452]), prediction=0.0)
# Row(description='Don‰Ûªt worry about cool, make your own uncool. Make your own, your own world. Sol LeWitt -- Eva Hesse -- us.', probability=DenseVector([0.9476, 0.0524]), prediction=0.0)
# Row(description='Entrepreneur, mentor, angel investor (and mom of twins!) coaching women entrepreneurs and leaders.', probability=DenseVector([0.985, 0.015]), prediction=0.0)
# Row(description="Ever wondered what a thing is? Follow this ontography machine, powered by tweets proclaiming that something 'is apparently a thing.' By @staeiou", probability=DenseVector([0.978, 0.022]), prediction=0.0)
# Row(description='Every website from the Internet International Directory, published 1995 (many dead links)', probability=DenseVector([0.7139, 0.2861]), prediction=0.0)
# Row(description='Exceptional GMAT classes and MBA admissions coaching in Austin, TX.', probability=DenseVector([0.9737, 0.0263]), prediction=0.0)
# Row(description='FOLLOW @devonxxbt AND RETWEET/LIKE HER PINNED', probability=DenseVector([0.8931, 0.1069]), prediction=0.0)
# Row(description='Fav and RT the superior word in each matchup. Goooal! A tribute to @everyword / @aparrish by @johnholdun', probability=DenseVector([0.9683, 0.0317]), prediction=0.0)
# Row(description='Feeling adventurous? Try one of these!', probability=DenseVector([0.9516, 0.0484]), prediction=0.0)
# Row(description='Female', probability=DenseVector([0.9324, 0.0676]), prediction=0.0)
# Row(description='Founder and Chairman of Rasmussen Global', probability=DenseVector([0.948, 0.052]), prediction=0.0)
# Row(description="Free Follow for @jalfiebutler ... follow back please or I'll unfollow _Ùªâ", probability=DenseVector([0.9153, 0.0847]), prediction=0.0)
# Row(description='Fresh E3 rumours every 3 hours! Made by @warandpeace with http://t.co/XpDuja7Q2I. Inspired by @TheBlackNerd, @sokareemie, @mikesacco, & @tinysubversions', probability=DenseVector([0.9874, 0.0126]), prediction=0.0)
# Row(description='From late 2014 Socium Marketplace will make shopping for fundamental business services more simple, more cost effective and more about you.', probability=DenseVector([0.468, 0.532]), prediction=1.0)
# Row(description='Good life, good health, good work.', probability=DenseVector([0.9767, 0.0233]), prediction=0.0)
# Row(description='Governor of South Carolina', probability=DenseVector([0.9729, 0.0271]), prediction=0.0)
# Row(description='Graduate student at NYU Tandon School of Engineering. Fan-fic reader and engineer by day soccer defender at night. Manchester United FC is life.', probability=DenseVector([0.9913, 0.0087]), prediction=0.0)
# Row(description='Grammy Award Winner https://t.co/n9Rl67gSUz - https://t.co/wzMnEiCDUM - Contact: https://t.co/pSbZI5acbu', probability=DenseVector([0.9218, 0.0782]), prediction=0.0)
# Row(description='Hello! I am a loving friend bot! @mossdogmusic and @inurashii created me (with help from @cirne) and I love you all very much!', probability=DenseVector([0.9211, 0.0789]), prediction=0.0)
# Row(description='Hello, I am African and Indian, Artist, Work, Pub, Design, Culture. Deco, Drawings, theater, Movie,  _ôÖ\x81_ôïñ_ôïî_ôï__ôë\x90_ô_¬äì\x8f¥Ÿ\x8f_ô_Â_ô\x8dÂ_ô\x8dÁ_ô_Â_ô\x8dÂ_ô\x8d‚_ô\x8d©_ô\x8dÈ_ô\x8d__ô\x8d\x9d_ô_¿_ô___ô\x8fó_ô\x8f\x90ä__¥Ÿ\x8f_ô___ô___ô___ô___ôñŸ_ôñé_ô___ô__...', probability=DenseVector([0.833, 0.167]), prediction=0.0)
# Row(description="Hi, I'm Pretty. #digitalarchival. Virus Corp. Mad King Ludwig GPS. #techtraderoutes #insideTarasphone #whatsgoingon101 #otherpeoplesadvertising", probability=DenseVector([0.9715, 0.0285]), prediction=0.0)
# Row(description='Historian & classicist with a particular interest in linguistics & philology, ancient & modern, English or not. Fair range of contemporary interests, too.', probability=DenseVector([0.7168, 0.2832]), prediction=0.0)
# Row(description='Hosts @KeiserReport on @RT_com, recommended bitcoin at $3', probability=DenseVector([0.9754, 0.0246]), prediction=0.0)
# Row(description='I am a moose. I am made of chocolate.', probability=DenseVector([0.964, 0.036]), prediction=0.0)
# Row(description='I cant complain but sometimes I still do', probability=DenseVector([0.9751, 0.0249]), prediction=0.0)
# Row(description='I find tweets about Danny Devito.', probability=DenseVector([0.8529, 0.1471]), prediction=0.0)
# Row(description='I have something to say about all the games.', probability=DenseVector([0.7646, 0.2354]), prediction=0.0)
# Row(description='I luv Zendya. She is SO awesome. Shak it up is my favorite disney channel show. teamfollowback zswager :3', probability=DenseVector([0.8806, 0.1194]), prediction=0.0)
# Row(description="I make video games, and have a beautiful wife with 4 boys. It's nutty!", probability=DenseVector([0.9481, 0.0519]), prediction=0.0)
# Row(description='I received  M. Sc. and  Ph. D. degrees in CS from Univ. of Lille I,France. Now 100 Talents Professor at CNIC, Chinese Academy of Sciences', probability=DenseVector([0.8654, 0.1346]), prediction=0.0)
# Row(description='I tweet a random object from the collection of the Museum of Modern Art four times a day. Bot by @backspace (not affiliated with @MuseumModernArt)', probability=DenseVector([0.8924, 0.1076]), prediction=0.0)
# Row(description="I want you to know thatI am both happy and sadand I'm still trying to fgure out how that could be.", probability=DenseVector([0.9846, 0.0154]), prediction=0.0)
# Row(description="I'm a bot that hates it when people use words that aren't @everyword canon. #taskcomplete by @negatendo, who is sorry.", probability=DenseVector([0.9842, 0.0158]), prediction=0.0)
# Row(description="I'm a professor of history at Brooklyn College and the CUNY Graduate Center. Former Fulbright at @telavivuni; former track announcer at @ScarboroDowns.", probability=DenseVector([0.9738, 0.0262]), prediction=0.0)
# Row(description="I'm a robot tracking data for bad words. Don't mind me.", probability=DenseVector([0.9552, 0.0448]), prediction=0.0)
# Row(description="Indian, Hyderabadi, Red Devil, Manipalite, Terrapin, Philanthropist, In that order! I'm nt da guy that every girl needs, I'm da guy every girl deserves ;)", probability=DenseVector([0.9704, 0.0296]), prediction=0.0)
# Row(description='Instagram - Parineetichopra. Snapchat - ChopraParineeti', probability=DenseVector([0.9064, 0.0936]), prediction=0.0)
# Row(description='Interesting facts about the world we live in. Facebook: https://t.co/nKPHSWpSOr / Enquiries: tweetingfacts@gmail.com', probability=DenseVector([0.9441, 0.0559]), prediction=0.0)
# Row(description='Jai Hind !!', probability=DenseVector([0.9337, 0.0663]), prediction=0.0)
# Row(description='Jay Sean. Singer/Songwriter. Sony Music.', probability=DenseVector([0.9029, 0.0971]), prediction=0.0)
# Row(description='Jazz Singer, Crooner, Almost Dancer... Old school music is my game.', probability=DenseVector([0.9331, 0.0669]), prediction=0.0)
# Row(description='Jeopardy! fixture of yesteryear. Author of the Junior Genius Guides and a bunch of other stuff. https://t.co/6osivaktzC', probability=DenseVector([0.9169, 0.0831]), prediction=0.0)
# Row(description='Jornalista. Escritor. Ser humano. Testemunha ocular do fim do mundo.', probability=DenseVector([0.878, 0.122]), prediction=0.0)
# Row(description='Juan David Solarte Arana', probability=DenseVector([0.9676, 0.0324]), prediction=0.0)
# Row(description='Just a bot that tweets the https://t.co/ROXIqz0eDO RSS feed. Not associated with https://t.co/1NJoBtBGWo / @grantsdotgov in any way. Maintained by @EcoEvoGames.', probability=DenseVector([0.887, 0.113]), prediction=0.0)
# Row(description="Just pingin' away at @poll to make sure the whole stack is in working order. I'm bored :(", probability=DenseVector([0.9057, 0.0943]), prediction=0.0)
# Row(description='Keeping our nation safe by arguing with RINOs like @EdTaters...  and you! A retired bot created by @leonardr.', probability=DenseVector([0.9624, 0.0376]), prediction=0.0)
# Row(description='Life is better than death; I believe; if only because it is less boring; and because it has fresh peaches in it.', probability=DenseVector([0.9293, 0.0707]), prediction=0.0)
# Row(description='MP for Thiruvananthapuram. Author of 16 books. Former Minister of State,Govt.of India.  Former UnderSecretaryGeneral,UnitedNations. RTs do not imply endorsement', probability=DenseVector([0.9036, 0.0964]), prediction=0.0)
# Row(description='Mantra: I empower people. Chief evangelist of @Canva https://t.co/7AwtiXC7jr. Author of thirteen books. Former chief evangelist of Apple.', probability=DenseVector([0.9469, 0.0531]), prediction=0.0)
# Row(description='Memphis, TN', probability=DenseVector([0.9624, 0.0376]), prediction=0.0)
# Row(description="Moderator of @meetthepress and @nbcnews political director; Covering politics since '92; And, yes, I tweet about sports too.", probability=DenseVector([0.9539, 0.0461]), prediction=0.0)
# Row(description='Mom, Mimi, Navair BFM, tree hugger.', probability=DenseVector([0.8657, 0.1343]), prediction=0.0)
# Row(description='NBA Forward, Danilo Gallinari Instagram @danilogallogallinari Facebook Danilo Gallinari', probability=DenseVector([0.8142, 0.1858]), prediction=0.0)
# Row(description='New album, A Head Full Of Dreams, out now worldwide. #AHFODtour runs through 2017. Spanish language account: @coldplay_es', probability=DenseVector([0.9126, 0.0874]), prediction=0.0)
# Row(description='New words, by @derekarnold', probability=DenseVector([0.9378, 0.0622]), prediction=0.0)
# Row(description='Nine years in the NFL. Two rings.', probability=DenseVector([0.8998, 0.1002]), prediction=0.0)
# Row(description='Not right wing... Just Right. #freedom #capitalism #objectivism https://t.co/Iq5MEjcBnU', probability=DenseVector([0.9526, 0.0474]), prediction=0.0)
# Row(description='Obsession with video games and kung-fu', probability=DenseVector([0.9024, 0.0976]), prediction=0.0)
# Row(description="Official Twitter site of NBA's All-Time Leading Scorer, New York Times best-selling author columnist, Time Magazine", probability=DenseVector([0.806, 0.194]), prediction=0.0)
# Row(description='Official page of Angie Harmon. Mother of three AMAZING kids, Unicef Ambassador, Writer, Director, LOVE being part of TNT Rizzoli & Isles', probability=DenseVector([0.8863, 0.1137]), prediction=0.0)
# Row(description='Papers on colouration and vision in nature (#colsci), mostly fed from #pubmed. Run by @TomEdWhite - suggestions welcome!', probability=DenseVector([0.74, 0.26]), prediction=0.0)
# Row(description="Passionate about my work, in love with my family and dedicated to spreading light. It's contagious! ;-) https://t.co/vZcUuNOKcz", probability=DenseVector([0.9774, 0.0226]), prediction=0.0)
# Row(description='Paz filhos da puta.', probability=DenseVector([0.9396, 0.0604]), prediction=0.0)
# Row(description='Platinum Recording Artist, Producer, Writer, Director, Art-Lover, Entrepreneur, 24/7 Creative Opportunist. Changing the world one song at a time..!', probability=DenseVector([0.976, 0.024]), prediction=0.0)
# Row(description='Praise is what I do...', probability=DenseVector([0.9515, 0.0485]), prediction=0.0)
# Row(description='Principal Engineer at @voxmediainc / @voxproduct. Tweets my own. Jokes shamelessly ripped from Reddit. Prev: @disqus, @threespot. ä\x9d_ StarCraft', probability=DenseVector([0.7558, 0.2442]), prediction=0.0)
# Row(description='Publication alert for genome-wide association studies @genomic_pred @mendelian_lit @wpgilks', probability=DenseVector([0.9013, 0.0987]), prediction=0.0)
# Row(description='Quoting those too often overlooked. Tweet a hashtag @the_underquoted to see if any quotes match that word. Tweets one unsolicited quote a day.', probability=DenseVector([0.9535, 0.0465]), prediction=0.0)
# Row(description='R&D: #ArtificialIntelligence, #AI, #DeepLearning, #NeuralNetworks, #MachineLearning, #Robotics, #Bionics, #Biometrics, #VR, #AR, etc. Founder & CEO @Rosenchild', probability=DenseVector([0.9513, 0.0487]), prediction=0.0)
# Row(description='REMEMBER MY NAME.', probability=DenseVector([0.9073, 0.0927]), prediction=0.0)
# Row(description='Read on Bustle,PlanetTransgender, CNNi,The Advocate,TheColu.mn,Gay-Essentials The NYT,HuffpoLive,Original Plumbing #girlslikeus Writer,Producer, Director,ENFP', probability=DenseVector([0.9302, 0.0698]), prediction=0.0)
# Row(description='Search Engineer', probability=DenseVector([0.914, 0.086]), prediction=0.0)
# Row(description='Serving clients for nearly 40 years. We buy and sell physical precious metals and prefer bitcoin but take most payment types. Not your average brokerage firm.', probability=DenseVector([0.9386, 0.0614]), prediction=0.0)
# Row(description='Solve the riddle by replying only the name of the person/character described! Created by @verhoevenben, @1vangro, @fvancesco, @pedrojmmartins at #codecampcc', probability=DenseVector([0.9913, 0.0087]), prediction=0.0)
# Row(description='Stand-upper, Zombie Therapist, Ball Dropper, Ravenclaw, @Nerdist Inventor and POINTS giver', probability=DenseVector([0.9456, 0.0544]), prediction=0.0)
# Row(description='Stay on top of all the latest publications on Biofilm research curated from PubMed. #biofilm #microbiology #antibioticresistance. Run by @mccarthy_ronan', probability=DenseVector([0.6587, 0.3413]), prediction=0.0)
# Row(description='Teacher and Educationist. ASCD Emerging Leader 2015/Tedx Speaker/ Founder Islamabad https://t.co/NjgxEvcwSm LEAD (pvt) Limited/Activist.', probability=DenseVector([0.9145, 0.0855]), prediction=0.0)
# Row(description='Tech/scifi/data enthusiast. Loves building digital things.', probability=DenseVector([0.918, 0.082]), prediction=0.0)
# Row(description='Tell me your successes, I want to steal them. Comm/design junkie, amenable traveler, political screamer, mediocre skeeballer. @NYUTandonTweets IDM MS Candidate.', probability=DenseVector([0.9599, 0.0401]), prediction=0.0)
# Row(description='The Mole Hole of Myrtle Beach,SC has been in business since 1978. We have the experience and selection to ensure our customers find something unique and special', probability=DenseVector([0.7608, 0.2392]), prediction=0.0)
# Row(description='The task that will complete is not an unvarying task. // a bot by @inky', probability=DenseVector([0.9671, 0.0329]), prediction=0.0)
# Row(description='This bot will post when anything gets added to the WWE Network. This is not an official WWE Account. Created by tgrollo@gmail.com', probability=DenseVector([0.9344, 0.0656]), prediction=0.0)
# Row(description='This should be the quickest route, but it depends on the traffic', probability=DenseVector([0.895, 0.105]), prediction=0.0)
# Row(description="Throw away your other Twitch bots. I'm the best Twitch bot you'll ever find. For support, visit https://t.co/MjyvbaH6TN.", probability=DenseVector([0.9511, 0.0489]), prediction=0.0)
# Row(description='Tweeting all the languages. All of them. Process should finish sometime in October 2015. Created by @OnnaAdele.', probability=DenseVector([0.8526, 0.1474]), prediction=0.0)
# Row(description="Tweets quotes [every hour] from Polygon's Monster Factory, starring Griffin and Justin McElroy! [run by @_AzureDragoon]", probability=DenseVector([0.9426, 0.0574]), prediction=0.0)
# Row(description='Twitterbot of nonribosomal or nrps or non-ribosomal in #Pubmed created and curated by jem.stach@ncl.ac.uk', probability=DenseVector([0.6375, 0.3625]), prediction=0.0)
# Row(description='Twittered every word in the English language. Task began in 2007 and completed in 2014. Buy the book! http://t.co/3OuWi3iCKy', probability=DenseVector([0.8419, 0.1581]), prediction=0.0)
# Row(description='Two division UFC World Champion. Two division Cage Warriors World Champion. Making history EVERYDAY!! #NOTORIOUS #EIRE', probability=DenseVector([0.9914, 0.0086]), prediction=0.0)
# Row(description='UN Office for the Coordination of Humanitarian Affairs (OCHA) in Asia and the Pacific provides key updates on humanitarian issues and disasters in the region', probability=DenseVector([0.7962, 0.2038]), prediction=0.0)
# Row(description='US 50k Record Holder. 4 Olympic Marathon Trials. 3 US Teams. TV analyst. Sports Agent. Believe in love, God, big dreams & hot salsa. NFL/Padres fan.', probability=DenseVector([0.9948, 0.0052]), prediction=0.0)
# Row(description='Uh, blame @tinysubversions for this one. (Actually one metaphor every two minutes. Twitter rate limits.)', probability=DenseVector([0.9934, 0.0066]), prediction=0.0)
# Row(description='Um blog sobre filmes, trilhas sonoras e curiosidades! Descontraí_do e eclí©tico! Siga a gente para receber as novidades!', probability=DenseVector([0.9907, 0.0093]), prediction=0.0)
# Row(description='University of Warwick Publications Service and WRAP. Simple Deposit: https://t.co/34Lw2ePmdP. Support via email: publications@warwick', probability=DenseVector([0.9489, 0.0511]), prediction=0.0)
# Row(description='Unofficial; imagery courtesy: Japan Meteorological Agency (https://t.co/lzPXaTnMCi) and CIRA (https://t.co/YksnDoJEl8). Bot by @__jcbl__', probability=DenseVector([0.9913, 0.0087]), prediction=0.0)
# Row(description='Vehicle', probability=DenseVector([0.8891, 0.1109]), prediction=0.0)
# Row(description='WI - CA - MA Family, Friends, Music, Sports, Shananagins, LIFE!', probability=DenseVector([0.8179, 0.1821]), prediction=0.0)
# Row(description="We're bringing clean and safe drinking water to people in need around the world.", probability=DenseVector([0.981, 0.019]), prediction=0.0)
# Row(description="Without forgiveness; there's no future.", probability=DenseVector([0.9538, 0.0462]), prediction=0.0)
# Row(description='[WORK IN PROGRESS] reminder bot. try  @mnemosynetron remind me to X at/in/on Y. // more notes in link // by and for @thricedotted', probability=DenseVector([0.9139, 0.0861]), prediction=0.0)
# Row(description='bot by @dbaker_h', probability=DenseVector([0.9063, 0.0937]), prediction=0.0)
# Row(description="butts. butt botts. butt things. https://t.co/9K7GC6ImGN #rumpology - @speckninja (bot favs tweets containing 'butt')", probability=DenseVector([0.7999, 0.2001]), prediction=0.0)
# Row(description="candle freak. tea addict. life enthusiast. let's dance, eat kale, and laugh til' we cry // snapchat - daniemo", probability=DenseVector([0.9167, 0.0833]), prediction=0.0)
# Row(description='folo: @bravowwhl, Insta: @bravoandy, Snap: AndysGotThe411, check out @RadioAndySXM - ch 102, tour info: https://t.co/wmQGwh2QWF', probability=DenseVector([0.9687, 0.0313]), prediction=0.0)
# Row(description="gentle affirmations for rough days/weeks/years, every 30 mins. just because a bot said them doesn't mean they're not true. call @chevalier_cygne with feedback", probability=DenseVector([0.9374, 0.0626]), prediction=0.0)
# Row(description='http://t.co/4PHOPJ3bDL', probability=DenseVector([0.9425, 0.0575]), prediction=0.0)
# Row(description='i am sia i was born from the bumhole of a unicorn named steve. New single The Greatest out now: https://t.co/bSJ8s4KyWU sia on tour: https://t.co/oBKYzDMZSN', probability=DenseVector([0.9697, 0.0303]), prediction=0.0)
# Row(description="i m calm, jolly person.................who has no matter what the other have.....but it matters for me why i don't have", probability=DenseVector([0.9867, 0.0133]), prediction=0.0)
# Row(description='im a bad friend and i might secretly want to kill you (by @starla4444)', probability=DenseVector([0.9672, 0.0328]), prediction=0.0)
# Row(description='just a river on twitter. made by @muffinista #botALLY', probability=DenseVector([0.9775, 0.0225]), prediction=0.0)
# Row(description='multilevel marketing,mmm. monitec, zewang, achieveyodreams, E.T. C.', probability=DenseVector([0.931, 0.069]), prediction=0.0)
# Row(description='nu merch: https://t.co/40NCLREgSv', probability=DenseVector([0.946, 0.054]), prediction=0.0)
# Row(description='pink team returning fire', probability=DenseVector([0.9525, 0.0475]), prediction=0.0)
# Row(description='see me live here https://t.co/bk16pVODRO', probability=DenseVector([0.8964, 0.1036]), prediction=0.0)
# Row(description='social contagionista. blogdiva extraordinaire. criminally prolific multilingual twittinfluencer. shmears gossip, news, sports & tech w/humor & profanity', probability=DenseVector([0.942, 0.058]), prediction=0.0)
# Row(description='tweets by Anderson Cooper. Anchor @AC360 and correspondent on @60Minutes. Author of NYTimes Best Seller - The Rainbow Comes And Goes https://t.co/1cZvasmMBi', probability=DenseVector([0.9224, 0.0776]), prediction=0.0)
# Row(description='water, melanin, bones, blood.', probability=DenseVector([0.9514, 0.0486]), prediction=0.0)
# Row(description="web developer, recent @devbootcamp grad - let's talk. dream project involves civic engagement or citizen science. queer immigrant enby treehugger. [they/she]", probability=DenseVector([0.9617, 0.0383]), prediction=0.0)
# Row(description='Î\x8fë_±_Î__Üó\x81IT\x8dî‡Üó\x81_´ÁÎ_„ICÎ‡«\x8dÂ†ÎŸšÜó\x81\x8f_‰_ñ\x8dÎ‡_Î_‰\x8d†„Üó\x81_ŠåÎ‡____ÎìÂÎ\x8d„__åÜó\x81_ìŠfoÎËƒÎ__Üó\x81_Ÿ\x8dfo\x8f_†Î_ÇÜó‰', probability=DenseVector([0.916, 0.084]), prediction=0.0)
# Row(description='Î\x8fëÎ_\x90Ü\x81¬Ü‰_Ü‰±Ü€çÜ€_Ü€¢Ü€ˆÜ€‚Ü‰ÍÜ\x81_Ü\x81ôÜ\x81»Ü‰Š_µ\x81Ü\x81»\x8f_£Îï_botÜó‰_µ‡Î__Ü‰_Ü‰±Ü€çÜ€_bot(@attractive_bot)Ü\x81†Ü‰Š_Ç_\x8dîôÜó‰\x8d¬ç\x8d\x90Ê___Î_¢(@fumicustodian)Üó‰Ü‰¢Ü‰_Ü‰_Ü€_Pletts TwinsÜó\x81Ü€ÖÜ€€Ü€óÜ€_Sampaio TwinsÜó‰', probability=DenseVector([0.9446, 0.0554]), prediction=0.0)
# Row(description='ä\x9d_', probability=DenseVector([0.9434, 0.0566]), prediction=0.0)
# Row(description='•_£•__•_¢•_´•__•_£•_ø•_¨•_¨•_´•_£•_«•_©•_¨•_¤‹ÛÛ•_£•__•_¢•_´•__•__•_ø•_µ‹ÛÛ•_£•__•_¢•_´•__•_á•_©•_«•_¬‹ÛÛ•_£•__•_¢•_´•__•_«•_¬•_´‹ÛÛ•_£•__•_¢•_´•__•_Â•_Á•_«•_´•__•_«‹ÛÛ•_£•__•_¢•_´•__•_¦•_ø•_£•_Á•_¢•_µ•_Â•_Á•__•__', probability=DenseVector([0.9385, 0.0615]), prediction=0.0)
# Row(description=' CA"""', probability=DenseVector([0.9207, 0.0793]), prediction=0.0)
# Row(description='""""', probability=DenseVector([0.9035, 0.0965]), prediction=0.0)
# Row(description='"""Am I cool yet?"""', probability=DenseVector([0.9613, 0.0387]), prediction=0.0)
# Row(description='"""Relationships are made of talk - and talk is for girls and women."""', probability=DenseVector([0.7888, 0.2112]), prediction=0.0)
# Row(description='"""The official Manchester City Twitter account | Supporter Services __ @ManCityHelp | Snapchat __ mancityofficial"""', probability=DenseVector([0.7214, 0.2786]), prediction=0.0)
# Row(description='"""The official Twitter account of New York City FC. For tickets and supporter services follow @NYCFCHelp. #NYCFC #WeAreOne"""', probability=DenseVector([0.737, 0.263]), prediction=0.0)
# Row(description='"""________"""', probability=DenseVector([0.9099, 0.0901]), prediction=0.0)
# Row(description='"""jogador do Chelsea FC - football player (Chelsea FC)"""', probability=DenseVector([0.9719, 0.0281]), prediction=0.0)
# Row(description='#DruHill20th  #LastDragon', probability=DenseVector([0.9386, 0.0614]), prediction=0.0)
# Row(description='#bitcoin #crypto #JS #Node, rockets, science. Liverpool JS founder, entrepreneur, words are mine unless hacked or intoxicated  0xb70b5e25f470bd12 https://t.co/z4GGcV07JH', probability=DenseVector([0.9078, 0.0922]), prediction=0.0)
# Row(description="#miracle out now #Karma new album out now @sonymusic @ultrarecords #Karma UK|European tour starting September16-Feb27 '17", probability=DenseVector([0.9929, 0.0071]), prediction=0.0)
# Row(description='7', probability=DenseVector([0.9189, 0.0811]), prediction=0.0)
# Row(description='@victor_zheng developed me to alert users in whose tweets I find improper grammar—he was inspired by @StealthMountain. To publish solecisms is to abase oneself!', probability=DenseVector([0.9133, 0.0867]), prediction=0.0)
# Row(description="A Markov-powered mashup of Erowid trip reports and tech recruiter emails. Run by @aphyr, who's not affiliated with Erowid. Heck, he's never even smoked pot.", probability=DenseVector([0.9794, 0.0206]), prediction=0.0)
# Row(description='A Twitter bot by @Quasimondo that creates random low-polygon versions of pictures it receives.https://t.co/ItJbIIQj01 #bot2bot was invented here.', probability=DenseVector([0.9248, 0.0752]), prediction=0.0)
# Row(description="A curated collection of news and opinions on DC's #startup ecosystem, #DCtech, and all things technology-related affecting the #DC metro area.", probability=DenseVector([0.7111, 0.2889]), prediction=0.0)
# Row(description='Absurd charts, twice daily. You get one flow chart and one Venn diagram. A bot by @tinysubversions', probability=DenseVector([0.97, 0.03]), prediction=0.0)
# Row(description='Actress, producer, singer, professional illuminator. Shop #IlluminateByAshley:', probability=DenseVector([0.918, 0.082]), prediction=0.0)
# Row(description='Always winning', probability=DenseVector([0.9312, 0.0688]), prediction=0.0)
# Row(description='An unfiltered view of EVERY SINGLE STEAM LAUNCH! A @dejobaan experiment bot. It creates 6s trailers, too: @MicroTrailers. Not affiliated with Steam.', probability=DenseVector([0.991, 0.009]), prediction=0.0)
# Row(description='Ancient Wisdom for Modern Living', probability=DenseVector([0.7881, 0.2119]), prediction=0.0)
# Row(description='Angel investor (@uber @thumbtack @wealthfront) Founder @Engadget @Inside @LAUNCH @twistartups / come to https://t.co/3Ugs6Cmos5', probability=DenseVector([0.9765, 0.0235]), prediction=0.0)
# Row(description='Animal videos sourced from @macaulaylibrary. Turn up the sound! // A bot by @tinysubversions. Not affiliated with the Macaulay Library.', probability=DenseVector([0.9777, 0.0223]), prediction=0.0)
# Row(description='Art Automata [bot]. See url below for how to help to keep me running.', probability=DenseVector([0.6731, 0.3269]), prediction=0.0)
# Row(description='Autodidact / Teammate / Building Brands People ‰\x9d_•ü\x8f / Boston Sports Fanatic', probability=DenseVector([0.9796, 0.0204]), prediction=0.0)
# Row(description='Automatically tweets ecological content from journals in plant biology. Auto filtering used to select content. Maintained by @EcoEvoGames', probability=DenseVector([0.7906, 0.2094]), prediction=0.0)
# Row(description='Avocat at @Fieldfisher. Expert #blockchain / #ethereum. Founder https://t.co/ErnYAvl3U1. Cofounder @AssethFR & @laChainTech', probability=DenseVector([0.9489, 0.0511]), prediction=0.0)
# Row(description='Barrister, wannabe interior designer, general messer. I get panicky when running low on mayonnaise.', probability=DenseVector([0.9835, 0.0165]), prediction=0.0)
# Row(description='Bhagavad Gita verses combined with online dating profile texts. #twitterbot by @greg00r', probability=DenseVector([0.8897, 0.1103]), prediction=0.0)
# Row(description="Bot of @jonathanPKMN that's all you need to know. Don't mind the profile pic.", probability=DenseVector([0.9728, 0.0272]), prediction=0.0)
# Row(description='Bot that tweets flavor text from Magic: the Gathering cards. Made by @scutajar. MtG is property of Wizards of the Coast and Hasbro, I own nothing.', probability=DenseVector([0.6242, 0.3758]), prediction=0.0)
# Row(description='Bringing you the latest in #lncRNA scientific literature. #lincRNA #longnoncodingRNA #RNA #biochem #pubmed #science', probability=DenseVector([0.8741, 0.1259]), prediction=0.0)
# Row(description='CARE fights global poverty by empowering girls and women. Visit https://t.co/tmn5uaYFAE and join us.', probability=DenseVector([0.9475, 0.0525]), prediction=0.0)
# Row(description='CEO @influenceandco, @Forbes @Inc columnist, speaker, father/husband. I work with some of the best brands and most influential people to grow their influence', probability=DenseVector([0.954, 0.046]), prediction=0.0)
# Row(description="CEO Rann Strategy Group. Visiting Professor King's College London. Former Australian Ambassador to Italy and High Commissioner to the UK. SA Premier 2002-2011.", probability=DenseVector([0.917, 0.083]), prediction=0.0)
# Row(description='CEO of #SODMG Records | Owner of @sbeezylightsco | bookings: @ceomiamimike', probability=DenseVector([0.9283, 0.0717]), prediction=0.0)
# Row(description='Channelwali @ Star Pravah ... Masterchef of Khayali Pulao !', probability=DenseVector([0.9774, 0.0226]), prediction=0.0)
# Row(description='Chief Strategy Officer at @Mashable ... lover of @kendallostrow, media, tech, entrepreneurship and sport.', probability=DenseVector([0.8676, 0.1324]), prediction=0.0)
# Row(description='Comedian/Actor/Jester/PajamaWearer/Singer/MarieBiscuitLover/BulldogEnthusiast/SherlockHolmesFanGirl/DogsBollocks', probability=DenseVector([0.9184, 0.0816]), prediction=0.0)
# Row(description='Comedy is when you take two tweets from journalists and then confuse them.', probability=DenseVector([0.9369, 0.0631]), prediction=0.0)
# Row(description='Continuous, auto-updated feed of #Celegans (and other Caenorhabditeae) of fruit or wherever they may be -- PubMed, arXiv, bioRxiv, and @PeerJ PrePrints.', probability=DenseVector([0.4577, 0.5423]), prediction=1.0)
# Row(description='DISCOUNT #SwimStore for exclusive #swimwear - #swimsuits, #SwimCaps, #SwimShirts, #SwimShorts, #SwimmingGoggles, #SwimsuitsForWomen etc. 20% OFF! SHOP NOW!', probability=DenseVector([0.6869, 0.3131]), prediction=0.0)
# Row(description='Daily links showing an unusual slice of IFDB content', probability=DenseVector([0.9114, 0.0886]), prediction=0.0)
# Row(description='Data science, jazz, and fox shirts.', probability=DenseVector([0.9356, 0.0644]), prediction=0.0)
# Row(description='Doing it all backwards & in high heels. Married to @Astro_Oz Grammy to 2. Golfer, skier. Former Member of Congress. Find me @FaegreBD fighting the good fight.', probability=DenseVector([0.9749, 0.0251]), prediction=0.0)
# Row(description='Electrical Engineer at Engro | LUMS 2014 | Work Hard Party Harder', probability=DenseVector([0.9642, 0.0358]), prediction=0.0)
# Row(description='Entrepreneur, Web-desidner, developer.', probability=DenseVector([0.8261, 0.1739]), prediction=0.0)
# Row(description='Estou a procura de amizades sinceras e bem legal na qual podemos manter sempre contatos!!!', probability=DenseVector([0.9968, 0.0032]), prediction=0.0)
# Row(description='Financial Advisor since 1988. Hobbies are skiing, surfing & golf . Whiskey single malt scotch enthusiast. Worldwide traveler with over 55 and counting.', probability=DenseVector([0.936, 0.064]), prediction=0.0)
# Row(description='Follow me for information on the hottest new IANA-registered link relations. A @leonardr bot, updated 1x/day.', probability=DenseVector([0.738, 0.262]), prediction=0.0)
# Row(description="Follow us to know when it's time for a drink. @bugloaf made me.", probability=DenseVector([0.8958, 0.1042]), prediction=0.0)
# Row(description='Founder at @FastForwardLabs. Data Scientist in Residence at @accel. I ? data and cheeseburgers.', probability=DenseVector([0.9681, 0.0319]), prediction=0.0)
# Row(description='Founder of Room to Read.  Author of Leaving Microsoft to Change the World.  Goldman Sachs 100 Most Intriguing Entrepreneurs.', probability=DenseVector([0.7642, 0.2358]), prediction=0.0)
# Row(description='Game developer 4ever. :0)', probability=DenseVector([0.9103, 0.0897]), prediction=0.0)
# Row(description='Health & Safety Executive for E Larning  DVD Sals', probability=DenseVector([0.9607, 0.0393]), prediction=0.0)
# Row(description='Helping those who build the future without destroying humanity. VC @lux_capital. Saudades do Rio.', probability=DenseVector([0.8969, 0.1031]), prediction=0.0)
# Row(description="Hi I'm Max, I kompress JPG or PNG images to JPEG level 0 when you mention me. Improper use equals a blok, use hash tags where applikable. By @_y_a_v_a_ #botALLY", probability=DenseVector([0.9981, 0.0019]), prediction=0.0)
# Row(description="Hi there! I'm a bot which monitors multiple paste sites for password dumps and other sensitive information.", probability=DenseVector([0.9755, 0.0245]), prediction=0.0)
# Row(description='How does he keep up with the news like that? #botALLY', probability=DenseVector([0.9462, 0.0538]), prediction=0.0)
# Row(description='I am a bot that tweets one random object from the Brooklyn Museum collection, four times a day. Bot by @backspace (not affiliated with @brooklynmuseum)', probability=DenseVector([0.9847, 0.0153]), prediction=0.0)
# Row(description="I invented post-it's", probability=DenseVector([0.8932, 0.1068]), prediction=0.0)
# Row(description='I looked up my family tree and found out I was the sap.', probability=DenseVector([0.7884, 0.2116]), prediction=0.0)
# Row(description="I'm a British European, I think like an American & was born in an Arabic country. I've run a few marathons & I start performing in Spanish in November", probability=DenseVector([0.7999, 0.2001]), prediction=0.0)
# Row(description="I'm quite out of my mind, actually, but people continue to find me amusing. I can't imagine why, unless it's morbid fascination.", probability=DenseVector([0.9778, 0.0222]), prediction=0.0)
# Row(description='In case you were wondering. Bot by @RobertVinluan. #botAlly', probability=DenseVector([0.9662, 0.0338]), prediction=0.0)
# Row(description='Infovis, SVG, Go Programming Language, Processing, REST, Web Architecture', probability=DenseVector([0.7136, 0.2864]), prediction=0.0)
# Row(description='Jenny lives, works, and writes in Brooklyn with her partner, twins, and pit bull.', probability=DenseVector([0.8918, 0.1082]), prediction=0.0)
# Row(description='LA VIDA ES PARA VIVIRLA Y PASARLA BIEN NO ANDAR ENBRONCADO CON OTROS VIVILA Y PASALA BOMBA JAJAJAJJA  _ô_Š_ô_Š_ô_Š_ô_Š_ô_Š', probability=DenseVector([0.9453, 0.0547]), prediction=0.0)
# Row(description='LI,NY.', probability=DenseVector([0.9471, 0.0529]), prediction=0.0)
# Row(description='Live Well, Love Much, & Laugh Often', probability=DenseVector([0.9237, 0.0763]), prediction=0.0)
# Row(description='Living, Loving, and working to help you.', probability=DenseVector([0.918, 0.082]), prediction=0.0)
# Row(description="Mashable is for superfans. We're not for the casually curious. Obsess with us.", probability=DenseVector([0.8298, 0.1702]), prediction=0.0)
# Row(description='Minister of External affairs', probability=DenseVector([0.9005, 0.0995]), prediction=0.0)
# Row(description='Mission: Live Like Jesus & Then Lead People to Jesus. The Best is Yet to Come! QB for Seattle Seahawks. Super Bowl Champ', probability=DenseVector([0.7602, 0.2398]), prediction=0.0)
# Row(description='Molecular biology pre-prints from bioarxiv #openaccess #science #molbiol #molecularbiology', probability=DenseVector([0.8795, 0.1205]), prediction=0.0)
# Row(description='NHL player with St Louis Blues. GenEthix partner.', probability=DenseVector([0.9684, 0.0316]), prediction=0.0)
# Row(description='NYU Wasserman Center for Career Development.  133 E 13th Street, 2nd Floor - inside Palladium!', probability=DenseVector([0.9563, 0.0437]), prediction=0.0)
# Row(description="Need a whizzy name for your social media startup? There's a #CDBQ bot for that.", probability=DenseVector([0.9628, 0.0372]), prediction=0.0)
# Row(description='New papers from: Oxford Bioinformatics, Briefings in Bioinformatics, BMC Bioinformatics, SCFBM, PLOS CB, ACM/IEEE. Generated with twitterfeed', probability=DenseVector([0.8539, 0.1461]), prediction=0.0)
# Row(description='News for @TribuneMedia. Former @NYDailyNews-er. Proselytizing morning person. Ask me about my favorite weird Florida story.', probability=DenseVector([0.9419, 0.0581]), prediction=0.0)
# Row(description='Ní£o se faz nada sozinho...', probability=DenseVector([0.9477, 0.0523]), prediction=0.0)
# Row(description='Oculus VR CTO', probability=DenseVector([0.9605, 0.0395]), prediction=0.0)
# Row(description='Official Bachelors of Education UOIT Account - #UOITBEd #BachelorsEd #Education #EdTech #UOIT #BachelorsOfEducation', probability=DenseVector([0.8257, 0.1743]), prediction=0.0)
# Row(description='Pakistani by heart, Engineer by profession, and a Gooner by choice. #COYG #Pak #Arsenal', probability=DenseVector([0.9832, 0.0168]), prediction=0.0)
# Row(description='Papers on directed and self assembly', probability=DenseVector([0.8634, 0.1366]), prediction=0.0)
# Row(description='Pearl Jam have launched a brand new website. Discover more:  https://t.co/1TasMMHPhd', probability=DenseVector([0.9787, 0.0213]), prediction=0.0)
# Row(description='People spending money on real estate in the greatest city on earth / bot by @fitnr', probability=DenseVector([0.9294, 0.0706]), prediction=0.0)
# Row(description='President - Intel Corporation', probability=DenseVector([0.9214, 0.0786]), prediction=0.0)
# Row(description='Prince of Eternia and Defender of the Secrets of Castle Grayskull. Dislikes blue cheese.', probability=DenseVector([0.8945, 0.1055]), prediction=0.0)
# Row(description='Psychotherapist. Special Education Advocate. Armchair Philosopher. Crusader for the downtrodden. Appreciator of good ideas. Film Buff. Mommy.', probability=DenseVector([0.7697, 0.2303]), prediction=0.0)
# Row(description='Representing America! Official CSP NY Twitter handle. Follow for the latest in Business Affairs and financial extrapolation.', probability=DenseVector([0.8157, 0.1843]), prediction=0.0)
# Row(description='Respect and love people who fear God .ARSENAL!!! My Favourite Football Club ! Venu,Serna !! You Guys !! Lets play Game,Set,Match!! Team Williams .', probability=DenseVector([0.922, 0.078]), prediction=0.0)
# Row(description='Se eu fosse um animal, seria uma cigarra', probability=DenseVector([0.8372, 0.1628]), prediction=0.0)
# Row(description="Send me a tweet & I'll give you some love. PS - I'm a computer, so words are my second language.", probability=DenseVector([0.9919, 0.0081]), prediction=0.0)
# Row(description='Senior Vice President of Stores dressbarn Student of the Universe. Inspired by great people, great companies, great stories, and game changing innovation.', probability=DenseVector([0.9689, 0.0311]), prediction=0.0)
# Row(description='Singer songwriter. Musician. Never give up and follow your dreams. Adventurer, Film Producer and board sport enthusiast. Snapchat: ericriethson IG: ericdrieth', probability=DenseVector([0.9912, 0.0088]), prediction=0.0)
# Row(description='Singlin pardise ..', probability=DenseVector([0.9262, 0.0738]), prediction=0.0)
# Row(description='Speaker. Investor. Radio Host @SiriusXM. Best Selling Author @DotComplicated Dot @Missy4Prez. Exec producer Dot @SproutChannel. Former Marketing @Facebook. Mom', probability=DenseVector([0.9684, 0.0316]), prediction=0.0)
# Row(description='Starting my second half of life', probability=DenseVector([0.926, 0.074]), prediction=0.0)
# Row(description='Swamp rock from Iowa that makes you get nude.', probability=DenseVector([0.9411, 0.0589]), prediction=0.0)
# Row(description='Taylor Gang', probability=DenseVector([0.9259, 0.0741]), prediction=0.0)
# Row(description='Technology and culture Humor Music Entertainment', probability=DenseVector([0.7734, 0.2266]), prediction=0.0)
# Row(description='The BEST Inspirational Quotes out there!', probability=DenseVector([0.9308, 0.0692]), prediction=0.0)
# Row(description='The Official Buckcherry Twitter Page', probability=DenseVector([0.8036, 0.1964]), prediction=0.0)
# Row(description='There is no need for that kind of language.', probability=DenseVector([0.935, 0.065]), prediction=0.0)
# Row(description='This Privacy Policy addresses the collection and use of personal information - https://t.co/Jp6yh1T58c', probability=DenseVector([0.9587, 0.0413]), prediction=0.0)
# Row(description="This is the David Mitchell who's in Peep Show and things, not the novelist or the Cumbrian origamist.", probability=DenseVector([0.9362, 0.0638]), prediction=0.0)
# Row(description='Tweetbot about ice-templated or freeze-casted scientific papers. Update from #Pubmed and #Google #Scholar. Maintained by @DevilleSy', probability=DenseVector([0.8202, 0.1798]), prediction=0.0)
# Row(description='Tweets randomly-generated 16x16 images using the NES color palette. Images are resampled for your viewing pleasure.', probability=DenseVector([0.9093, 0.0907]), prediction=0.0)
# Row(description='UNL', probability=DenseVector([0.9156, 0.0844]), prediction=0.0)
# Row(description='Understand that your not alone, there is support for those diagnosed or curious about #Acromegaly. For more information: https://t.co/FXg432cnbZ', probability=DenseVector([0.6865, 0.3135]), prediction=0.0)
# Row(description='Visual storyteller | Photographer based in Italy.', probability=DenseVector([0.949, 0.051]), prediction=0.0)
# Row(description='We make and sell premium organic chocolate using fine, ethically sourced ingredients. Tweeting from our London HQ.', probability=DenseVector([0.9803, 0.0197]), prediction=0.0)
# ...
# Row(description='black eil bries arebae', probability=DenseVector([0.9309, 0.0691]), prediction=0.0)
# Row(description='every 6 hours - by @v21', probability=DenseVector([0.9523, 0.0477]), prediction=0.0)
# Row(description='fartgoth', probability=DenseVector([0.9081, 0.0919]), prediction=0.0)
# Row(description='ha te world thinks', probability=DenseVector([0.9514, 0.0486]), prediction=0.0)
# Row(description='https://t.co/NUKO1zr9PA Snapchat - TimWestwoodTV https://t.co/XXbxSWU1oL https://t.co/Ind8CtxJvR ..... Capital Xtra Saturday 7pm-11pm', probability=DenseVector([0.7698, 0.2302]), prediction=0.0)
# Row(description='i headbang in the rock and roll band fall out boy. snapchat: peteweezy follow it _ÙÔä https://t.co/dgp6GakaCp', probability=DenseVector([0.733, 0.267]), prediction=0.0)
# Row(description="life's a beach man", probability=DenseVector([0.9626, 0.0374]), prediction=0.0)
# Row(description='likely Autechre song titles // aåÊbot byåÊ@inky', probability=DenseVector([0.7459, 0.2541]), prediction=0.0)
# Row(description='simple girl; lover of art; self proclaimed Queen of facial expressions; proud dork; Elephants & animated film enthusiast  #Bruins #Pats _ô\x90Ö_ô_Â_ôÖìäìë', probability=DenseVector([0.995, 0.005]), prediction=0.0)
# Row(description='student', probability=DenseVector([0.9143, 0.0857]), prediction=0.0)
# Row(description='they made me smile as oon as  pressd play', probability=DenseVector([0.9888, 0.0112]), prediction=0.0)
# Row(description='traveller,like being introvert,always learner,discovering oneself, fascinate about data', probability=DenseVector([0.9506, 0.0494]), prediction=0.0)
# Row(description='trust yr technolust', probability=DenseVector([0.9183, 0.0817]), prediction=0.0)
# Row(description='video boy at @polygon äó¢ anime liker äó¢ @CoolGamesInc co-host äó¢ other videos on https://t.co/17vp1IHXJF and streams on https://t.co/uwZQfDr98a äÖ_¥Ÿ\x8f', probability=DenseVector([0.9948, 0.0052]), prediction=0.0)
# Row(description='íŠ relativo porque tudo depende...', probability=DenseVector([0.805, 0.195]), prediction=0.0)
# Row(description='‰ÛÏGenius is... inspiration...‰Û\x9d ‰ÛÓThomas Alva Edison', probability=DenseVector([0.9095, 0.0905]), prediction=0.0)
# Row(description=' IN"""', probability=DenseVector([0.9215, 0.0785]), prediction=0.0)
# Row(description=' VA"""', probability=DenseVector([0.9227, 0.0773]), prediction=0.0)
# Row(description='"""Every Mon-Tues at 10 PM KST | Jisung', probability=DenseVector([0.9144, 0.0856]), prediction=0.0)
# Row(description='"""_______"""', probability=DenseVector([0.9466, 0.0534]), prediction=0.0)
# Row(description='*IN BETA* Low-res, slightly bizarre Open Access images from the Met (via @MuseumBot) crossed with palettes from @colourlovers. Powered by @uncontext. By @_ARP.', probability=DenseVector([0.9443, 0.0557]), prediction=0.0)
# Row(description='@CNNTech editor. Previously: @Mashable. Pint sized and curious. Samantha.Kelly@Turner.com', probability=DenseVector([0.9858, 0.0142]), prediction=0.0)
# Row(description='@NYUStern MBA student passionate about marketing, media, travel, and wine', probability=DenseVector([0.9307, 0.0693]), prediction=0.0)
# Row(description="@dril's tweets, but for your home or office. A @dril you can bring home to your parents on Thanksgiving. #botALLY", probability=DenseVector([0.9365, 0.0635]), prediction=0.0)
# Row(description='@indexventures, @Dropbox, Startups, Physics.', probability=DenseVector([0.8291, 0.1709]), prediction=0.0)
# Row(description='A dad, hubby of @jessvpeterson, long-time original @themisfits fan, @Mashable CTO, @WWE board member, and a mediocre snowboarder.', probability=DenseVector([0.9178, 0.0822]), prediction=0.0)
# Row(description='A feed for papers in network biology.', probability=DenseVector([0.6029, 0.3971]), prediction=0.0)
# Row(description='Actor...who loves to make ppl laugh... ..https://t.co/lvWDr6NKFZ', probability=DenseVector([0.9575, 0.0425]), prediction=0.0)
# Row(description='Agricultural Engineer, likes to joke and trying to live a certain balance between his laptop at the office and his shovel in the field.', probability=DenseVector([0.8584, 0.1416]), prediction=0.0)
# Row(description='Anak Auhn Rmbulan A2R', probability=DenseVector([0.8963, 0.1037]), prediction=0.0)
# Row(description='BOT HARD EVE RY DAY TIL WE REACH THE GOAL #taskcomplete by @negatendo', probability=DenseVector([0.9491, 0.0509]), prediction=0.0)
# Row(description='Bot that scrapes Wikipedia and immediately tweets RIP messages when there is a celebrity death. Member of The Bot Collective, a project by @kildall', probability=DenseVector([0.9649, 0.0351]), prediction=0.0)
# Row(description='Breaking news alerts and updates from the BBC. For news, features, analysis follow @BBCWorld (international) or @BBCNews (UK). Latest sport news @BBCSport.', probability=DenseVector([0.9009, 0.0991]), prediction=0.0)
# Row(description='Carbon-based multicellular lifeform.', probability=DenseVector([0.9373, 0.0627]), prediction=0.0)
# Row(description='Co-Founder @yellowmssngr & Botplatform.io. Entrepreneur in making. https://t.co/XPbVSKJAQ3 || https://t.co/g81AEpYMcX. Young Padawan.', probability=DenseVector([0.9463, 0.0537]), prediction=0.0)
# Row(description='Comedian. Writer. Been cheering up people since 2010.', probability=DenseVector([0.9504, 0.0496]), prediction=0.0)
# Row(description='Connecting service design and customer experience to transform brands and grow businesses.', probability=DenseVector([0.9064, 0.0936]), prediction=0.0)
# Row(description='Contact/booking: contactfreesol@gmail.com', probability=DenseVector([0.9559, 0.0441]), prediction=0.0)
# Row(description="Daily RSS feed for papers on Synthetic Lethality in Cancer. cancer AND (synthetic lethal OR synthetic lethality). Largely automated, don't expect responses", probability=DenseVector([0.4646, 0.5354]), prediction=1.0)
# Row(description='Entertaining One Crore People', probability=DenseVector([0.9239, 0.0761]), prediction=0.0)
# Row(description='Fake recaps of your favorite TV shows ‰Û¢ bot by @ckolderup & @jamiesoncox ‰Û¢ concept by @M_Weiland #vergehackweek #botALLY', probability=DenseVector([0.9338, 0.0662]), prediction=0.0)
# Row(description='Finance Minister, Minister of Corporate Affairs and Minister of Information and Broadcasting, Government of India', probability=DenseVector([0.2659, 0.7341]), prediction=1.0)
# Row(description="Following the formula: I'm not X but I am the definition of X. (via @stefanhayden) Tweets every 10 minutes.", probability=DenseVector([0.961, 0.039]), prediction=0.0)
# Row(description='Free follow! Follow @krishamil_', probability=DenseVector([0.9615, 0.0385]), prediction=0.0)
# Row(description='Galatians 6:9 - #DST ä\x9d_¥Ÿ\x8f - @NCATSUAggies Alumna - Morning News Producer @ABC7SWFL', probability=DenseVector([0.989, 0.011]), prediction=0.0)
# Row(description='Generates a random wizard every 3 hours. | Bot by @THEWAAnderson', probability=DenseVector([0.9919, 0.0081]), prediction=0.0)
# Row(description="Hi. I'm Andrí© Marques, Brazilian. I'm 21 and I am part of Aracnofí£, a Brazilian website about Spider-Man.", probability=DenseVector([0.9491, 0.0509]), prediction=0.0)
# Row(description='Host of The Herd 9-12 on @FS1 & @IHeartradio. SiriusXM ch 83. The Herd podcast on @iTunes. Co Host of @SFY. NYT Best Seller and Sundays on FOX NFL Kickoff.', probability=DenseVector([0.9135, 0.0865]), prediction=0.0)
# Row(description="Host of The Roe Conn Show afternoons on Chicago's WGN Radio and contributor to ABC7's Windy City Live.", probability=DenseVector([0.9486, 0.0514]), prediction=0.0)
# Row(description="I am a walking conundrum. I'm also a mom and do mom stuff.", probability=DenseVector([0.8871, 0.1129]), prediction=0.0)
# Row(description="I live in brooklyn, I'm a bike messenger, I play in a band, I'm uniquely doing the same exact things as everyone else", probability=DenseVector([0.9272, 0.0728]), prediction=0.0)
# Row(description="I'm a bot tweeting a random @andrewismusic lyric every two hours.", probability=DenseVector([0.9869, 0.0131]), prediction=0.0)
# Row(description="I'm a twitterised, neon display, clock. Tweet with #NixieBotShowMe and a word, full guide on tumblr. Be patient with long queues. Queue : Empty", probability=DenseVector([0.6552, 0.3448]), prediction=0.0)
# Row(description='Instagram: @GeneSimmons', probability=DenseVector([0.8882, 0.1118]), prediction=0.0)
# Row(description='It is a thousand times better to have common sense without education than to have education without common sense.', probability=DenseVector([0.6797, 0.3203]), prediction=0.0)
# Row(description="It's not like the fire ended in 1989, so this bot by @air_hadoken makes new lyrics for the Billy Joel classic based on Google Trends. #botALLY", probability=DenseVector([0.9327, 0.0673]), prediction=0.0)
# Row(description='Keep up to date on the latest publications on the universal second messenger Cyclic di-GMP with this twitter feed of up to date publications.', probability=DenseVector([0.8865, 0.1135]), prediction=0.0)
# Row(description='Literature bot searching arXiv, biorXiv, PeerJ & PubMed for supercoiling papers. Maintained by @red_gravel.', probability=DenseVector([0.1126, 0.8874]), prediction=1.0)
# Row(description='Looking for a bot that generates random netflix taglines? You just found one. Lucky.', probability=DenseVector([0.9894, 0.0106]), prediction=0.0)
# Row(description='MAX WEISS BUFFALO NY 26 AND FLY', probability=DenseVector([0.9719, 0.0281]), prediction=0.0)
# Row(description='My new album #Glory is out now!', probability=DenseVector([0.7748, 0.2252]), prediction=0.0)
# Row(description='Nessa sofríÈncia que í© amar vocíÈ', probability=DenseVector([0.9695, 0.0305]), prediction=0.0)
# Row(description='Official Anthony Edwards Twitter Page', probability=DenseVector([0.8054, 0.1946]), prediction=0.0)
# Row(description='PhD Candidate, Carnegie Mellon University. Chair of Advocacy Board, NAGPS.', probability=DenseVector([0.8862, 0.1138]), prediction=0.0)
# Row(description='Publisher and founder of Juggernaut Books', probability=DenseVector([0.9226, 0.0774]), prediction=0.0)
# Row(description="Pubmed RSS paper feed on cohesin and its 'friends': condensin, Smc5/6, Scc2 (NIPBL), Scc4 (Mau2) and MukBEF.", probability=DenseVector([0.7025, 0.2975]), prediction=0.0)
# Row(description='Recent meiosis papers from pubmed RSS and bioR?iv. Maintained by @pmcarlton', probability=DenseVector([0.2195, 0.7805]), prediction=1.0)
# Row(description='Retweets people trying to find the perfect German word. - via @stefanhayden', probability=DenseVector([0.9768, 0.0232]), prediction=0.0)
# Row(description="Rock 'N Roll!", probability=DenseVector([0.8775, 0.1225]), prediction=0.0)
# Row(description="Rocket Ship Builder (that was Twitter's default option... how perfect)", probability=DenseVector([0.9467, 0.0533]), prediction=0.0)
# Row(description="Stanford is one of the world's leading research and teaching institutions. Official Twitter feed by University Communications.", probability=DenseVector([0.9247, 0.0753]), prediction=0.0)
# Row(description='Station 51000 went adrift on 3/10/2013. Unmoored, the NOAA buoy now transmits observation data from an unknown location.', probability=DenseVector([0.9949, 0.0051]), prediction=0.0)
# Row(description='TV Host Fox News Channel 10 PM. Nationally Syndicated Radio Host 3-6 PM EST. https://t.co/z23FRgA02S  Retweets, Follows NOT endorsements!', probability=DenseVector([0.7594, 0.2406]), prediction=0.0)
# Row(description='The Place To Learn Anything, Anywhere For All', probability=DenseVector([0.9491, 0.0509]), prediction=0.0)
# Row(description='The Summits of the Americas bring together the democratically elected Heads of State of the Americas. The OAS serves as the technical secretariat of the process', probability=DenseVector([0.9748, 0.0252]), prediction=0.0)
# Row(description='Trying to understand how brains think and create culture', probability=DenseVector([0.9101, 0.0899]), prediction=0.0)
# Row(description='Tweets new releases on Netflix Instant. Created by @zak123. Check out @Redbox_bot as well. Updates between 5-7AM MST Every Morning.', probability=DenseVector([0.9885, 0.0115]), prediction=0.0)
# Row(description='Under Construction', probability=DenseVector([0.8648, 0.1352]), prediction=0.0)
# Row(description="Updated by Luke O'Dell, Senior Lecturer in NMR Spectroscopy at Deakin University, Australia.", probability=DenseVector([0.9255, 0.0745]), prediction=0.0)
# Row(description='YOLO you only live once', probability=DenseVector([0.9209, 0.0791]), prediction=0.0)
# Row(description='a little disappointed tbh', probability=DenseVector([0.9217, 0.0783]), prediction=0.0)
# Row(description='an infinity of deserts, each more infinite than the last. bot mapped by @getdizzzy', probability=DenseVector([0.9387, 0.0613]), prediction=0.0)
# Row(description='by @NoraReed', probability=DenseVector([0.9209, 0.0791]), prediction=0.0)
# Row(description='generating cards for a mysterious card game åá bot by @ckolderup åá #botALLY åá avatar by Dmitriy Ivanov from the Noun Project', probability=DenseVector([0.9962, 0.0038]), prediction=0.0)
# Row(description='http://t.co/rn21deoPKI', probability=DenseVector([0.8903, 0.1097]), prediction=0.0)
# Row(description='i know right? #wowwwnetwork', probability=DenseVector([0.9317, 0.0683]), prediction=0.0)
# Row(description='i steal from @TVFaceBot and maybe from you, too. @BooDooPerson made me. You can watch my birth! https://t.co/KwqWaVFKGN #botALLY', probability=DenseVector([0.9743, 0.0257]), prediction=0.0)
# Row(description="it's never not funny‹ÄÈ#botALLY‹ÄÈ#wowwwnetwork", probability=DenseVector([0.9244, 0.0756]), prediction=0.0)
# Row(description='prabida', probability=DenseVector([0.9346, 0.0654]), prediction=0.0)
# Row(description='secr', probability=DenseVector([0.8919, 0.1081]), prediction=0.0)
# Row(description="you're here with me now", probability=DenseVector([0.97, 0.03]), prediction=0.0)
# Row(description=' England"""', probability=DenseVector([0.956, 0.044]), prediction=0.0)
# Row(description='""""', probability=DenseVector([0.9035, 0.0965]), prediction=0.0)
# Row(description='"""Katie Lin"""', probability=DenseVector([0.8394, 0.1606]), prediction=0.0)
# Row(description='20 Something in NJ.', probability=DenseVector([0.9138, 0.0862]), prediction=0.0)
# Row(description="Everybody's lookin' forward to the weekend!", probability=DenseVector([0.9111, 0.0889]), prediction=0.0)
# Row(description='Father. Artist. Producer. Actor. Entrepreneur. Philanthropist.', probability=DenseVector([0.8626, 0.1374]), prediction=0.0)
# Row(description='Great Lakes oceanographer, banjo player', probability=DenseVector([0.9373, 0.0627]), prediction=0.0)
# Row(description="Hi, I'm Sharri and I will help review products for you!", probability=DenseVector([0.9258, 0.0742]), prediction=0.0)
# Row(description='If a girl is stupid enough to love you after you broke her heart, I guarantee you. She is the one.', probability=DenseVector([0.9309, 0.0691]), prediction=0.0)
# Row(description='Instagram : Trviswilliams', probability=DenseVector([0.9532, 0.0468]), prediction=0.0)
# Row(description='OA OPERATIVA DE DEFENSA INTEGRAL CAABOBO', probability=DenseVector([0.9275, 0.0725]), prediction=0.0)
# Row(description='The Official American Country Countdown Twitter Page', probability=DenseVector([0.9262, 0.0738]), prediction=0.0)
# Row(description='The complete works of composer JÌ_rgen Sebastian Bot. // by @inky', probability=DenseVector([0.9842, 0.0158]), prediction=0.0)
# Row(description='Verizon Team Penske driver. Race winner in F1, Indycar, NASCAR, CART,  and Grand-AM.', probability=DenseVector([0.9851, 0.0149]), prediction=0.0)
# Row(description="You can't spell words without other words.", probability=DenseVector([0.8595, 0.1405]), prediction=0.0)
# Row(description='http://t.co/YfHoThSDVQ...', probability=DenseVector([0.9361, 0.0639]), prediction=0.0)
# Row(description='meio ogra mas o coraí_í£o í© de mocinha', probability=DenseVector([0.886, 0.114]), prediction=0.0)

# %% [markdown]
# In the text output search for
# `prediction=1`
#
# Write in the chat which `description` got classified as a bot!
#
# Notice that in some of the `description` exists the word - `bot`.
#
# Meaning your algorithm found it without being told directly to search for the word bot 🤓

# %% [markdown]
# ---

# %% [markdown]
# In the last task, you used `BinaryClassificationEvaluator` since it is more accurate to our needs. It works with Binary data - bot or human.
# `ParamGridBuilder` is a utility that helps us construct a parameter grid for our algorithm. It helps us test out various models built with various params.
#
# `ParamGridBuilder` is part of `pyspark.ml.tuning` lib.

# %% [markdown]
# ## Well Done! 👏👏👏
# ## You just finished chapter 4: Spark ML - Evaluating models and intro to Pipelines
# ## This was the last chapter for **Apache Spark ML First Steps**
#
# ## I hope you enjoyed it!
#
#
# [@adipolak](https://twitter.com/AdiPolak)
