# %% [markdown]
# # 2 - Apache Spark ML - Create train and test set
#
# In this chapter, you will:
#
# • Create a test and train set
#
# • Learn more Spark functionality and how to use it

# %%
from pyspark.sql import SparkSession 

spark = SparkSession.builder \
    .master('local[*]') \
    .appName("ApacheSparkML") \
    .getOrCreate()

# %% [markdown]
# After filtering and working on the train DataFrame, we need to make sure the test set has the same structure.
#
# Load testing data from CSV file:

# %%
df_test = spark.read.csv("testing_bot_data.csv", header= True)

# %%
df_test.schema
# Out:
# StructType(List(StructField(id,StringType,true),StructField(id_str,StringType,true),StructField(screen_name,StringType,true),StructField(location,StringType,true),StructField(description,StringType,true),StructField(url,StringType,true),StructField(followers_count,StringType,true),StructField(friends_count,StringType,true),StructField(listed_count,StringType,true),StructField(created_at,StringType,true),StructField(favourites_count,StringType,true),StructField(verified,StringType,true),StructField(statuses_count,StringType,true),StructField(lang,StringType,true),StructField(status,StringType,true),StructField(default_profile,StringType,true),StructField(default_profile_image,StringType,true),StructField(has_extended_profile,StringType,true),StructField(name,StringType,true)))

# %%
df_test.count()
# Out:
# 578

# %%
df_test.limit(25) .toPandas ()
# Out:
#              id      id_str      screen_name          location  \
# 0    2281292622  2281292622        __keating          brooklyn
# 1    2344040251  2344040251     _callme_Dani   Los Angeles, CA
# 2     765871267   765871267   _little_britt_              None
# 3    4772373433  4772373433            134k5              None
# 4    1324548560        None    2181chrom_bot             自分の天幕
# 5    2561341789        None        2LA1R_bot              None
# 6     347810134        None         3pei_bot               三河屋
# 7     856303860        None      94kichi_bot              None
# 8   8.32875E+17        None  A3_Dekasegi_bot            ビロード駅前
# 9      88856792        None       aamir_khan            Mumbai
# 10  7.13557E+17    7.14E+17  AceWallpaperBot              None
# 11   1566746503  1566746503    acormier_bzfd      New York, NY
# 12     90420314        None      ActuallyNPH     Manhattanland
# 13    184910040        None            Adele            London
# 14    157690631   157690631          aflores       Los Angeles
# 15     42420346        None          agnezmo       Los Angeles
# 16     42382447    42382447    Agostinozoida     Agostinozoida
# 17     43993280    43993280   AhmedBharoocha              None
# 18   2305236733        None     aho_levi_bot          teamリヴァイ
# 19  7.42794E+17    7.43E+17        aiomacbot              None
# 20     31348594        None      akshaykumar              None
# 21    122085859   122085859    AlannaBennett      New York, NY
# 22     23573083        None    AlArabiya_Brk             Dubai
# 23     43152482        None    AlejandroSanz              None
# 24    188857501   188857501  alexis_levinson  Washington, D.C.
#
#                                           description  \
# 0   lgbt editor at @buzzfeed. shannon.keating@buzz...
# 1   News Curation Editor @BuzzFeedNews I do a lot ...
# 2   Family comes first! Also I am in love with piz...
# 3   @BuzzFeedJapan ��� @cnet_japan / DM��܋�㋁_��_��...
# 4   これはFE覚醒のクロム…つまり俺がツイ廃なbotらしい。よく分からんがネタ要素しかないそうだ...
# 5                   ふれあ語をつぶやくbotです たまに中の人(ふれあ)もつぶやきます
# 6   ■ちわーす！三河屋でーす！三郎くんには負けませんｗｗｗ■サザエさんに過去登場、三河屋さんへ勤...
# 7   94 チャック・ウィルソンと愉快な仲間たちの笑いあり涙ありなちょこっとキチガイツイートを集め...
# 8   シトロン「A3!出稼ぎ日誌ダヨー！みんなの出稼ぎ中のあんなことやこんなことをまとめた日誌ネ！...
# 9                                              Actor.
# 10  Posts a [SFW] wallpaper every 30 minutes. Ever...
# 11  Investigative Reporter-Editor @buzzfeed. Forme...
# 12  I dig variety acts, Pixar, puppets, prestidigi...
# 13                            https://t.co/5Vf55N5xFe
# 14  Latino affairs and breaking news reporter for ...
# 15  DREAM BELIEVE & MAKE IT HAPPEN! Instagram: @ag...
# 16                                      Agostinozoida
# 17                                  I forget to tweet
# 18  YDK。botシステム外部レンタルから自作に乗り換えました。呼ぶとヒョッコリ現れます。モノを...
# 19                A simple all-in-one bot for the Mac
# 20                                               None
# 21  Writer, all sorts. Film & TV Writer @BuzzFeedN...
# 22                 خدمة قناة #العربية للأخبار العاجلة
# 23                            https://t.co/sS9G4mmPM0
# 24  @BuzzFeedNews reporter. former @NRO. Scared of...
#
#                         url followers_count friends_count listed_count  \
# 0   https://t.co/QneJmYRyhj            4466          1295          111
# 1                      None             295          1016           10
# 2   https://t.co/E7DE1cJB7e         1001678          3017           14
# 3   https://t.co/Cbguzs2PjT             445           487           17
# 4    http://t.co/10Swf6luED             187            68           13
# 5                      None              80            87         None
# 6   http://twpf.jp/3pei_bot            2020          1978           56
# 7                      None              70            80            2
# 8   https://t.co/t171JmIrjL             181           144            2
# 9   https://t.co/l1dUhQjS8Y        20419393             9            6
# 10  https://t.co/tuq9iPhc0Z           20423             8          130
# 11  https://t.co/iiAufe34NG            1436          2017           55
# 12  https://t.co/c8ibVF0Lfq        26376073            91        60767
# 13  https://t.co/5Vf55N5xFe        27950120           157        32993
# 14   http://t.co/ykLlu4DCdC            5210          2555          232
# 15  https://t.co/PYhVmN5FYH        16328463          1071        10848
# 16  https://t.co/2gdWyQjNq4             964           331           15
# 17  https://t.co/iM3lj0uBHg            5254          2407          102
# 18                     None             446           431            4
# 19  https://t.co/cR0QCvj4cu            1404             0            2
# 20  https://t.co/nVpOquecxs        16933838            21        14682
# 21  https://t.co/nLwRgOwrQ9            8619          3229          190
# 22  https://t.co/3J8D8Z8yvo        15610695            36        15248
# 23  https://t.co/jh99bUQM9w        15836207          1046        32067
# 24                     None           14749          1843          584
#
#                         created_at favourites_count verified statuses_count  \
# 0   Tue Jan 07 23:26:52 +0000 2014             1579     TRUE           3036
# 1   Fri Feb 14 19:45:56 +0000 2014              300    FALSE            618
# 2                  8/18/2012 15:13            13040     TRUE           3329
# 3   Sun Jan 17 07:11:45 +0000 2016             1112    FALSE             46
# 4   Wed Apr 03 13:00:42 +0000 2013             None     None         690359
# 5   Wed Jun 11 13:12:06 +0000 2014             None     None          20167
# 6   Wed Aug 03 11:52:59 +0000 2011             None     None         968182
# 7   Mon Oct 01 12:39:46 +0000 2012             None     None          76735
# 8   Sat Feb 18 08:50:03 +0000 2017             None     None           1960
# 9   Tue Nov 10 05:08:56 +0000 2009             None     TRUE            468
# 10                  3/26/2016 2:42                0    FALSE          17387
# 11  Wed Jul 03 21:28:01 +0000 2013             1099     TRUE            967
# 12  Mon Nov 16 15:54:48 +0000 2009             None     TRUE           2666
# 13  Mon Aug 30 19:53:19 +0000 2010             None     TRUE            287
# 14  Sun Jun 20 15:27:55 +0000 2010             1169     TRUE           5501
# 15  Mon May 25 15:05:00 +0000 2009             None     TRUE          14596
# 16                 5/25/2009 10:02             2832    FALSE           6389
# 17                  6/1/2009 22:44             3082    FALSE           3392
# 18  Wed Jan 22 17:52:19 +0000 2014             None     None         119680
# 19                 6/14/2016 18:59               12    FALSE            141
# 20  Wed Apr 15 05:23:19 +0000 2009             None     TRUE           3673
# 21  Thu Mar 11 15:00:48 +0000 2010            50921     TRUE          38918
# 22  Tue Mar 10 09:15:09 +0000 2009             None     TRUE          82958
# 23  Thu May 28 17:21:35 +0000 2009             None     TRUE          27660
# 24  Thu Sep 09 19:19:59 +0000 2010             2389     TRUE          20076
#
#    lang                                             status  \
# 0    en  "{'created_at': 'Tue Apr 11 15:31:51 +0000 201...
# 1    en  "{'created_at': 'Tue Apr 11 00:56:02 +0000 201...
# 2    en  "{'place': None, 'retweeted': False, 'favorite...
# 3    ja  "{'created_at': 'Sat Apr 08 08:41:08 +0000 201...
# 4    ja  "{u'lang': u'ja', u'text': u'@2181lucina_bot \...
# 5    ja  "{u'lang': u'ja', u'text': u'\u3010\u3075\u308...
# 6    ja  "{u'lang': u'ja', u'text': u'@kazenoraby \uff6...
# 7    ja  "{u'lang': u'ja', u'text': u'\u307f\u3093\u306...
# 8    ja  "{u'lang': u'ja', u'text': u'\u30b7\u30c8\u30e...
# 9    en  "{u'lang': u'en', u'text': u'Hey guys, doing s...
# 10   en  "{'favorite_count': 12, 'id': 8514323558563061...
# 11   en  "{'created_at': 'Tue Apr 11 14:07:03 +0000 201...
# 12   en  "{u'lang': u'en', u'text': u""Podcast recommen...
# 13   en  "{u'lang': u'en', u'truncated': True, u'text':...
# 14   en  "{'created_at': 'Tue Apr 11 18:31:46 +0000 201...
# 15   en  "{u'lang': u'en', u'text': u'Too comfortable \...
# 16   en  "{'place': None, 'retweeted_status': {'place':...
# 17   en  "{'place': None, 'retweeted_status': {'place':...
# 18   ja  "{u'lang': u'ja', u'text': u'@kotsubu_149 \u30...
# 19   en  "{'favorite_count': 2, 'id': 85117552838408192...
# 20   en  "{u'lang': u'en', u'truncated': True, u'text':...
# 21   en  "{'created_at': 'Tue Apr 11 19:59:24 +0000 201...
# 22   en  "{u'lang': u'ar', u'text': u'\u0635\u062d\u064...
# 23   es  "{u'lang': u'es', u'retweeted_status': {u'lang...
# 24   en  "{'created_at': 'Tue Apr 11 17:20:13 +0000 201...
#
#                                     default_profile  \
# 0                                'truncated': False
# 1                                'truncated': False
# 2    'created_at': 'Sat Apr 08 19:18:41 +0000 2017'
# 3       'in_reply_to_status_id': 850628293522894849
# 4      u'in_reply_to_status_id': 851191070100606976
# 5                  u'id_str': u'851191514206097409'
# 6      u'in_reply_to_status_id': 851191255841124352
# 7                  u'id_str': u'851191524062670848'
# 8                  u'id_str': u'851191498854998016'
# 9                  u'id_str': u'849903030598344704'
# 10                             'contributors': None
# 11                    'in_reply_to_status_id': None
# 12                                         intimate
# 13                 u'id_str': u'844477332693897216'
# 14                    'in_reply_to_status_id': None
# 15                 u'id_str': u'842052863853531137'
# 16                                    Jamie Kennedy
# 17                      'possibly_sensitive': False
# 18     u'in_reply_to_status_id': 851191318789226497
# 19                             'contributors': None
# 20                 u'id_str': u'851080708130983937'
# 21                               'truncated': False
# 22                 u'id_str': u'851171829091848196'
# 23                 u'id_str': u'851163510331629568'
# 24                               'truncated': False
#
#                                 default_profile_image  \
# 0                         'entities': {'hashtags': []
# 1                         'entities': {'hashtags': []
# 2                            'id': 850790016838238210
# 3    'in_reply_to_status_id_str': '850628293522894...
# 4       u'in_reply_to_screen_name': u'2181lucina_bot'
# 5                                         u'urls': []
# 6           u'in_reply_to_screen_name': u'kazenoraby'
# 7                                         u'urls': []
# 8                                         u'urls': []
# 9                                         u'urls': []
# 10                     'id_str': '851432355856306177'
# 11                  'in_reply_to_status_id_str': None
# 12                                              crazy
# 13      u'urls': [{u'url': u'https://t.co/W5570kii0M'
# 14                  'in_reply_to_status_id_str': None
# 15      u'urls': [{u'url': u'https://t.co/heDL0FPSqO'
# 16                                       Kate Quigley
# 17     'created_at': 'Wed Apr 05 14:33:06 +0000 2017'
# 18         u'in_reply_to_screen_name': u'kotsubu_149'
# 19                     'id_str': '851175528384081922'
# 20      u'urls': [{u'url': u'https://t.co/fNgLENylXk'
# 21                        'entities': {'hashtags': []
# 22                                        u'urls': []
# 23      u'urls': [{u'url': u'https://t.co/MGqSQhRAwB'
# 24                        'entities': {'hashtags': []
#
#                                  has_extended_profile  \
# 0                                       'symbols': []
# 1                                       'symbols': []
# 2                                        'lang': 'en'
# 3                   'in_reply_to_user_id': 2249898907
# 4                    u'id_str': u'851191507486986241'
# 5                         u'id': 851191514206097409}"
# 6                    u'id_str': u'851191511765176320'
# 7                         u'id': 851191524062670848}"
# 8                         u'id': 851191498854998016}"
# 9    u'media': [{u'expanded_url': u'https://twitte...
# 10                        'in_reply_to_user_id': None
# 11                        'in_reply_to_user_id': None
# 12                                         mysterious
# 13   u'expanded_url': u'https://twitter.com/i/web/...
# 14                        'in_reply_to_user_id': None
# 15   u'expanded_url': u'https://www.instagram.com/...
# 16   K-Von and more! Hope you can make it! https:/...
# 17                           'id': 849630982311366656
# 18                   u'id_str': u'851191500176211970'
# 19                  'in_reply_to_user_id': 1090862568
# 20   u'expanded_url': u'https://twitter.com/i/web/...
# 21                                      'symbols': []
# 22                               u'retweet_count': 26
# 23   u'expanded_url': u'https://twitter.com/alejan...
# 24                                      'symbols': []
#
#                                                  name
# 0    'user_mentions': [{'screen_name': 'Carrasquillo'
# 1    'user_mentions': [{'screen_name': 'elliesunak...
# 2                             'retweet_count': 2037}"
# 3             'in_reply_to_user_id_str': '2249898907'
# 4                                         u'urls': []
# 5                                                TRUE
# 6                                         u'urls': []
# 7                                                TRUE
# 8                                                TRUE
# 9       u'display_url': u'pic.twitter.com/uYmd8FKOVH'
# 10                                 'favorited': False
# 11                    'in_reply_to_user_id_str': None
# 12                                        informative
# 13                             u'retweet_count': 5435
# 14                    'in_reply_to_user_id_str': None
# 15                              u'retweet_count': 211
# 16   'extended_entities': {'media': [{'id_str': '8...
# 17                                       'lang': 'en'
# 18                                        u'urls': []
# 19                                 'favorited': False
# 20                             u'retweet_count': 1725
# 21                                'user_mentions': []
# 22                          u'id': 851171829091848196
# 23                              u'retweet_count': 214
# 24       'user_mentions': [{'screen_name': 'jmartNYT'

# %% [markdown]
# Clean and prep testing data as well:
# Remember that here we don't have bot value.
#
# You will not drop id, as we will use it to compare results later.
#
# Excecute the next commands:

# %%
from pyspark.sql.types import IntegerType, ArrayType, BooleanType, StringType
from pyspark.sql.functions import udf
from pyspark.sql.functions import when


# Dropping irrelevant columns and duplicates
df_test = df_test.drop('default_profile_image','has_extended_profile','url','created_at','lang','id','id_str')
df_test = df_test.dropDuplicates()

# %%
# First Transformation
df_test = df_test.withColumn("friends_count", df_test["friends_count"].cast(IntegerType()))
df_test = df_test.withColumn("listed_count", df_test["listed_count"].cast(IntegerType()))
df_test = df_test.withColumn("favourites_count", df_test["favourites_count"].cast(IntegerType()))
df_test = df_test.withColumn("statuses_count", df_test["statuses_count"].cast(IntegerType()))
df_test = df_test.withColumn("verified", df_test["verified"].cast(BooleanType()))
df_test = df_test.withColumn("default_profile", df_test["default_profile"].cast(BooleanType()))

# %%
# Second Transformation
df_test = df_test.withColumn('default_profile',df_test['default_profile'].cast(IntegerType()))
df_test = df_test.withColumn('name',when(df_test['name'].isNull(),0).otherwise(1))
df_test = df_test.withColumn('verified',df_test['verified'].cast(IntegerType()))

# %%
# Theird Transformation
df_test = df_test.withColumn('verified',when(df_test['verified'].isNull(),0).otherwise(df_test['verified']))
df_test = df_test.withColumn('default_profile',when(df_test['default_profile'].isNull(),0).otherwise(df_test['default_profile']))
df_test = df_test.withColumn('location',when(df_test['location'].isNull(),0).otherwise(1))
df_test = df_test.withColumn('status',when(df_test['status'].isNull(),0).otherwise(1))
df_test = df_test.withColumn('screen_name',when(df_test['screen_name'].isNull(),0).otherwise(1))

# %%
# Forth Transformation
df_test = df_test.dropna(subset=['description'])

def split_and_set(some_str):
    if isinstance(some_str, str):
        some_str = ''.join(c for c in some_str if c not in "[](){}<>,'/.")
        return list(set(some_str.split(' ')))
    return some_str

list_udf = udf(lambda y: split_and_set(y), ArrayType(StringType()))
df_test = df_test.withColumn('description', list_udf(df_test['description']))

# %%
# Fifth Transformation - fill NA:
df_test = df_test.fillna({'followers_count':0,'statuses_count':0,'favourites_count':0,'listed_count':0,'friends_count':0,})

# %% [markdown]
# Save to parquet:
#
# Code sample:
# ```python
# df_test.write.parquet("test_data")
# ```

# %%
df_test.write.parquet("test_data")

# %% [markdown]
# The `test_data` file that you save doesn't consist of information about bots at all.
#
# We can use it to compare various algorithms and see how they behave.
# However, since our training data is supervised, we would like to test it with classified data.
# This will help us estimate our model.
#
# Hence, you will split the training data into testing and train data set.

# %%
# Load the train data:
df_train = spark.read.parquet("final_train_data")

# %% [markdown]
# Split the training data into training and test sets, hold 30% out for testing.
#
# Use randomSplit function:
#
# ```python
# (trainingData, testData) = some_data.randomSplit((0.7, 0.3))
# ```
#
# <details><summary>Hint</summary>
# <p>
#
# Use randomSplit function:
#
# ```python
# (trainingData, testData) = data.randomSplit((0.7, 0.3))
#
# ```
# </p>
# </details>
#
# Remember to validate yourself with count

# %%
(trainingData, testData) = df_train.randomSplit([0.7, 0.3])

# %%
trainingData.count()
# Out:
# 1714

# %%
testData.count()
# Out:
# 719

# %% [markdown]
# Save the split data for the next Chapter.

# %%
testData.write.mode('overwrite').parquet("classified_test_data")

# %%
trainingData.write.mode('overwrite').parquet("classified_train_data")

# %% [markdown]
# # Well Done! 👏👏👏
#
#
# ## You just finished:  Apache Spark ML - Create train and test set
#
#
# ## Next exercise: Apache Spark ML and create machine learning models
